# %% [markdown]
# ### Quickie python to match a facebook friends list fuzzily with a list of potential matches

# %%
# Load useful packages
from pandas import Series,DataFrame
import pandas as pd
import io
from fuzzywuzzy import fuzz
# Out:
# /home/topquirk67/anaconda3/envs/insight/lib/python3.7/site-packages/fuzzywuzzy/fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
friends_file = '/home/topquirk67/Documents/mh.txt'
match_file   = '/home/topquirk67/Downloads/Go-to-survey 2017 (All Students) - Sheet1.csv'

match_data = pd.read_csv(match_file)
match_data.columns = ['advisor', 'grade', 'name', 'Q1', 'Q2', 'Q3', 'Q4', 'Q5', 'Q6']

# %%
match_data = match_data.loc[match_data['grade'].isin([9,10])]
match_data.drop(['advisor', 'Q1', 'Q2', 'Q3', 'Q4', 'Q5', 'Q6'],axis=1,inplace=True)
match_data['name'] = match_data['name'].str.lower()
match_data['name'] = match_data['name'].str.replace(' ','')

# %%
match_data.head()
# Out:
#    grade              name
# 0      9      alextanemura
# 1      9  benjaminscherzer
# 2      9     frankietonina
# 3      9      ingridodmark
# 4      9    leightoncahoon

# %%
# simply read in friends as a list
with open(friends_file) as f:
    friends_lines = f.read().splitlines()
    
# eliminate all blank lines and all lines with "friend" case insensitive in it
friends_lines = [item.lower() for item in friends_lines]
friends_lines = [item.replace(" ","") for item in friends_lines if 'friend' not in item]
friends_lines = [item for item in friends_lines if item != '']

# %%
#friends_lines

# %%
# go through students df and find the maximum fuzzy match; print if above 50

#fuzz.ratio(friends_lines[9],match_data['name'])
for item in match_data['name']:
    scores = [fuzz.ratio(item,) for friend in friends_lines]
    print(item)
# Out:
# alextanemura
# benjaminscherzer
# frankietonina
# ingridodmark
# leightoncahoon
# oliviafinkelstein
# savvysparks
# sorenwilliams
# willmueller
# alexisnorwitz
# arianarastani
# junoshantz
# laurenhanauer
# maiamalakoff
# morrisvasser-campbell
# orsonsmith
# troygipson
# willvipond
# akselodmark
# alekcurless
# derekeng
# ellaflanders
# haleyselman
# harlowebrumett-dunn
# lucywaggoner
# williamle
# zacwurfel
# abbysanderson
# dimitrivladimir
# elenazytnicki
# florettecederstrand
# lucassherman
# maxsirotnik
# maxtorres
# palmermckay
# sophieginsberg-hayes
# coltranethomas
# dylanbreslin
# ellihebert
# henryupton
# isabelsiebrecht
# matthewhopkins
# pjcolino
# sophieflynn
# isaaclong
# grantarntz
# lailapickett
# maxcook
# owensangster
# scoutphillips
# sofiavladimir
# stellahorns
# willsieler
# ariporad
# beccafriedman
# helenruckelshaus
# j.d.jahn
# nicolearends
# oliverhamilton
# romansaladino
# sallymenti
# serenacunningham
# camihebert
# jackfleischmann
# juliagreenley
# lukeduncan
# malloryleff
# sydneygrayson
# yanrich
# angelazapata
# aurelegeltzer
# calistatoy
# chloerubin
# eliasorbino
# floramehdi
# haydenjanssen
# jackspangler
# rileyrock
# anyadraine
# hannahmcconnell
# jackjones
# jacobratzliff
# katepotvin
# lewiswelsh
# oliviashaw
# sarahbelinsky
# theospringer
# arjunpiplani
# isaacrose
# isaiahronquillo
# sadiecook
# sarinasingh
# tcbenton
# theoperlin
# benheymann
# chrissanchez
# connortinubu-karch
# emmaleventhal
# olivialevitan
# sabinemaclise
# sambouchey
# sammyketcham
# savannahparker
# zachcohen
# bafodedrame
# danielscherzer
# ellemisko
# ellisandrews
# isabellafonseca
# juliawelton
# maxschrock
# rhoadsamadon
# sambeane
# akieisenman-shoda
# audreylamey
# benadams
# bentasch
# drewnofsinger
# ellajursek
# maxshethar
# piahamel
# wyattwren
# allisonwicklund
# carolinastedman
# gracieduck
# sammoffitt
# samschroeter
# samrawlins
# sophieborenstein
# theokessel
# blairvoorhees
# emersonrichmond-burke
# guyburg
# jessecarter
# joiporter-harris
# mckinlaydaggatt
# rubyseiwert
# solomoncalvert-adera
# gageraftery
# natalieparker
# nejatali
# norachapman
# samzivin
# saylorgreen
# willpatrick
# zoemiller
# ellakodjababian
# evinjaff
# juliaphillips
# kamerynbatingan
# luciarosenast
# lucyjacobsen
# malloryrubin
# oscarzorn
# owencobb
# sylviabergerud
# brennenzakaluk
# brynmcconnell
# elsaaitchison
# ezramagaram
# jaydenyoppolo
# larspurdy
# penelopeowen
# tategibbons
# victoralhadeff
# adamloeb
# dariahorns
# darioguerra
# jordanisaacs
# j.w.thomas
# katemilne
# mackiewilliams
# paigediamond
# trevordunnigan
# angelhernandez
# carmenoldham
# chasrinne
# emilyrinn
# georgiarobinson
# kelchen
# leofaury
# makenakerns
# sophiaescalona
# axelhejlsberg
# gigiolsen
# joshkrimsky
# laurenbaty
# maddybyrne
# maxwellrichmond
# mei-jifong
# oliviawilliamson
# rachelgalanti
# tayamcmillan
# zacharyeverts
# adrianvalentine
# davidking
# isabellabarwick
# jackedgar
# joshuateicher
# lunahotchkiss-blackledge
# marlamitchell
# nataliefleming
# savannahwestra
# celestemccallcromer
# duncankubalak
# elenasandoval
# heldanadaniel
# jadkarjian
# leilaguilhemotonia
# oliviabrandon
# owencolwell
# vansenseney
# abrahamsolovy
# curtisherbolich
# estellestedman
# lucymalarkey
# matthewleroy
# oliviaharkins-finn
# cicicarter
# taylorconrad
# aidanbarry
# blakecalvo
# audreyhogan
# claircolee
# elirichmond
# jessapodell
# kurtgundlach
# natalierezek
# rushabartlett
# aarongreenstein
# andersgibbons
# caitlincalfo
# coreywood
# ethanpurcell
# hannahclack
# kadenrosenblatt
# madeleineosler
# mirandawu-georges
# oliviaforslund
# serenmccallcromer
# asherstein
# bradydoran
# brennamccormick
# hannahdavis
# ianlock
# lydiaunderwood
# robertherbolich
# zorahelson
# alainaneuburger
# jakobkriseman
# jesachiro
# lukeallen
# luzguerra
# maxray-keil
# moriahreibman
# sashapoll
# taliaaukema-gray
# tessbarton
# andrzejdomanski
# avikakasubhai
# benjaminriley
# brandonburke
# bunkerrisse
# chloedarrow
# ericgolde
# havasprung
# maxhellmann
# mayasulkin
# taylorrinn

# %%
print(friends_lines[9],' ',match_data['name'][9])
# Out:
# saasgrad   alexisnorwitz

# %%
fuzz.ratio('saasgrad','gradsaas')
# Out:
# 50
