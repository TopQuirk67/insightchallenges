# %% [markdown]
# ## NYTimes Letter Boxed
#
# This is a notebook to provide solutions to the [New York Times Letter Boxed Puzzle](https://www.nytimes.com/puzzles/letter-boxed).

# %%
#puzzle = {'UNH','ASC','KTO','LRI'}
puzzle = {'EMA','HNL','RSB','OIT'}

def check_puzzle(puzzle):
    import string
    try:
        assert len(puzzle) == 4, 'Puzzle must be length 4'
    except AssertionError as e:
        print(e)
    try:
        assert all([len(item)==3 for item in puzzle]), 'Puzzle sides must all be length 3'
    except AssertionError as e:
        print(e)
    try:
        assert all([len(set(item))==3 for item in puzzle]), 'Puzzle must have unique characters'
    except AssertionError as e:
        print(e)
    try:
        char_set = set()
        s = set(string.ascii_uppercase)
        for item in puzzle:
            char_set.update(set(item))
        assert (len(char_set)==12) and (len(char_set.intersection(s))==12), 'Puzzle have exactly 12 unique characters and all in alphabet'
    except AssertionError as e:
        print(e)

check_puzzle(puzzle)

# %%
# load dictionary
# Please note that this file is not on github; you can substitute another dictionary
# for example, https://gitlab.com/snippets/1777561/raw has a dictionary.
file18     = 'twl2018.txt'
with open(file18) as f:
    twl18 = f.read().splitlines()
twl18 = [item.upper() for item in twl18]

# pre-process lexicon: only keep possible words:
# rules: 1) can reuse letters 2) consecutive letters must be from different sides 3) >=3 letter length
def preprocess_lexicon(l,puzzle):
    puzzle_string_unsorted = ''.join(puzzle)
    lex = []
    for item in l:
        # check that word is at least three characters and all the characters are in the puzzle
        if (len(item)>=3) and (all([c in puzzle_string_unsorted for c in item])):
            # check that word is valid; i.e. subsequent letters must come from different puzzle sides
            side1 = -1
            wd  = True
            for c in item:
                side2 = puzzle_string_unsorted.index(c) // 3
                wd = wd and (side2 != side1)
                side1 = side2
            if wd:
                lex.append(item)#=''.join(sorted(set(item)))

    return(lex)

lex = preprocess_lexicon(twl18,puzzle)

# %%
# import random
# num_to_select = 20
# list_of_random_items = sorted(random.sample(lex, num_to_select))
# list_of_random_items

# %%
puzzle
# Out:
# {'EMA', 'HNL', 'OIT', 'RSB'}

# %%
def processed_letters(chain,puzzle):
    s = ''.join(sorted(''.join(puzzle)))
    finished_letters = set()
    for item in chain:
        finished_letters.update(item)
    unfinished_letters = set(s) - finished_letters
    return finished_letters,unfinished_letters

def reduce_lexicon(chain,lexicon,unfinished_letters):
    sort_by = [len(unfinished_letters.intersection(set(item))) for item in lexicon]
    sorted_lex = [item for _,item in sorted(zip(sort_by,lexicon),reverse=True)]
    sorted_lex = [item for item in sorted_lex if (len(unfinished_letters.intersection(set(item))) > 0)]
    return(sorted_lex)

def tree(chain,puzzle,lexicon,best_depth):
    tree_depth = len(chain)
    # 1) reduce lexicon: only words that start with the last character of the final 
    # word in chain and only words that will eliminate new letters
    # 2) sort lexicon: descending order by the number of letters that the word will eliminate
    finished_letters,unfinished_letters = processed_letters(chain,puzzle)
    reduced_lexicon = reduce_lexicon(chain,lexicon,unfinished_letters)
    #print('Start tree call',tree_depth,chain,reduced_lexicon,unfinished_letters)
    for word in reduced_lexicon:
        if len(chain)>0:
            last_letter = chain[-1][-1]
            valid_next_word = last_letter == word[0]
        else:
            valid_next_word = True
        if (valid_next_word):
            c = chain.copy()
            c.append(word)
            f,u = processed_letters(c,puzzle)
            #print('XXX',chain,word,u,best_depth)
            # base case:
            if len(u)==0:
                if (tree_depth+1<best_depth):
                    best_depth = tree_depth+1
                print('Puzzle Solved! Depth = ',best_depth,' ',c,'leftovers',u)
            elif (tree_depth+1 >= best_depth):
                pass
                #print('Puzzle unsolved',tree_depth+1,c,' leftovers',u)
            else:
                #print('XXXX',tree_depth,c,reduced_lexicon)
                best_depth = tree(c,puzzle,reduced_lexicon,best_depth)
    
    return(best_depth)
    
chain = []
best_depth = tree(chain,puzzle,lex,10)
best_depth
# Out:
# Puzzle Solved! Depth =  2   ['THERMOSTABLE', 'ETESIANS'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOSTABLE', 'ETESIAN'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOSTABLE', 'ETERNISES'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOSTABLE', 'ETERNISE'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOSTABLE', 'ETERNALISES'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOSTABLE', 'ETERNALISE'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOSTABLE', 'ESTRINS'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOSTABLE', 'ESTRIN'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOSTABLE', 'ESERINES'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOSTABLE', 'ESERINE'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOSTABLE', 'ERMINES'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOSTABLE', 'ERMINE'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOSTABLE', 'EOSINS'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOSTABLE', 'EOSINES'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOSTABLE', 'EOSINE'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOSTABLE', 'EOSIN'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOSTABLE', 'EONISMS'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOSTABLE', 'EONISM'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOSTABLE', 'EONIAN'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOSTABLE', 'EOLIAN'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOSTABLE', 'ENTRIES'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOSTABLE', 'ENTRAINS'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOSTABLE', 'ENTRAINER'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOSTABLE', 'ENTRAIN'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOSTABLE', 'ENTRAILS'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOSTABLE', 'ENTERTAINS'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOSTABLE', 'ENTERTAINER'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOSTABLE', 'ENTERTAIN'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOSTABLE', 'ENTEROBIASIS'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOSTABLE', 'ENTEROBIASES'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOSTABLE', 'ENTASIS'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOSTABLE', 'ENTASIAS'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOSTABLE', 'ENTASIA'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOSTABLE', 'ENTAILS'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOSTABLE', 'ENTAILER'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOSTABLE', 'ENTAIL'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOSTABLE', 'ENSILES'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOSTABLE', 'ENSILE'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOSTABLE', 'ENSHRINES'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOSTABLE', 'ENSHRINE'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOSTABLE', 'ENOSISES'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOSTABLE', 'ENOSIS'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOSTABLE', 'ENISLES'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOSTABLE', 'ENISLE'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOSTABLE', 'ELINTS'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOSTABLE', 'ELINT'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOSTABLE', 'ELIMINATES'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOSTABLE', 'ELIMINATE'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOSTABLE', 'ELATERINS'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOSTABLE', 'ELATERIN'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOSTABLE', 'ELAINS'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOSTABLE', 'ELAIN'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOSTABLE', 'EINSTEINS'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOSTABLE', 'EINSTEIN'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOSTABLE', 'EBONISES'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOSTABLE', 'EBONISE'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOSTABLE', 'EBONIES'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOLABILE', 'ETNAS'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOLABILE', 'ETHENES'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOLABILE', 'ETHANOLS'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOLABILE', 'ETHANES'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOLABILE', 'ETHANALS'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOLABILE', 'ETESIANS'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOLABILE', 'ETESIAN'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOLABILE', 'ETERNISES'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOLABILE', 'ETERNISE'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOLABILE', 'ETERNALS'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOLABILE', 'ETERNALISES'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOLABILE', 'ETERNALISE'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOLABILE', 'ETALONS'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOLABILE', 'ESTRONES'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOLABILE', 'ESTRONE'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOLABILE', 'ESTRINS'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOLABILE', 'ESTRIN'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOLABILE', 'ESNES'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOLABILE', 'ESNE'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOLABILE', 'ESERINES'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOLABILE', 'ESERINE'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOLABILE', 'ERNS'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOLABILE', 'ERNES'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOLABILE', 'ERMINES'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOLABILE', 'EOSINS'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOLABILE', 'EOSINES'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOLABILE', 'EOSINE'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOLABILE', 'EOSIN'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOLABILE', 'EONS'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOLABILE', 'EONISMS'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOLABILE', 'EONISM'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOLABILE', 'ENTRIES'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOLABILE', 'ENTRESOLS'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOLABILE', 'ENTRESOL'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOLABILE', 'ENTRANTS'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOLABILE', 'ENTRAINS'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOLABILE', 'ENTRAILS'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOLABILE', 'ENTHRONES'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOLABILE', 'ENTHRALS'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOLABILE', 'ENTERTAINS'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOLABILE', 'ENTERONS'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOLABILE', 'ENTEROBIASIS'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOLABILE', 'ENTEROBIASES'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOLABILE', 'ENTENTES'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOLABILE', 'ENTASIS'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOLABILE', 'ENTASIAS'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOLABILE', 'ENTASIA'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOLABILE', 'ENTASES'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOLABILE', 'ENTAILS'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOLABILE', 'ENSNARLS'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOLABILE', 'ENSNARL'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOLABILE', 'ENSNARES'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOLABILE', 'ENSNARER'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOLABILE', 'ENSNARE'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOLABILE', 'ENSILES'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOLABILE', 'ENSILE'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOLABILE', 'ENSHRINES'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOLABILE', 'ENSHRINE'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOLABILE', 'ENS'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOLABILE', 'ENROLS'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOLABILE', 'ENROBES'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOLABILE', 'ENOSISES'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOLABILE', 'ENOSIS'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOLABILE', 'ENOLS'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOLABILE', 'ENOLASES'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOLABILE', 'ENOLASE'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOLABILE', 'ENISLES'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOLABILE', 'ENISLE'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOLABILE', 'ENATES'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOLABILE', 'ENABLES'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOLABILE', 'ELINTS'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOLABILE', 'ELIMINATES'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOLABILE', 'ELATERINS'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOLABILE', 'ELASTANES'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOLABILE', 'ELASTANE'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOLABILE', 'ELANS'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOLABILE', 'ELAINS'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOLABILE', 'EINSTEINS'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOLABILE', 'EINSTEIN'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOLABILE', 'EBONS'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOLABILE', 'EBONISES'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOLABILE', 'EBONISE'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOLABILE', 'EBONIES'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOHALINE', 'ESTABLISHES'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOHALINE', 'ESTABLISHER'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOHALINE', 'ESTABLISHABLE'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOHALINE', 'ESTABLISH'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOHALINE', 'EROSIBLE'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOHALINE', 'ERASABLE'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOHALINE', 'ENTEROBIASIS'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOHALINE', 'ENTEROBIASES'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOHALINE', 'ENROBES'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOHALINE', 'ENABLES'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOHALINE', 'ELABORATES'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOHALINE', 'EBONS'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOHALINE', 'EBONISES'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOHALINE', 'EBONISE'] leftovers set()
# Puzzle Solved! Depth =  2   ['THERMOHALINE', 'EBONIES'] leftovers set()
# Puzzle Solved! Depth =  2   ['TARNISHABLE', 'EONISMS'] leftovers set()
# Puzzle Solved! Depth =  2   ['TARNISHABLE', 'EONISM'] leftovers set()
# Puzzle Solved! Depth =  2   ['TARNISHABLE', 'ENORM'] leftovers set()
# Puzzle Solved! Depth =  2   ['ORIENTALISMS', 'STENOBATHS'] leftovers set()
# Puzzle Solved! Depth =  2   ['ORIENTALISMS', 'STENOBATH'] leftovers set()
# Puzzle Solved! Depth =  2   ['ORIENTALISMS', 'STABLISHES'] leftovers set()
# Puzzle Solved! Depth =  2   ['ORIENTALISMS', 'STABLISH'] leftovers set()
# Puzzle Solved! Depth =  2   ['ORIENTALISMS', 'SHINBONES'] leftovers set()
# Puzzle Solved! Depth =  2   ['ORIENTALISMS', 'SHINBONE'] leftovers set()
# Puzzle Solved! Depth =  2   ['ORIENTALISMS', 'SHIBAHS'] leftovers set()
# Puzzle Solved! Depth =  2   ['ORIENTALISMS', 'SHIBAH'] leftovers set()
# Puzzle Solved! Depth =  2   ['ORIENTALISMS', 'SHARABLE'] leftovers set()
# Puzzle Solved! Depth =  2   ['ORIENTALISMS', 'SAHIB'] leftovers set()
# Puzzle Solved! Depth =  2   ['ORIENTALISM', 'MIHRAB'] leftovers set()
# Puzzle Solved! Depth =  2   ['NONTERMINALS', 'STENOBATHS'] leftovers set()
# Puzzle Solved! Depth =  2   ['NONTERMINALS', 'STENOBATH'] leftovers set()
# Puzzle Solved! Depth =  2   ['NONTERMINALS', 'STABLISHES'] leftovers set()
# Puzzle Solved! Depth =  2   ['NONTERMINALS', 'STABLISH'] leftovers set()
# Puzzle Solved! Depth =  2   ['NONTERMINALS', 'SHINBONES'] leftovers set()
# Puzzle Solved! Depth =  2   ['NONTERMINALS', 'SHINBONE'] leftovers set()
# Puzzle Solved! Depth =  2   ['NONTERMINALS', 'SHIBAHS'] leftovers set()
# Puzzle Solved! Depth =  2   ['NONTERMINALS', 'SHIBAH'] leftovers set()
# Puzzle Solved! Depth =  2   ['NONTERMINALS', 'SHARABLE'] leftovers set()
# Puzzle Solved! Depth =  2   ['NONTERMINALS', 'SAHIB'] leftovers set()
# Puzzle Solved! Depth =  2   ['NEOLIBERALISMS', 'STRATHS'] leftovers set()
# Puzzle Solved! Depth =  2   ['NEOLIBERALISMS', 'STRATH'] leftovers set()
# Puzzle Solved! Depth =  2   ['NEOLIBERALISMS', 'STHENIAS'] leftovers set()
# Puzzle Solved! Depth =  2   ['NEOLIBERALISMS', 'STHENIA'] leftovers set()
# Puzzle Solved! Depth =  2   ['NEOLIBERALISMS', 'STENOHALINE'] leftovers set()
# Puzzle Solved! Depth =  2   ['NEOLIBERALISMS', 'STENOBATHS'] leftovers set()
# Puzzle Solved! Depth =  2   ['NEOLIBERALISMS', 'STENOBATH'] leftovers set()
# Puzzle Solved! Depth =  2   ['NEOLIBERALISMS', 'STASHES'] leftovers set()
# Puzzle Solved! Depth =  2   ['NEOLIBERALISMS', 'STASH'] leftovers set()
# Puzzle Solved! Depth =  2   ['NEOLIBERALISMS', 'STABLISHES'] leftovers set()
# Puzzle Solved! Depth =  2   ['NEOLIBERALISMS', 'STABLISH'] leftovers set()
# Puzzle Solved! Depth =  2   ['NEOLIBERALISMS', 'SNATHS'] leftovers set()
# Puzzle Solved! Depth =  2   ['NEOLIBERALISMS', 'SNATHES'] leftovers set()
# Puzzle Solved! Depth =  2   ['NEOLIBERALISMS', 'SNATHE'] leftovers set()
# Puzzle Solved! Depth =  2   ['NEOLIBERALISMS', 'SNATH'] leftovers set()
# Puzzle Solved! Depth =  2   ['NEOLIBERALISMS', 'SLOSHIEST'] leftovers set()
# Puzzle Solved! Depth =  2   ['NEOLIBERALISMS', 'SLATHER'] leftovers set()
# Puzzle Solved! Depth =  2   ['NEOLIBERALISMS', 'SHTETLS'] leftovers set()
# Puzzle Solved! Depth =  2   ['NEOLIBERALISMS', 'SHTETL'] leftovers set()
# Puzzle Solved! Depth =  2   ['NEOLIBERALISMS', 'SHTETELS'] leftovers set()
# Puzzle Solved! Depth =  2   ['NEOLIBERALISMS', 'SHTETEL'] leftovers set()
# Puzzle Solved! Depth =  2   ['NEOLIBERALISMS', 'SHORTS'] leftovers set()
# Puzzle Solved! Depth =  2   ['NEOLIBERALISMS', 'SHORTLISTS'] leftovers set()
# Puzzle Solved! Depth =  2   ['NEOLIBERALISMS', 'SHORTLIST'] leftovers set()
# Puzzle Solved! Depth =  2   ['NEOLIBERALISMS', 'SHORTHORNS'] leftovers set()
# Puzzle Solved! Depth =  2   ['NEOLIBERALISMS', 'SHORTHORN'] leftovers set()
# Puzzle Solved! Depth =  2   ['NEOLIBERALISMS', 'SHORTHAIR'] leftovers set()
# Puzzle Solved! Depth =  2   ['NEOLIBERALISMS', 'SHORTEST'] leftovers set()
# Puzzle Solved! Depth =  2   ['NEOLIBERALISMS', 'SHORTER'] leftovers set()
# Puzzle Solved! Depth =  2   ['NEOLIBERALISMS', 'SHORTENS'] leftovers set()
# Puzzle Solved! Depth =  2   ['NEOLIBERALISMS', 'SHORTENER'] leftovers set()
# Puzzle Solved! Depth =  2   ['NEOLIBERALISMS', 'SHORTEN'] leftovers set()
# Puzzle Solved! Depth =  2   ['NEOLIBERALISMS', 'SHORT'] leftovers set()
# Puzzle Solved! Depth =  2   ['NEOLIBERALISMS', 'SHOATS'] leftovers set()
# Puzzle Solved! Depth =  2   ['NEOLIBERALISMS', 'SHOAT'] leftovers set()
# Puzzle Solved! Depth =  2   ['NEOLIBERALISMS', 'SHOALIEST'] leftovers set()
# Puzzle Solved! Depth =  2   ['NEOLIBERALISMS', 'SHOALEST'] leftovers set()
# Puzzle Solved! Depth =  2   ['NEOLIBERALISMS', 'SHISTS'] leftovers set()
# Puzzle Solved! Depth =  2   ['NEOLIBERALISMS', 'SHIST'] leftovers set()
# Puzzle Solved! Depth =  2   ['NEOLIBERALISMS', 'SHIRTS'] leftovers set()
# Puzzle Solved! Depth =  2   ['NEOLIBERALISMS', 'SHIRT'] leftovers set()
# Puzzle Solved! Depth =  2   ['NEOLIBERALISMS', 'SHINIEST'] leftovers set()
# Puzzle Solved! Depth =  2   ['NEOLIBERALISMS', 'SHIEST'] leftovers set()
# Puzzle Solved! Depth =  2   ['NEOLIBERALISMS', 'SHENT'] leftovers set()
# Puzzle Solved! Depth =  2   ['NEOLIBERALISMS', 'SHELTERER'] leftovers set()
# Puzzle Solved! Depth =  2   ['NEOLIBERALISMS', 'SHELTER'] leftovers set()
# Puzzle Solved! Depth =  2   ['NEOLIBERALISMS', 'SHELTAS'] leftovers set()
# Puzzle Solved! Depth =  2   ['NEOLIBERALISMS', 'SHELTA'] leftovers set()
# Puzzle Solved! Depth =  2   ['NEOLIBERALISMS', 'SHAT'] leftovers set()
# Puzzle Solved! Depth =  2   ['NEOLIBERALISMS', 'SHASTAS'] leftovers set()
# Puzzle Solved! Depth =  2   ['NEOLIBERALISMS', 'SHASTA'] leftovers set()
# Puzzle Solved! Depth =  2   ['NEOLIBERALISMS', 'SHARIATS'] leftovers set()
# Puzzle Solved! Depth =  2   ['NEOLIBERALISMS', 'SHARIAT'] leftovers set()
# Puzzle Solved! Depth =  2   ['NEOLIBERALISMS', 'SHALT'] leftovers set()
# Puzzle Solved! Depth =  2   ['NEOLIBERALISMS', 'SHALIEST'] leftovers set()
# Puzzle Solved! Depth =  2   ['NEOLIBERALISM', 'MONTHS'] leftovers set()
# Puzzle Solved! Depth =  2   ['NEOLIBERALISM', 'MONTH'] leftovers set()
# Puzzle Solved! Depth =  2   ['NEOLIBERALISM', 'MISHANTER'] leftovers set()
# Puzzle Solved! Depth =  2   ['NEOLIBERALISM', 'MIRTHS'] leftovers set()
# Puzzle Solved! Depth =  2   ['NEOLIBERALISM', 'MIRTH'] leftovers set()
# Puzzle Solved! Depth =  2   ['LIBERTARIANISMS', 'STENOHALINE'] leftovers set()
# Puzzle Solved! Depth =  2   ['LIBERTARIANISMS', 'STENOBATHS'] leftovers set()
# Puzzle Solved! Depth =  2   ['LIBERTARIANISMS', 'STENOBATH'] leftovers set()
# Puzzle Solved! Depth =  2   ['LIBERTARIANISMS', 'SOHS'] leftovers set()
# Puzzle Solved! Depth =  2   ['LIBERTARIANISMS', 'SOH'] leftovers set()
# Puzzle Solved! Depth =  2   ['LIBERTARIANISMS', 'SLOSHIEST'] leftovers set()
# Puzzle Solved! Depth =  2   ['LIBERTARIANISMS', 'SLOSHIER'] leftovers set()
# Puzzle Solved! Depth =  2   ['LIBERTARIANISMS', 'SLOSHES'] leftovers set()
# Puzzle Solved! Depth =  2   ['LIBERTARIANISMS', 'SLOSH'] leftovers set()
# Puzzle Solved! Depth =  2   ['LIBERTARIANISMS', 'SHORTS'] leftovers set()
# Puzzle Solved! Depth =  2   ['LIBERTARIANISMS', 'SHORTLISTS'] leftovers set()
# Puzzle Solved! Depth =  2   ['LIBERTARIANISMS', 'SHORTLIST'] leftovers set()
# Puzzle Solved! Depth =  2   ['LIBERTARIANISMS', 'SHORTHORNS'] leftovers set()
# Puzzle Solved! Depth =  2   ['LIBERTARIANISMS', 'SHORTHORN'] leftovers set()
# Puzzle Solved! Depth =  2   ['LIBERTARIANISMS', 'SHORTHAIR'] leftovers set()
# Puzzle Solved! Depth =  2   ['LIBERTARIANISMS', 'SHORTEST'] leftovers set()
# Puzzle Solved! Depth =  2   ['LIBERTARIANISMS', 'SHORTER'] leftovers set()
# Puzzle Solved! Depth =  2   ['LIBERTARIANISMS', 'SHORTENS'] leftovers set()
# Puzzle Solved! Depth =  2   ['LIBERTARIANISMS', 'SHORTENER'] leftovers set()
# Puzzle Solved! Depth =  2   ['LIBERTARIANISMS', 'SHORTEN'] leftovers set()
# Puzzle Solved! Depth =  2   ['LIBERTARIANISMS', 'SHORT'] leftovers set()
# Puzzle Solved! Depth =  2   ['LIBERTARIANISMS', 'SHORN'] leftovers set()
# Puzzle Solved! Depth =  2   ['LIBERTARIANISMS', 'SHORLS'] leftovers set()
# Puzzle Solved! Depth =  2   ['LIBERTARIANISMS', 'SHORL'] leftovers set()
# Puzzle Solved! Depth =  2   ['LIBERTARIANISMS', 'SHORES'] leftovers set()
# Puzzle Solved! Depth =  2   ['LIBERTARIANISMS', 'SHORELINES'] leftovers set()
# Puzzle Solved! Depth =  2   ['LIBERTARIANISMS', 'SHORELINE'] leftovers set()
# Puzzle Solved! Depth =  2   ['LIBERTARIANISMS', 'SHORE'] leftovers set()
# Puzzle Solved! Depth =  2   ['LIBERTARIANISMS', 'SHORANS'] leftovers set()
# Puzzle Solved! Depth =  2   ['LIBERTARIANISMS', 'SHORAN'] leftovers set()
# Puzzle Solved! Depth =  2   ['LIBERTARIANISMS', 'SHONE'] leftovers set()
# Puzzle Solved! Depth =  2   ['LIBERTARIANISMS', 'SHOLOMS'] leftovers set()
# Puzzle Solved! Depth =  2   ['LIBERTARIANISMS', 'SHOLOM'] leftovers set()
# Puzzle Solved! Depth =  2   ['LIBERTARIANISMS', 'SHOESHINES'] leftovers set()
# Puzzle Solved! Depth =  2   ['LIBERTARIANISMS', 'SHOESHINE'] leftovers set()
# Puzzle Solved! Depth =  2   ['LIBERTARIANISMS', 'SHOES'] leftovers set()
# Puzzle Solved! Depth =  2   ['LIBERTARIANISMS', 'SHOER'] leftovers set()
# Puzzle Solved! Depth =  2   ['LIBERTARIANISMS', 'SHOEHORNS'] leftovers set()
# Puzzle Solved! Depth =  2   ['LIBERTARIANISMS', 'SHOEHORN'] leftovers set()
# Puzzle Solved! Depth =  2   ['LIBERTARIANISMS', 'SHOE'] leftovers set()
# Puzzle Solved! Depth =  2   ['LIBERTARIANISMS', 'SHOATS'] leftovers set()
# Puzzle Solved! Depth =  2   ['LIBERTARIANISMS', 'SHOAT'] leftovers set()
# Puzzle Solved! Depth =  2   ['LIBERTARIANISMS', 'SHOALS'] leftovers set()
# Puzzle Solved! Depth =  2   ['LIBERTARIANISMS', 'SHOALIEST'] leftovers set()
# Puzzle Solved! Depth =  2   ['LIBERTARIANISMS', 'SHOALIER'] leftovers set()
# Puzzle Solved! Depth =  2   ['LIBERTARIANISMS', 'SHOALEST'] leftovers set()
# Puzzle Solved! Depth =  2   ['LIBERTARIANISMS', 'SHOALER'] leftovers set()
# Puzzle Solved! Depth =  2   ['LIBERTARIANISMS', 'SHOAL'] leftovers set()
# Puzzle Solved! Depth =  2   ['LIBERTARIANISMS', 'SHO'] leftovers set()
# Puzzle Solved! Depth =  2   ['LIBERTARIANISMS', 'SHMOES'] leftovers set()
# Puzzle Solved! Depth =  2   ['LIBERTARIANISMS', 'SHMOE'] leftovers set()
# Puzzle Solved! Depth =  2   ['LIBERTARIANISMS', 'SHMO'] leftovers set()
# Puzzle Solved! Depth =  2   ['LIBERTARIANISMS', 'SHINOLAS'] leftovers set()
# Puzzle Solved! Depth =  2   ['LIBERTARIANISMS', 'SHINOLA'] leftovers set()
# Puzzle Solved! Depth =  2   ['LIBERTARIANISMS', 'SHINBONES'] leftovers set()
# Puzzle Solved! Depth =  2   ['LIBERTARIANISMS', 'SHINBONE'] leftovers set()
# Puzzle Solved! Depth =  2   ['LIBERTARIANISMS', 'SHEROES'] leftovers set()
# Puzzle Solved! Depth =  2   ['LIBERTARIANISMS', 'SHERO'] leftovers set()
# Puzzle Solved! Depth =  2   ['LIBERTARIANISMS', 'SHEOLS'] leftovers set()
# Puzzle Solved! Depth =  2   ['LIBERTARIANISMS', 'SHEOL'] leftovers set()
# Puzzle Solved! Depth =  2   ['LIBERTARIANISMS', 'SHALOMS'] leftovers set()
# Puzzle Solved! Depth =  2   ['LIBERTARIANISMS', 'SHALOM'] leftovers set()
# Puzzle Solved! Depth =  2   ['LIBERTARIANISM', 'MOSHES'] leftovers set()
# Puzzle Solved! Depth =  2   ['LIBERTARIANISM', 'MOSHER'] leftovers set()
# Puzzle Solved! Depth =  2   ['LIBERTARIANISM', 'MOSH'] leftovers set()
# Puzzle Solved! Depth =  2   ['LIBERTARIANISM', 'MORISH'] leftovers set()
# Puzzle Solved! Depth =  2   ['LIBERTARIANISM', 'MOREISH'] leftovers set()
# Puzzle Solved! Depth =  2   ['LIBERTARIANISM', 'MONTHS'] leftovers set()
# Puzzle Solved! Depth =  2   ['LIBERTARIANISM', 'MONTH'] leftovers set()
# Puzzle Solved! Depth =  2   ['LIBERTARIANISM', 'MONISHES'] leftovers set()
# Puzzle Solved! Depth =  2   ['LIBERTARIANISM', 'MONISH'] leftovers set()
# Puzzle Solved! Depth =  2   ['LIBERTARIANISM', 'MOHOS'] leftovers set()
# Puzzle Solved! Depth =  2   ['LIBERTARIANISM', 'MOHO'] leftovers set()
# Puzzle Solved! Depth =  2   ['LIBERTARIANISM', 'MOHELS'] leftovers set()
# Puzzle Solved! Depth =  2   ['LIBERTARIANISM', 'MOHELIM'] leftovers set()
# Puzzle Solved! Depth =  2   ['LIBERTARIANISM', 'MOHEL'] leftovers set()
# Puzzle Solved! Depth =  2   ['LIBERTARIANISM', 'MOHALIM'] leftovers set()
# Puzzle Solved! Depth =  2   ['LIBERTARIANISM', 'MOHAIR'] leftovers set()
# Puzzle Solved! Depth =  2   ['LIBERTARIANISM', 'MISHMOSHES'] leftovers set()
# Puzzle Solved! Depth =  2   ['LIBERTARIANISM', 'MISHMOSH'] leftovers set()
# Puzzle Solved! Depth =  2   ['LIBERTARIANISM', 'MHOS'] leftovers set()
# Puzzle Solved! Depth =  2   ['LIBERTARIANISM', 'MHO'] leftovers set()
# Puzzle Solved! Depth =  2   ['TRINOMIALS', 'STENOBATHS'] leftovers set()
# Puzzle Solved! Depth =  2   ['TRINOMIALS', 'STENOBATH'] leftovers set()
# Puzzle Solved! Depth =  2   ['TRINOMIALS', 'STABLISHES'] leftovers set()
# Puzzle Solved! Depth =  2   ['TRINOMIALS', 'SHINBONES'] leftovers set()
# Puzzle Solved! Depth =  2   ['TRINOMIALS', 'SHINBONE'] leftovers set()
# Puzzle Solved! Depth =  2   ['TRINOMIALS', 'SHARABLE'] leftovers set()
# Puzzle Solved! Depth =  2   ['THROMBINS', 'STRAINABLE'] leftovers set()
# Puzzle Solved! Depth =  2   ['THROMBINS', 'STERNAL'] leftovers set()
# Puzzle Solved! Depth =  2   ['THROMBINS', 'STERILANTS'] leftovers set()
# Puzzle Solved! Depth =  2   ['THROMBINS', 'STERILANT'] leftovers set()
# Puzzle Solved! Depth =  2   ['THROMBINS', 'STENOHALINE'] leftovers set()
# Puzzle Solved! Depth =  2   ['THROMBINS', 'STELAR'] leftovers set()
# Puzzle Solved! Depth =  2   ['THROMBINS', 'STELAI'] leftovers set()
# Puzzle Solved! Depth =  2   ['THROMBINS', 'STELA'] leftovers set()
# Puzzle Solved! Depth =  2   ['THROMBINS', 'STATELIEST'] leftovers set()
# Puzzle Solved! Depth =  2   ['THROMBINS', 'STATELIER'] leftovers set()
# Puzzle Solved! Depth =  2   ['THROMBINS', 'STATELETS'] leftovers set()
# Puzzle Solved! Depth =  2   ['THROMBINS', 'STATELET'] leftovers set()
# Puzzle Solved! Depth =  2   ['THROMBINS', 'STATABLE'] leftovers set()
# Puzzle Solved! Depth =  2   ['THROMBINS', 'STARTLES'] leftovers set()
# Puzzle Solved! Depth =  2   ['THROMBINS', 'STARTLER'] leftovers set()
# Puzzle Solved! Depth =  2   ['THROMBINS', 'STARTLE'] leftovers set()
# Puzzle Solved! Depth =  2   ['THROMBINS', 'STARLETS'] leftovers set()
# Puzzle Solved! Depth =  2   ['THROMBINS', 'STARLET'] leftovers set()
# Puzzle Solved! Depth =  2   ['THROMBINS', 'STALEST'] leftovers set()
# Puzzle Solved! Depth =  2   ['THROMBINS', 'STALES'] leftovers set()
# Puzzle Solved! Depth =  2   ['THROMBINS', 'STALER'] leftovers set()
# Puzzle Solved! Depth =  2   ['THROMBINS', 'STALE'] leftovers set()
# Puzzle Solved! Depth =  2   ['THROMBINS', 'STAINABLE'] leftovers set()
# Puzzle Solved! Depth =  2   ['THROMBINS', 'STABLISHES'] leftovers set()
# Puzzle Solved! Depth =  2   ['THROMBINS', 'STABLEST'] leftovers set()
# Puzzle Solved! Depth =  2   ['THROMBINS', 'STABLES'] leftovers set()
# Puzzle Solved! Depth =  2   ['THROMBINS', 'STABLER'] leftovers set()
# Puzzle Solved! Depth =  2   ['THROMBINS', 'STABLE'] leftovers set()
# Puzzle Solved! Depth =  2   ['THROMBINS', 'STABILISES'] leftovers set()
# Puzzle Solved! Depth =  2   ['THROMBINS', 'STABILISER'] leftovers set()
# Puzzle Solved! Depth =  2   ['THROMBINS', 'STABILISE'] leftovers set()
# Puzzle Solved! Depth =  2   ['THROMBINS', 'STABILES'] leftovers set()
# Puzzle Solved! Depth =  2   ['THROMBINS', 'STABILE'] leftovers set()
# Puzzle Solved! Depth =  2   ['THROMBINS', 'SORTABLE'] leftovers set()
# Puzzle Solved! Depth =  2   ['THROMBINS', 'SOLERAS'] leftovers set()
# Puzzle Solved! Depth =  2   ['THROMBINS', 'SOLERA'] leftovers set()
# Puzzle Solved! Depth =  2   ['THROMBINS', 'SOLATES'] leftovers set()
# Puzzle Solved! Depth =  2   ['THROMBINS', 'SOLATE'] leftovers set()
# Puzzle Solved! Depth =  2   ['THROMBINS', 'SOLARISES'] leftovers set()
# Puzzle Solved! Depth =  2   ['THROMBINS', 'SOLARISE'] leftovers set()
# Puzzle Solved! Depth =  2   ['THROMBINS', 'SOLANINES'] leftovers set()
# Puzzle Solved! Depth =  2   ['THROMBINS', 'SOLANINE'] leftovers set()
# Puzzle Solved! Depth =  2   ['THROMBINS', 'SNARLIEST'] leftovers set()
# Puzzle Solved! Depth =  2   ['THROMBINS', 'SNARLIER'] leftovers set()
# Puzzle Solved! Depth =  2   ['THROMBINS', 'SNARLER'] leftovers set()
# Puzzle Solved! Depth =  2   ['THROMBINS', 'SLATHER'] leftovers set()
# Puzzle Solved! Depth =  2   ['THROMBINS', 'SLATES'] leftovers set()
# Puzzle Solved! Depth =  2   ['THROMBINS', 'SLATER'] leftovers set()
# Puzzle Solved! Depth =  2   ['THROMBINS', 'SLATE'] leftovers set()
# Puzzle Solved! Depth =  2   ['THROMBINS', 'SLASHES'] leftovers set()
# Puzzle Solved! Depth =  2   ['THROMBINS', 'SLASHER'] leftovers set()
# Puzzle Solved! Depth =  2   ['THROMBINS', 'SLAINTE'] leftovers set()
# Puzzle Solved! Depth =  2   ['THROMBINS', 'SILESIAS'] leftovers set()
# Puzzle Solved! Depth =  2   ['THROMBINS', 'SILESIA'] leftovers set()
# Puzzle Solved! Depth =  2   ['THROMBINS', 'SILANES'] leftovers set()
# Puzzle Solved! Depth =  2   ['THROMBINS', 'SILANE'] leftovers set()
# Puzzle Solved! Depth =  2   ['THROMBINS', 'SIBILATES'] leftovers set()
# Puzzle Solved! Depth =  2   ['THROMBINS', 'SIBILATE'] leftovers set()
# Puzzle Solved! Depth =  2   ['THROMBINS', 'SHOALIEST'] leftovers set()
# Puzzle Solved! Depth =  2   ['THROMBINS', 'SHOALIER'] leftovers set()
# Puzzle Solved! Depth =  2   ['THROMBINS', 'SHOALEST'] leftovers set()
# Puzzle Solved! Depth =  2   ['THROMBINS', 'SHOALER'] leftovers set()
# Puzzle Solved! Depth =  2   ['THROMBINS', 'SHELTAS'] leftovers set()
# Puzzle Solved! Depth =  2   ['THROMBINS', 'SHELTA'] leftovers set()
# Puzzle Solved! Depth =  2   ['THROMBINS', 'SHEILAS'] leftovers set()
# Puzzle Solved! Depth =  2   ['THROMBINS', 'SHEILA'] leftovers set()
# Puzzle Solved! Depth =  2   ['THROMBINS', 'SHARABLE'] leftovers set()
# Puzzle Solved! Depth =  2   ['THROMBINS', 'SHALIEST'] leftovers set()
# Puzzle Solved! Depth =  2   ['THROMBINS', 'SHALIER'] leftovers set()
# Puzzle Solved! Depth =  2   ['THROMBINS', 'SHALES'] leftovers set()
# Puzzle Solved! Depth =  2   ['THROMBINS', 'SHALE'] leftovers set()
# Puzzle Solved! Depth =  2   ['THROMBINS', 'SETAL'] leftovers set()
# Puzzle Solved! Depth =  2   ['THROMBINS', 'SERTRALINES'] leftovers set()
# Puzzle Solved! Depth =  2   ['THROMBINS', 'SERTRALINE'] leftovers set()
# Puzzle Solved! Depth =  2   ['THROMBINS', 'SEROSAL'] leftovers set()
# Puzzle Solved! Depth =  2   ['THROMBINS', 'SERIALS'] leftovers set()
# Puzzle Solved! Depth =  2   ['THROMBINS', 'SERIALISTS'] leftovers set()
# Puzzle Solved! Depth =  2   ['THROMBINS', 'SERIALIST'] leftovers set()
# Puzzle Solved! Depth =  2   ['THROMBINS', 'SERIALISMS'] leftovers set()
# Puzzle Solved! Depth =  2   ['THROMBINS', 'SERIALISM'] leftovers set()
# Puzzle Solved! Depth =  2   ['THROMBINS', 'SERIALISES'] leftovers set()
# Puzzle Solved! Depth =  2   ['THROMBINS', 'SERIALISE'] leftovers set()
# Puzzle Solved! Depth =  2   ['THROMBINS', 'SERIAL'] leftovers set()
# Puzzle Solved! Depth =  2   ['THROMBINS', 'SERAL'] leftovers set()
# Puzzle Solved! Depth =  2   ['THROMBINS', 'SERAILS'] leftovers set()
# Puzzle Solved! Depth =  2   ['THROMBINS', 'SERAIL'] leftovers set()
# Puzzle Solved! Depth =  2   ['THROMBINS', 'SENSORIAL'] leftovers set()
# Puzzle Solved! Depth =  2   ['THROMBINS', 'SENSIBILIA'] leftovers set()
# Puzzle Solved! Depth =  2   ['THROMBINS', 'SELENATES'] leftovers set()
# Puzzle Solved! Depth =  2   ['THROMBINS', 'SELENATE'] leftovers set()
# Puzzle Solved! Depth =  2   ['THROMBINS', 'SELAHS'] leftovers set()
# Puzzle Solved! Depth =  2   ['THROMBINS', 'SELAH'] leftovers set()
# Puzzle Solved! Depth =  2   ['THROMBINS', 'SEISABLE'] leftovers set()
# Puzzle Solved! Depth =  2   ['THROMBINS', 'SALTEST'] leftovers set()
# Puzzle Solved! Depth =  2   ['THROMBINS', 'SALTERNS'] leftovers set()
# Puzzle Solved! Depth =  2   ['THROMBINS', 'SALTERN'] leftovers set()
# Puzzle Solved! Depth =  2   ['THROMBINS', 'SALTERIES'] leftovers set()
# Puzzle Solved! Depth =  2   ['THROMBINS', 'SALTER'] leftovers set()
# Puzzle Solved! Depth =  2   ['THROMBINS', 'SALINES'] leftovers set()
# Puzzle Solved! Depth =  2   ['THROMBINS', 'SALINE'] leftovers set()
# Puzzle Solved! Depth =  2   ['THROMBINS', 'SALIENTS'] leftovers set()
# Puzzle Solved! Depth =  2   ['THROMBINS', 'SALIENT'] leftovers set()
# Puzzle Solved! Depth =  2   ['THROMBINS', 'SALES'] leftovers set()
# Puzzle Solved! Depth =  2   ['THROMBINS', 'SALE'] leftovers set()
# Puzzle Solved! Depth =  2   ['THROMBINS', 'SALARIES'] leftovers set()
# Puzzle Solved! Depth =  2   ['THROMBINS', 'SALABLE'] leftovers set()
# Puzzle Solved! Depth =  2   ['THROMBINS', 'SAINTLIEST'] leftovers set()
# Puzzle Solved! Depth =  2   ['THROMBINS', 'SAINTLIER'] leftovers set()
# Puzzle Solved! Depth =  2   ['THROMBINS', 'SAILER'] leftovers set()
# Puzzle Solved! Depth =  2   ['THROMBINS', 'SAILBOATER'] leftovers set()
# Puzzle Solved! Depth =  2   ['THROMBINS', 'SAILABLE'] leftovers set()
# Puzzle Solved! Depth =  2   ['THROMBINS', 'SABLEST'] leftovers set()
# Puzzle Solved! Depth =  2   ['THROMBINS', 'SABLES'] leftovers set()
# Puzzle Solved! Depth =  2   ['THROMBINS', 'SABLER'] leftovers set()
# Puzzle Solved! Depth =  2   ['THROMBINS', 'SABLE'] leftovers set()
# Puzzle Solved! Depth =  2   ['THORNTAILS', 'SOMBEREST'] leftovers set()
# Puzzle Solved! Depth =  2   ['THORNTAILS', 'SOMBERER'] leftovers set()
# Puzzle Solved! Depth =  2   ['THORNTAILS', 'SOMBER'] leftovers set()
# Puzzle Solved! Depth =  2   ['TERMINALS', 'STENOBATHS'] leftovers set()
# Puzzle Solved! Depth =  2   ['TERMINALS', 'STENOBATH'] leftovers set()
# Puzzle Solved! Depth =  2   ['TERMINALS', 'SHINBONES'] leftovers set()
# Puzzle Solved! Depth =  2   ['TERMINALS', 'SHINBONE'] leftovers set()
# Puzzle Solved! Depth =  2   ['TERMINABLE', 'ETHOSES'] leftovers set()
# Puzzle Solved! Depth =  2   ['TERMINABLE', 'ETHOS'] leftovers set()
# Puzzle Solved! Depth =  2   ['TERMINABLE', 'ETHANOLS'] leftovers set()
# Puzzle Solved! Depth =  2   ['TERMINABLE', 'ENTHRONES'] leftovers set()
# Puzzle Solved! Depth =  2   ['TABORINES', 'SHOLOMS'] leftovers set()
# Puzzle Solved! Depth =  2   ['TABORINES', 'SHOLOM'] leftovers set()
# Puzzle Solved! Depth =  2   ['TABORINES', 'SHALOMS'] leftovers set()
# Puzzle Solved! Depth =  2   ['TABORINES', 'SHALOM'] leftovers set()
# Puzzle Solved! Depth =  2   ['REOBTAINS', 'SHOLOMS'] leftovers set()
# Puzzle Solved! Depth =  2   ['REOBTAINS', 'SHOLOM'] leftovers set()
# Puzzle Solved! Depth =  2   ['REOBTAINS', 'SHALOMS'] leftovers set()
# Puzzle Solved! Depth =  2   ['REOBTAINS', 'SHALOM'] leftovers set()
# Puzzle Solved! Depth =  2   ['RENOMINATES', 'STABLISHES'] leftovers set()
# Puzzle Solved! Depth =  2   ['RENOMINATES', 'STABLISH'] leftovers set()
# Puzzle Solved! Depth =  2   ['RENOMINATES', 'SHARABLE'] leftovers set()
# Puzzle Solved! Depth =  2   ['ORIENTALIST', 'THROMBOSIS'] leftovers set()
# Puzzle Solved! Depth =  2   ['ORIENTALIST', 'THROMBOSES'] leftovers set()
# Puzzle Solved! Depth =  2   ['ORIENTALIST', 'THROMBOSE'] leftovers set()
# Puzzle Solved! Depth =  2   ['ORIENTALIST', 'THROMBINS'] leftovers set()
# Puzzle Solved! Depth =  2   ['ORIENTALIST', 'THROMBIN'] leftovers set()
# Puzzle Solved! Depth =  2   ['ORIENTALIST', 'THROMBI'] leftovers set()
# Puzzle Solved! Depth =  2   ['ORIENTALIST', 'THIMBLES'] leftovers set()
# Puzzle Solved! Depth =  2   ['ORIENTALIST', 'THIMBLE'] leftovers set()
# Puzzle Solved! Depth =  2   ['ORIENTALIST', 'THERMOSTABLE'] leftovers set()
# Puzzle Solved! Depth =  2   ['ORIENTALIST', 'THERMOLABILE'] leftovers set()
# Puzzle Solved! Depth =  2   ['NONMONETARISTS', 'STABLISHES'] leftovers set()
# Puzzle Solved! Depth =  2   ['NONMONETARISTS', 'STABLISH'] leftovers set()
# Puzzle Solved! Depth =  2   ['NONMONETARISTS', 'SHARABLE'] leftovers set()
# Puzzle Solved! Depth =  2   ['NONMONETARIST', 'THIMBLES'] leftovers set()
# Puzzle Solved! Depth =  2   ['NONMONETARIST', 'THIMBLE'] leftovers set()
# Puzzle Solved! Depth =  2   ['NONMONETARIST', 'THERMOSTABLE'] leftovers set()
# Puzzle Solved! Depth =  2   ['NONMONETARIST', 'THERMOLABILE'] leftovers set()
# Puzzle Solved! Depth =  2   ['NONMONETARIST', 'TARNISHABLE'] leftovers set()
# Puzzle Solved! Depth =  2   ['NOMINATABLE', 'ETHERISH'] leftovers set()
# Puzzle Solved! Depth =  2   ['NOMINATABLE', 'ETHERISES'] leftovers set()
# Puzzle Solved! Depth =  2   ['NOMINATABLE', 'ETHERISE'] leftovers set()
# Puzzle Solved! Depth =  2   ['NOMINATABLE', 'ESTABLISHER'] leftovers set()
# Puzzle Solved! Depth =  2   ['NOMINATABLE', 'ERETHISMS'] leftovers set()
# Puzzle Solved! Depth =  2   ['NOMINATABLE', 'ERETHISM'] leftovers set()
# Puzzle Solved! Depth =  2   ['NOMINATABLE', 'ENTHRONES'] leftovers set()
# Puzzle Solved! Depth =  2   ['NOMINATABLE', 'ENTHRALS'] leftovers set()
# Puzzle Solved! Depth =  2   ['NOMINATABLE', 'ENSHRINES'] leftovers set()
# Puzzle Solved! Depth =  2   ['NOMINATABLE', 'ENSHRINE'] leftovers set()
# Puzzle Solved! Depth =  2   ['MONETARISTS', 'STABLISHES'] leftovers set()
# Puzzle Solved! Depth =  2   ['MONETARISTS', 'STABLISH'] leftovers set()
# Puzzle Solved! Depth =  2   ['MONETARISTS', 'SHARABLE'] leftovers set()
# Puzzle Solved! Depth =  2   ['MONETARIST', 'THIMBLES'] leftovers set()
# Puzzle Solved! Depth =  2   ['MONETARIST', 'THIMBLE'] leftovers set()
# Puzzle Solved! Depth =  2   ['MONETARIST', 'THERMOSTABLE'] leftovers set()
# Puzzle Solved! Depth =  2   ['MONETARIST', 'THERMOLABILE'] leftovers set()
# Puzzle Solved! Depth =  2   ['MONETARIST', 'TARNISHABLE'] leftovers set()
# Puzzle Solved! Depth =  2   ['MONETARISMS', 'STABLISHES'] leftovers set()
# Puzzle Solved! Depth =  2   ['MONETARISMS', 'STABLISH'] leftovers set()
# Puzzle Solved! Depth =  2   ['MONETARISMS', 'SHARABLE'] leftovers set()
# Puzzle Solved! Depth =  2   ['MONASTERIES', 'STABLISHES'] leftovers set()
# Puzzle Solved! Depth =  2   ['MONASTERIES', 'STABLISH'] leftovers set()
# Puzzle Solved! Depth =  2   ['MONASTERIES', 'SHARABLE'] leftovers set()
# Puzzle Solved! Depth =  2   ['MISTRANSLATES', 'STENOBATHS'] leftovers set()
# Puzzle Solved! Depth =  2   ['MISTRANSLATES', 'STENOBATH'] leftovers set()
# Puzzle Solved! Depth =  2   ['MISTRANSLATES', 'SHINBONES'] leftovers set()
# Puzzle Solved! Depth =  2   ['MISTRANSLATES', 'SHINBONE'] leftovers set()
# Puzzle Solved! Depth =  2   ['MISHANTER', 'ROBLES'] leftovers set()
# Puzzle Solved! Depth =  2   ['MISHANTER', 'ROBLE'] leftovers set()
# Puzzle Solved! Depth =  2   ['MISHANTER', 'ROBALOS'] leftovers set()
# Puzzle Solved! Depth =  2   ['MISHANTER', 'ROBALO'] leftovers set()
# Puzzle Solved! Depth =  2   ['MISHANTER', 'RETABLOS'] leftovers set()
# Puzzle Solved! Depth =  2   ['MISHANTER', 'RETABLO'] leftovers set()
# Puzzle Solved! Depth =  2   ['LIBERTARIANS', 'SHOLOMS'] leftovers set()
# Puzzle Solved! Depth =  2   ['LIBERTARIANS', 'SHOLOM'] leftovers set()
# Puzzle Solved! Depth =  2   ['LIBERTARIANS', 'SHMOES'] leftovers set()
# Puzzle Solved! Depth =  2   ['LIBERTARIANS', 'SHMOE'] leftovers set()
# Puzzle Solved! Depth =  2   ['LIBERTARIANS', 'SHMO'] leftovers set()
# Puzzle Solved! Depth =  2   ['LIBERTARIANS', 'SHALOMS'] leftovers set()
# Puzzle Solved! Depth =  2   ['LIBERTARIANS', 'SHALOM'] leftovers set()
# Puzzle Solved! Depth =  2   ['INTERTERMINALS', 'STENOBATHS'] leftovers set()
# Puzzle Solved! Depth =  2   ['INTERTERMINALS', 'STENOBATH'] leftovers set()
# Puzzle Solved! Depth =  2   ['INTERTERMINALS', 'SHINBONES'] leftovers set()
# Puzzle Solved! Depth =  2   ['INTERTERMINALS', 'SHINBONE'] leftovers set()
# Puzzle Solved! Depth =  2   ['INTERMINABLE', 'ETHOSES'] leftovers set()
# Puzzle Solved! Depth =  2   ['INTERMINABLE', 'ETHOS'] leftovers set()
# Puzzle Solved! Depth =  2   ['INTERMINABLE', 'ETHANOLS'] leftovers set()
# Puzzle Solved! Depth =  2   ['INTERMINABLE', 'ENTHRONES'] leftovers set()
# Puzzle Solved! Depth =  2   ['HORTENSIA', 'ANABOLISMS'] leftovers set()
# Puzzle Solved! Depth =  2   ['HORTENSIA', 'ANABOLISM'] leftovers set()
# Puzzle Solved! Depth =  2   ['HORTENSIA', 'ALBINISMS'] leftovers set()
# Puzzle Solved! Depth =  2   ['HORTENSIA', 'ALBINISM'] leftovers set()
# Puzzle Solved! Depth =  2   ['HORTENSIA', 'AIRMOBILE'] leftovers set()
# Puzzle Solved! Depth =  2   ['HORTENSIA', 'ABOMINABLE'] leftovers set()
# Puzzle Solved! Depth =  2   ['HORTENSIA', 'ABLEISMS'] leftovers set()
# Puzzle Solved! Depth =  2   ['HORTENSIA', 'ABLEISM'] leftovers set()
# Puzzle Solved! Depth =  2   ['HORNTAILS', 'SOMBEREST'] leftovers set()
# Puzzle Solved! Depth =  2   ['HORNTAILS', 'SOMBERER'] leftovers set()
# Puzzle Solved! Depth =  2   ['HORNTAILS', 'SOMBER'] leftovers set()
# Puzzle Solved! Depth =  2   ['HIBERNATES', 'SOMNOLENT'] leftovers set()
# Puzzle Solved! Depth =  2   ['HIBERNATES', 'SOLARISMS'] leftovers set()
# Puzzle Solved! Depth =  2   ['HIBERNATES', 'SOLARISM'] leftovers set()
# Puzzle Solved! Depth =  2   ['HIBERNATES', 'SMOLTS'] leftovers set()
# Puzzle Solved! Depth =  2   ['HIBERNATES', 'SMOLT'] leftovers set()
# Puzzle Solved! Depth =  2   ['HIBERNATES', 'SLOMOS'] leftovers set()
# Puzzle Solved! Depth =  2   ['HIBERNATES', 'SLOMO'] leftovers set()
# Puzzle Solved! Depth =  2   ['HIBERNATES', 'SLALOMS'] leftovers set()
# Puzzle Solved! Depth =  2   ['HIBERNATES', 'SLALOMISTS'] leftovers set()
# Puzzle Solved! Depth =  2   ['HIBERNATES', 'SLALOMIST'] leftovers set()
# Puzzle Solved! Depth =  2   ['HIBERNATES', 'SLALOM'] leftovers set()
# Puzzle Solved! Depth =  2   ['HIBERNATES', 'SIMOLEONS'] leftovers set()
# Puzzle Solved! Depth =  2   ['HIBERNATES', 'SIMOLEON'] leftovers set()
# Puzzle Solved! Depth =  2   ['HIBERNATES', 'SHOLOMS'] leftovers set()
# Puzzle Solved! Depth =  2   ['HIBERNATES', 'SHOLOM'] leftovers set()
# Puzzle Solved! Depth =  2   ['HIBERNATES', 'SHALOMS'] leftovers set()
# Puzzle Solved! Depth =  2   ['HIBERNATES', 'SHALOM'] leftovers set()
# Puzzle Solved! Depth =  2   ['HIBERNATES', 'SALMONS'] leftovers set()
# Puzzle Solved! Depth =  2   ['HIBERNATES', 'SALMON'] leftovers set()
# Puzzle Solved! Depth =  2   ['HETERONOMIES', 'STROBILAR'] leftovers set()
# Puzzle Solved! Depth =  2   ['HETERONOMIES', 'STROBILA'] leftovers set()
# Puzzle Solved! Depth =  2   ['HETERONOMIES', 'STRAINABLE'] leftovers set()
# Puzzle Solved! Depth =  2   ['HETERONOMIES', 'STATABLE'] leftovers set()
# Puzzle Solved! Depth =  2   ['HETERONOMIES', 'STAINABLE'] leftovers set()
# Puzzle Solved! Depth =  2   ['HETERONOMIES', 'STABLISHES'] leftovers set()
# Puzzle Solved! Depth =  2   ['HETERONOMIES', 'STABLISH'] leftovers set()
# Puzzle Solved! Depth =  2   ['HETERONOMIES', 'STABLEST'] leftovers set()
# Puzzle Solved! Depth =  2   ['HETERONOMIES', 'STABLES'] leftovers set()
# Puzzle Solved! Depth =  2   ['HETERONOMIES', 'STABLER'] leftovers set()
# Puzzle Solved! Depth =  2   ['HETERONOMIES', 'STABLE'] leftovers set()
# Puzzle Solved! Depth =  2   ['HETERONOMIES', 'STABILISES'] leftovers set()
# Puzzle Solved! Depth =  2   ['HETERONOMIES', 'STABILISER'] leftovers set()
# Puzzle Solved! Depth =  2   ['HETERONOMIES', 'STABILISE'] leftovers set()
# Puzzle Solved! Depth =  2   ['HETERONOMIES', 'STABILES'] leftovers set()
# Puzzle Solved! Depth =  2   ['HETERONOMIES', 'STABILE'] leftovers set()
# Puzzle Solved! Depth =  2   ['HETERONOMIES', 'SORTABLE'] leftovers set()
# Puzzle Solved! Depth =  2   ['HETERONOMIES', 'SLAB'] leftovers set()
# Puzzle Solved! Depth =  2   ['HETERONOMIES', 'SIBILATES'] leftovers set()
# Puzzle Solved! Depth =  2   ['HETERONOMIES', 'SIBILATE'] leftovers set()
# Puzzle Solved! Depth =  2   ['HETERONOMIES', 'SIBILANTS'] leftovers set()
# Puzzle Solved! Depth =  2   ['HETERONOMIES', 'SIBILANT'] leftovers set()
# Puzzle Solved! Depth =  2   ['HETERONOMIES', 'SHARABLE'] leftovers set()
# Puzzle Solved! Depth =  2   ['HETERONOMIES', 'SENSIBILIA'] leftovers set()
# Puzzle Solved! Depth =  2   ['HETERONOMIES', 'SEISABLE'] leftovers set()
# Puzzle Solved! Depth =  2   ['HETERONOMIES', 'SALABLE'] leftovers set()
# Puzzle Solved! Depth =  2   ['HETERONOMIES', 'SAILBOATS'] leftovers set()
# Puzzle Solved! Depth =  2   ['HETERONOMIES', 'SAILBOATER'] leftovers set()
# Puzzle Solved! Depth =  2   ['HETERONOMIES', 'SAILBOAT'] leftovers set()
# Puzzle Solved! Depth =  2   ['HETERONOMIES', 'SAILABLE'] leftovers set()
# Puzzle Solved! Depth =  2   ['HETERONOMIES', 'SABLEST'] leftovers set()
# Puzzle Solved! Depth =  2   ['HETERONOMIES', 'SABLES'] leftovers set()
# Puzzle Solved! Depth =  2   ['HETERONOMIES', 'SABLER'] leftovers set()
# Puzzle Solved! Depth =  2   ['HETERONOMIES', 'SABLE'] leftovers set()
# Puzzle Solved! Depth =  2   ['HETERONOMIES', 'SABALS'] leftovers set()
# Puzzle Solved! Depth =  2   ['HETERONOMIES', 'SABAL'] leftovers set()
# Puzzle Solved! Depth =  2   ['HELMINTHIASIS', 'STROBILS'] leftovers set()
# Puzzle Solved! Depth =  2   ['HELMINTHIASIS', 'STROBILI'] leftovers set()
# Puzzle Solved! Depth =  2   ['HELMINTHIASIS', 'STROBILES'] leftovers set()
# Puzzle Solved! Depth =  2   ['HELMINTHIASIS', 'STROBILE'] leftovers set()
# Puzzle Solved! Depth =  2   ['HELMINTHIASIS', 'STROBILAR'] leftovers set()
# Puzzle Solved! Depth =  2   ['HELMINTHIASIS', 'STROBILA'] leftovers set()
# Puzzle Solved! Depth =  2   ['HELMINTHIASIS', 'STROBIL'] leftovers set()
# Puzzle Solved! Depth =  2   ['HELMINTHIASIS', 'STROBES'] leftovers set()
# Puzzle Solved! Depth =  2   ['HELMINTHIASIS', 'STROBE'] leftovers set()
# Puzzle Solved! Depth =  2   ['HELMINTHIASIS', 'SORTABLE'] leftovers set()
# Puzzle Solved! Depth =  2   ['HELMINTHIASIS', 'SOMBEREST'] leftovers set()
# Puzzle Solved! Depth =  2   ['HELMINTHIASIS', 'SOMBERER'] leftovers set()
# Puzzle Solved! Depth =  2   ['HELMINTHIASIS', 'SOMBER'] leftovers set()
# Puzzle Solved! Depth =  2   ['HELMINTHIASIS', 'SOBEREST'] leftovers set()
# Puzzle Solved! Depth =  2   ['HELMINTHIASIS', 'SOBERER'] leftovers set()
# Puzzle Solved! Depth =  2   ['HELMINTHIASIS', 'SOBER'] leftovers set()
# Puzzle Solved! Depth =  2   ['HELMINTHIASIS', 'SAILBOATER'] leftovers set()
# Puzzle Solved! Depth =  2   ['HELMINTHIASES', 'STROBILS'] leftovers set()
# Puzzle Solved! Depth =  2   ['HELMINTHIASES', 'STROBILI'] leftovers set()
# Puzzle Solved! Depth =  2   ['HELMINTHIASES', 'STROBILES'] leftovers set()
# Puzzle Solved! Depth =  2   ['HELMINTHIASES', 'STROBILE'] leftovers set()
# Puzzle Solved! Depth =  2   ['HELMINTHIASES', 'STROBILAR'] leftovers set()
# Puzzle Solved! Depth =  2   ['HELMINTHIASES', 'STROBILA'] leftovers set()
# Puzzle Solved! Depth =  2   ['HELMINTHIASES', 'STROBIL'] leftovers set()
# Puzzle Solved! Depth =  2   ['HELMINTHIASES', 'STROBES'] leftovers set()
# Puzzle Solved! Depth =  2   ['HELMINTHIASES', 'STROBE'] leftovers set()
# Puzzle Solved! Depth =  2   ['HELMINTHIASES', 'SORTABLE'] leftovers set()
# Puzzle Solved! Depth =  2   ['HELMINTHIASES', 'SOMBEREST'] leftovers set()
# Puzzle Solved! Depth =  2   ['HELMINTHIASES', 'SOMBERER'] leftovers set()
# Puzzle Solved! Depth =  2   ['HELMINTHIASES', 'SOMBER'] leftovers set()
# Puzzle Solved! Depth =  2   ['HELMINTHIASES', 'SOBEREST'] leftovers set()
# Puzzle Solved! Depth =  2   ['HELMINTHIASES', 'SOBERER'] leftovers set()
# Puzzle Solved! Depth =  2   ['HELMINTHIASES', 'SOBER'] leftovers set()
# Puzzle Solved! Depth =  2   ['HELMINTHIASES', 'SAILBOATER'] leftovers set()
# Puzzle Solved! Depth =  2   ['HARMONISTS', 'STROBILES'] leftovers set()
# Puzzle Solved! Depth =  2   ['HARMONISTS', 'STROBILE'] leftovers set()
# Puzzle Solved! Depth =  2   ['HARMONISTS', 'STRAINABLE'] leftovers set()
# Puzzle Solved! Depth =  2   ['HARMONISTS', 'STATABLE'] leftovers set()
# Puzzle Solved! Depth =  2   ['HARMONISTS', 'STAINABLE'] leftovers set()
# Puzzle Solved! Depth =  2   ['HARMONISTS', 'STABLISHES'] leftovers set()
# Puzzle Solved! Depth =  2   ['HARMONISTS', 'STABLEST'] leftovers set()
# Puzzle Solved! Depth =  2   ['HARMONISTS', 'STABLES'] leftovers set()
# Puzzle Solved! Depth =  2   ['HARMONISTS', 'STABLER'] leftovers set()
# Puzzle Solved! Depth =  2   ['HARMONISTS', 'STABLE'] leftovers set()
# Puzzle Solved! Depth =  2   ['HARMONISTS', 'STABILISES'] leftovers set()
# Puzzle Solved! Depth =  2   ['HARMONISTS', 'STABILISER'] leftovers set()
# Puzzle Solved! Depth =  2   ['HARMONISTS', 'STABILISE'] leftovers set()
# Puzzle Solved! Depth =  2   ['HARMONISTS', 'STABILES'] leftovers set()
# Puzzle Solved! Depth =  2   ['HARMONISTS', 'STABILE'] leftovers set()
# Puzzle Solved! Depth =  2   ['HARMONISTS', 'SORTABLE'] leftovers set()
# Puzzle Solved! Depth =  2   ['HARMONISTS', 'SIBILATES'] leftovers set()
# Puzzle Solved! Depth =  2   ['HARMONISTS', 'SIBILATE'] leftovers set()
# Puzzle Solved! Depth =  2   ['HARMONISTS', 'SHARABLE'] leftovers set()
# Puzzle Solved! Depth =  2   ['HARMONISTS', 'SENSIBLEST'] leftovers set()
# Puzzle Solved! Depth =  2   ['HARMONISTS', 'SENSIBLES'] leftovers set()
# Puzzle Solved! Depth =  2   ['HARMONISTS', 'SENSIBLER'] leftovers set()
# Puzzle Solved! Depth =  2   ['HARMONISTS', 'SENSIBLE'] leftovers set()
# Puzzle Solved! Depth =  2   ['HARMONISTS', 'SENSIBILIA'] leftovers set()
# Puzzle Solved! Depth =  2   ['HARMONISTS', 'SEISABLE'] leftovers set()
# Puzzle Solved! Depth =  2   ['HARMONISTS', 'SALABLE'] leftovers set()
# Puzzle Solved! Depth =  2   ['HARMONISTS', 'SAILBOATER'] leftovers set()
# Puzzle Solved! Depth =  2   ['HARMONISTS', 'SAILABLE'] leftovers set()
# Puzzle Solved! Depth =  2   ['HARMONISTS', 'SABLEST'] leftovers set()
# Puzzle Solved! Depth =  2   ['HARMONISTS', 'SABLES'] leftovers set()
# Puzzle Solved! Depth =  2   ['HARMONISTS', 'SABLER'] leftovers set()
# Puzzle Solved! Depth =  2   ['HARMONISTS', 'SABLE'] leftovers set()
# Puzzle Solved! Depth =  2   ['HARMONIST', 'TRILOBATE'] leftovers set()
# ...
# Puzzle Solved! Depth =  2   ['BOREHOLE', 'ELIMINATES'] leftovers set()
# Puzzle Solved! Depth =  2   ['BONESET', 'THERMOLABILE'] leftovers set()
# Puzzle Solved! Depth =  2   ['BONESET', 'THERMOHALINE'] leftovers set()
# Puzzle Solved! Depth =  2   ['BOMBORAS', 'STENOHALINE'] leftovers set()
# Puzzle Solved! Depth =  2   ['BOMBLET', 'THORNTAILS'] leftovers set()
# Puzzle Solved! Depth =  2   ['BOMBLET', 'THERIANS'] leftovers set()
# Puzzle Solved! Depth =  2   ['BOMBLET', 'TARNISHES'] leftovers set()
# Puzzle Solved! Depth =  2   ['BOMBLET', 'TARNISHABLE'] leftovers set()
# Puzzle Solved! Depth =  2   ['BOMBLET', 'TARNISH'] leftovers set()
# Puzzle Solved! Depth =  2   ['BOMBASTS', 'SHORELINES'] leftovers set()
# Puzzle Solved! Depth =  2   ['BOMBASTS', 'SHORELINE'] leftovers set()
# Puzzle Solved! Depth =  2   ['BOMBAST', 'THERMOHALINE'] leftovers set()
# Puzzle Solved! Depth =  2   ['BOMBAST', 'TARNISHABLE'] leftovers set()
# Puzzle Solved! Depth =  2   ['BLETHER', 'RENOMINATES'] leftovers set()
# Puzzle Solved! Depth =  2   ['BLAHER', 'RENOMINATES'] leftovers set()
# Puzzle Solved! Depth =  2   ['BERTHA', 'ANABOLISMS'] leftovers set()
# Puzzle Solved! Depth =  2   ['BERTHA', 'ANABOLISM'] leftovers set()
# Puzzle Solved! Depth =  2   ['BERTHA', 'ALMONRIES'] leftovers set()
# Puzzle Solved! Depth =  2   ['BERTHA', 'ALIMONIES'] leftovers set()
# Puzzle Solved! Depth =  2   ['BENTHON', 'NONTERMINALS'] leftovers set()
# Puzzle Solved! Depth =  2   ['BENTHON', 'NEOLIBERALISMS'] leftovers set()
# Puzzle Solved! Depth =  2   ['BENTHON', 'NEOLIBERALISM'] leftovers set()
# Puzzle Solved! Depth =  2   ['BARMIE', 'ETHANOLS'] leftovers set()
# Puzzle Solved! Depth =  2   ['BAREST', 'THERMOHALINE'] leftovers set()
# Puzzle Solved! Depth =  2   ['BABIEST', 'THERMOHALINE'] leftovers set()
# Puzzle Solved! Depth =  2   ['ARMLET', 'THROMBINS'] leftovers set()
# Puzzle Solved! Depth =  2   ['ANTSIEST', 'THERMOSTABLE'] leftovers set()
# Puzzle Solved! Depth =  2   ['ANTSIEST', 'THERMOLABILE'] leftovers set()
# Puzzle Solved! Depth =  2   ['ANTHRO', 'OBELISMS'] leftovers set()
# Puzzle Solved! Depth =  2   ['ANTHRO', 'OBELISM'] leftovers set()
# Puzzle Solved! Depth =  2   ['ANOMIE', 'ESTABLISHER'] leftovers set()
# Puzzle Solved! Depth =  2   ['ANIMIST', 'THERMOSTABLE'] leftovers set()
# Puzzle Solved! Depth =  2   ['ANIMIST', 'THERMOLABILE'] leftovers set()
# Puzzle Solved! Depth =  2   ['ALTERNANT', 'THROMBOSIS'] leftovers set()
# Puzzle Solved! Depth =  2   ['ALTERNANT', 'THROMBINS'] leftovers set()
# Puzzle Solved! Depth =  2   ['ALTERANT', 'THROMBOSIS'] leftovers set()
# Puzzle Solved! Depth =  2   ['ALTERANT', 'THROMBINS'] leftovers set()
# Puzzle Solved! Depth =  2   ['ALMOST', 'TEREBINTHS'] leftovers set()
# Puzzle Solved! Depth =  2   ['ALMOST', 'TEREBINTH'] leftovers set()
# Puzzle Solved! Depth =  2   ['ALMOST', 'TARNISHABLE'] leftovers set()
# Puzzle Solved! Depth =  2   ['ALERTEST', 'THROMBINS'] leftovers set()
# Puzzle Solved! Depth =  2   ['ALERTEST', 'THROMBIN'] leftovers set()
# Puzzle Solved! Depth =  2   ['ALARMISMS', 'STENOBATHS'] leftovers set()
# Puzzle Solved! Depth =  2   ['ALARMISMS', 'STENOBATH'] leftovers set()
# Puzzle Solved! Depth =  2   ['ABOHMS', 'STRAINABLE'] leftovers set()
# Puzzle Solved! Depth =  2   ['ABOHMS', 'STERILANTS'] leftovers set()
# Puzzle Solved! Depth =  2   ['ABOHMS', 'STERILANT'] leftovers set()
# Puzzle Solved! Depth =  2   ['ABOHMS', 'SNARLIEST'] leftovers set()
# Puzzle Solved! Depth =  2   ['ABOHMS', 'SILENTER'] leftovers set()
# Puzzle Solved! Depth =  2   ['ABOHMS', 'SERTRALINES'] leftovers set()
# Puzzle Solved! Depth =  2   ['ABOHMS', 'SERTRALINE'] leftovers set()
# Puzzle Solved! Depth =  2   ['ABOHMS', 'SAINTLIER'] leftovers set()
# Puzzle Solved! Depth =  2   ['ABMHOS', 'STRAINABLE'] leftovers set()
# Puzzle Solved! Depth =  2   ['ABMHOS', 'STERILANTS'] leftovers set()
# Puzzle Solved! Depth =  2   ['ABMHOS', 'STERILANT'] leftovers set()
# Puzzle Solved! Depth =  2   ['ABMHOS', 'SNARLIEST'] leftovers set()
# Puzzle Solved! Depth =  2   ['ABMHOS', 'SILENTER'] leftovers set()
# Puzzle Solved! Depth =  2   ['ABMHOS', 'SERTRALINES'] leftovers set()
# Puzzle Solved! Depth =  2   ['ABMHOS', 'SERTRALINE'] leftovers set()
# Puzzle Solved! Depth =  2   ['ABMHOS', 'SAINTLIER'] leftovers set()
# Puzzle Solved! Depth =  2   ['ABLEST', 'THROMBINS'] leftovers set()
# Puzzle Solved! Depth =  2   ['ABLEST', 'THROMBIN'] leftovers set()
# Puzzle Solved! Depth =  2   ['ABLEST', 'THERMOHALINE'] leftovers set()
# Puzzle Solved! Depth =  2   ['ABELIAN', 'NORTHMOST'] leftovers set()
# Puzzle Solved! Depth =  2   ['ABELIAN', 'NORTHERNMOST'] leftovers set()
# Puzzle Solved! Depth =  2   ['ABELIAN', 'NETHERMOST'] leftovers set()
# Puzzle Solved! Depth =  2   ['ABALONE', 'ERETHISMS'] leftovers set()
# Puzzle Solved! Depth =  2   ['ABALONE', 'ERETHISM'] leftovers set()
# Puzzle Solved! Depth =  2   ['THORON', 'NEOLIBERALISMS'] leftovers set()
# Puzzle Solved! Depth =  2   ['THORON', 'NEOLIBERALISM'] leftovers set()
# Puzzle Solved! Depth =  2   ['THORN', 'NEOLIBERALISMS'] leftovers set()
# Puzzle Solved! Depth =  2   ['THORN', 'NEOLIBERALISM'] leftovers set()
# Puzzle Solved! Depth =  2   ['THEIN', 'NEOLIBERALISMS'] leftovers set()
# Puzzle Solved! Depth =  2   ['THEIN', 'NEOLIBERALISM'] leftovers set()
# Puzzle Solved! Depth =  2   ['TARTLET', 'THROMBINS'] leftovers set()
# Puzzle Solved! Depth =  2   ['TANIST', 'THERMOSTABLE'] leftovers set()
# Puzzle Solved! Depth =  2   ['TANIST', 'THERMOLABILE'] leftovers set()
# Puzzle Solved! Depth =  2   ['TALENT', 'THROMBOSIS'] leftovers set()
# Puzzle Solved! Depth =  2   ['TALENT', 'THROMBINS'] leftovers set()
# Puzzle Solved! Depth =  2   ['TABLET', 'THROMBINS'] leftovers set()
# Puzzle Solved! Depth =  2   ['STERNEST', 'THERMOLABILE'] leftovers set()
# Puzzle Solved! Depth =  2   ['STATELET', 'THROMBINS'] leftovers set()
# Puzzle Solved! Depth =  2   ['STATELET', 'THROMBIN'] leftovers set()
# Puzzle Solved! Depth =  2   ['STALEST', 'THROMBINS'] leftovers set()
# Puzzle Solved! Depth =  2   ['STALEST', 'THROMBIN'] leftovers set()
# Puzzle Solved! Depth =  2   ['SONANT', 'THERMOLABILE'] leftovers set()
# Puzzle Solved! Depth =  2   ['SNORT', 'THERMOLABILE'] leftovers set()
# Puzzle Solved! Depth =  2   ['SMOLT', 'TARNISHABLE'] leftovers set()
# Puzzle Solved! Depth =  2   ['SLANT', 'THERMOLABILE'] leftovers set()
# Puzzle Solved! Depth =  2   ['SHORT', 'TERMINABLE'] leftovers set()
# Puzzle Solved! Depth =  2   ['SHORN', 'NOMINATABLE'] leftovers set()
# Puzzle Solved! Depth =  2   ['SHORL', 'LIBERTARIANISMS'] leftovers set()
# Puzzle Solved! Depth =  2   ['SHORL', 'LIBERTARIANISM'] leftovers set()
# Puzzle Solved! Depth =  2   ['SHOLOMS', 'STRAINABLE'] leftovers set()
# Puzzle Solved! Depth =  2   ['SHOAT', 'TERMINABLE'] leftovers set()
# Puzzle Solved! Depth =  2   ['SHOAL', 'LIBERTARIANISMS'] leftovers set()
# Puzzle Solved! Depth =  2   ['SHOAL', 'LIBERTARIANISM'] leftovers set()
# Puzzle Solved! Depth =  2   ['SHMOES', 'STRAINABLE'] leftovers set()
# Puzzle Solved! Depth =  2   ['SHEOL', 'LIBERTARIANISMS'] leftovers set()
# Puzzle Solved! Depth =  2   ['SHEOL', 'LIBERTARIANISM'] leftovers set()
# Puzzle Solved! Depth =  2   ['SHENT', 'THERMOLABILE'] leftovers set()
# Puzzle Solved! Depth =  2   ['SHARN', 'NOMINATABLE'] leftovers set()
# Puzzle Solved! Depth =  2   ['SETENANT', 'THERMOLABILE'] leftovers set()
# Puzzle Solved! Depth =  2   ['SERENEST', 'THERMOLABILE'] leftovers set()
# Puzzle Solved! Depth =  2   ['SATANIST', 'THERMOSTABLE'] leftovers set()
# Puzzle Solved! Depth =  2   ['SATANIST', 'THERMOLABILE'] leftovers set()
# Puzzle Solved! Depth =  2   ['SANEST', 'THERMOLABILE'] leftovers set()
# Puzzle Solved! Depth =  2   ['SALTEST', 'THROMBINS'] leftovers set()
# Puzzle Solved! Depth =  2   ['SALTEST', 'THROMBIN'] leftovers set()
# Puzzle Solved! Depth =  2   ['SALTANT', 'THERMOLABILE'] leftovers set()
# Puzzle Solved! Depth =  2   ['SAINT', 'THERMOSTABLE'] leftovers set()
# Puzzle Solved! Depth =  2   ['SAINT', 'THERMOLABILE'] leftovers set()
# Puzzle Solved! Depth =  2   ['ROSHI', 'INTERMINABLE'] leftovers set()
# Puzzle Solved! Depth =  2   ['RIANT', 'THERMOSTABLE'] leftovers set()
# Puzzle Solved! Depth =  2   ['RESENT', 'THERMOLABILE'] leftovers set()
# Puzzle Solved! Depth =  2   ['RENEST', 'THERMOLABILE'] leftovers set()
# Puzzle Solved! Depth =  2   ['ONSET', 'THERMOLABILE'] leftovers set()
# Puzzle Solved! Depth =  2   ['OBTEST', 'THERMOHALINE'] leftovers set()
# Puzzle Solved! Depth =  2   ['NORMS', 'STABLISHES'] leftovers set()
# Puzzle Solved! Depth =  2   ['NONART', 'THIMBLES'] leftovers set()
# Puzzle Solved! Depth =  2   ['NEIST', 'THERMOSTABLE'] leftovers set()
# Puzzle Solved! Depth =  2   ['NEIST', 'THERMOLABILE'] leftovers set()
# Puzzle Solved! Depth =  2   ['MOSTEST', 'TARNISHABLE'] leftovers set()
# Puzzle Solved! Depth =  2   ['MOSHES', 'STRAINABLE'] leftovers set()
# Puzzle Solved! Depth =  2   ['MORONS', 'STABLISHES'] leftovers set()
# Puzzle Solved! Depth =  2   ['MORNS', 'STABLISHES'] leftovers set()
# Puzzle Solved! Depth =  2   ['MONTE', 'ESTABLISHER'] leftovers set()
# Puzzle Solved! Depth =  2   ['MONIE', 'ESTABLISHER'] leftovers set()
# Puzzle Solved! Depth =  2   ['MOHEL', 'LIBERTARIANS'] leftovers set()
# Puzzle Solved! Depth =  2   ['MOHEL', 'LIBERTARIANISMS'] leftovers set()
# Puzzle Solved! Depth =  2   ['MOHEL', 'LIBERTARIANISM'] leftovers set()
# Puzzle Solved! Depth =  2   ['MBIRA', 'ANETHOLS'] leftovers set()
# Puzzle Solved! Depth =  2   ['MBIRA', 'ANETHOLES'] leftovers set()
# Puzzle Solved! Depth =  2   ['LENIENT', 'THERMOSTABLE'] leftovers set()
# Puzzle Solved! Depth =  2   ['LATEST', 'THROMBINS'] leftovers set()
# Puzzle Solved! Depth =  2   ['LATEST', 'THROMBIN'] leftovers set()
# Puzzle Solved! Depth =  2   ['LATENT', 'THROMBOSIS'] leftovers set()
# Puzzle Solved! Depth =  2   ['LATENT', 'THROMBINS'] leftovers set()
# Puzzle Solved! Depth =  2   ['INTRANT', 'THERMOSTABLE'] leftovers set()
# Puzzle Solved! Depth =  2   ['INTERNET', 'THERMOSTABLE'] leftovers set()
# Puzzle Solved! Depth =  2   ['INTENSEST', 'THERMOSTABLE'] leftovers set()
# Puzzle Solved! Depth =  2   ['INTENSEST', 'THERMOLABILE'] leftovers set()
# Puzzle Solved! Depth =  2   ['INSTANT', 'THERMOSTABLE'] leftovers set()
# Puzzle Solved! Depth =  2   ['INSTANT', 'THERMOLABILE'] leftovers set()
# Puzzle Solved! Depth =  2   ['INSISTENT', 'THERMOSTABLE'] leftovers set()
# Puzzle Solved! Depth =  2   ['INSISTENT', 'THERMOLABILE'] leftovers set()
# Puzzle Solved! Depth =  2   ['INSET', 'THERMOSTABLE'] leftovers set()
# Puzzle Solved! Depth =  2   ['INSET', 'THERMOLABILE'] leftovers set()
# Puzzle Solved! Depth =  2   ['INERT', 'THERMOSTABLE'] leftovers set()
# Puzzle Solved! Depth =  2   ['HOSEL', 'LIBERTARIANISMS'] leftovers set()
# Puzzle Solved! Depth =  2   ['HOSEL', 'LIBERTARIANISM'] leftovers set()
# Puzzle Solved! Depth =  2   ['HORAL', 'LIBERTARIANISMS'] leftovers set()
# Puzzle Solved! Depth =  2   ['HORAL', 'LIBERTARIANISM'] leftovers set()
# Puzzle Solved! Depth =  2   ['HOLMS', 'STRAINABLE'] leftovers set()
# Puzzle Solved! Depth =  2   ['HIMBO', 'ORIENTALS'] leftovers set()
# Puzzle Solved! Depth =  2   ['HIMBO', 'ORIENTALISTS'] leftovers set()
# Puzzle Solved! Depth =  2   ['HIMBO', 'ORIENTALIST'] leftovers set()
# Puzzle Solved! Depth =  2   ['HIMBO', 'ORIENTALISMS'] leftovers set()
# Puzzle Solved! Depth =  2   ['HIMBO', 'ORIENTALISM'] leftovers set()
# Puzzle Solved! Depth =  2   ['HAINT', 'THERMOSTABLE'] leftovers set()
# Puzzle Solved! Depth =  2   ['ELINT', 'THERMOSTABLE'] leftovers set()
# Puzzle Solved! Depth =  2   ['BOMBORA', 'ANTHRANILATES'] leftovers set()
# Puzzle Solved! Depth =  2   ['BOAST', 'THERMOHALINE'] leftovers set()
# Puzzle Solved! Depth =  2   ['BLEST', 'THERMOHALINE'] leftovers set()
# Puzzle Solved! Depth =  2   ['BLAST', 'THERMOHALINE'] leftovers set()
# Puzzle Solved! Depth =  2   ['BLAIN', 'NORTHERNMOST'] leftovers set()
# Puzzle Solved! Depth =  2   ['BLAIN', 'NETHERMOST'] leftovers set()
# Puzzle Solved! Depth =  2   ['BIBLIST', 'THERMOHALINE'] leftovers set()
# Puzzle Solved! Depth =  2   ['BERMS', 'STENOHALINE'] leftovers set()
# Puzzle Solved! Depth =  2   ['BEHEST', 'TRINOMIALS'] leftovers set()
# Puzzle Solved! Depth =  2   ['BEHEST', 'TRINOMIAL'] leftovers set()
# Puzzle Solved! Depth =  2   ['BEHEST', 'THERMOHALINE'] leftovers set()
# Puzzle Solved! Depth =  2   ['BASEST', 'THERMOHALINE'] leftovers set()
# Puzzle Solved! Depth =  2   ['BASALT', 'THERMOHALINE'] leftovers set()
# Puzzle Solved! Depth =  2   ['BARMS', 'STENOHALINE'] leftovers set()
# Puzzle Solved! Depth =  2   ['ASLANT', 'THERMOLABILE'] leftovers set()
# Puzzle Solved! Depth =  2   ['ANENST', 'THERMOLABILE'] leftovers set()
# Puzzle Solved! Depth =  2   ['ALERT', 'THROMBINS'] leftovers set()
# Puzzle Solved! Depth =  2   ['ABOHM', 'MISTRANSLATES'] leftovers set()
# Puzzle Solved! Depth =  2   ['ABOHM', 'MISTRANSLATE'] leftovers set()
# Puzzle Solved! Depth =  2   ['ABOHM', 'MINSTRELSIES'] leftovers set()
# Puzzle Solved! Depth =  2   ['ABOHM', 'MINSTRELS'] leftovers set()
# Puzzle Solved! Depth =  2   ['ABOHM', 'MINSTREL'] leftovers set()
# Puzzle Solved! Depth =  2   ['ABOHM', 'MINISTERIAL'] leftovers set()
# Puzzle Solved! Depth =  2   ['ABMHO', 'ORIENTALS'] leftovers set()
# Puzzle Solved! Depth =  2   ['ABMHO', 'ORIENTALISTS'] leftovers set()
# Puzzle Solved! Depth =  2   ['ABMHO', 'ORIENTALIST'] leftovers set()
# Puzzle Solved! Depth =  2   ['ABMHO', 'ORIENTALISMS'] leftovers set()
# Puzzle Solved! Depth =  2   ['ABMHO', 'ORIENTALISM'] leftovers set()
# Puzzle Solved! Depth =  2   ['THIN', 'NEOLIBERALISMS'] leftovers set()
# Puzzle Solved! Depth =  2   ['THIN', 'NEOLIBERALISM'] leftovers set()
# Puzzle Solved! Depth =  2   ['THEN', 'NEOLIBERALISMS'] leftovers set()
# Puzzle Solved! Depth =  2   ['THEN', 'NEOLIBERALISM'] leftovers set()
# Puzzle Solved! Depth =  2   ['THAN', 'NEOLIBERALISMS'] leftovers set()
# Puzzle Solved! Depth =  2   ['THAN', 'NEOLIBERALISM'] leftovers set()
# Puzzle Solved! Depth =  2   ['TENSEST', 'THERMOLABILE'] leftovers set()
# Puzzle Solved! Depth =  2   ['TAINT', 'THERMOSTABLE'] leftovers set()
# Puzzle Solved! Depth =  2   ['STENT', 'THERMOLABILE'] leftovers set()
# Puzzle Solved! Depth =  2   ['STATANT', 'THERMOLABILE'] leftovers set()
# Puzzle Solved! Depth =  2   ['SENT', 'THERMOLABILE'] leftovers set()
# Puzzle Solved! Depth =  2   ['OHMS', 'STRAINABLE'] leftovers set()
# Puzzle Solved! Depth =  2   ['NEST', 'THERMOLABILE'] leftovers set()
# Puzzle Solved! Depth =  2   ['MOST', 'TARNISHABLE'] leftovers set()
# Puzzle Solved! Depth =  2   ['MORT', 'TARNISHABLE'] leftovers set()
# Puzzle Solved! Depth =  2   ['MOLT', 'TARNISHABLE'] leftovers set()
# Puzzle Solved! Depth =  2   ['MOHOS', 'STRAINABLE'] leftovers set()
# Puzzle Solved! Depth =  2   ['MOAT', 'TARNISHABLE'] leftovers set()
# Puzzle Solved! Depth =  2   ['MINT', 'THERMOSTABLE'] leftovers set()
# Puzzle Solved! Depth =  2   ['MHOS', 'STRAINABLE'] leftovers set()
# Puzzle Solved! Depth =  2   ['LINT', 'THERMOSTABLE'] leftovers set()
# Puzzle Solved! Depth =  2   ['INTENT', 'THERMOSTABLE'] leftovers set()
# Puzzle Solved! Depth =  2   ['INSIST', 'THERMOSTABLE'] leftovers set()
# Puzzle Solved! Depth =  2   ['INSIST', 'THERMOLABILE'] leftovers set()
# Puzzle Solved! Depth =  2   ['HOST', 'TERMINABLE'] leftovers set()
# Puzzle Solved! Depth =  2   ['HOMS', 'STRAINABLE'] leftovers set()
# Puzzle Solved! Depth =  2   ['HOMOS', 'STRAINABLE'] leftovers set()
# Puzzle Solved! Depth =  2   ['HOBNOB', 'BILATERALISMS'] leftovers set()
# Puzzle Solved! Depth =  2   ['HOBNOB', 'BILATERALISM'] leftovers set()
# Puzzle Solved! Depth =  2   ['HINT', 'THERMOSTABLE'] leftovers set()
# Puzzle Solved! Depth =  2   ['BLAH', 'HETERONOMIES'] leftovers set()
# Puzzle Solved! Depth =  2   ['BINT', 'THERMOSTABLE'] leftovers set()
# Puzzle Solved! Depth =  2   ['BEST', 'THERMOHALINE'] leftovers set()
# Puzzle Solved! Depth =  2   ['BESET', 'THERMOHALINE'] leftovers set()
# Puzzle Solved! Depth =  2   ['BAST', 'THERMOHALINE'] leftovers set()
# Puzzle Solved! Depth =  2   ['HOBO', 'ORIENTALISMS'] leftovers set()
# Puzzle Solved! Depth =  2   ['HOBO', 'ORIENTALISM'] leftovers set()
# Puzzle Solved! Depth =  2   ['BOHO', 'ORIENTALISMS'] leftovers set()
# Puzzle Solved! Depth =  2   ['BOHO', 'ORIENTALISM'] leftovers set()
# 2
