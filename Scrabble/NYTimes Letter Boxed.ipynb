# %% [markdown]
# ## NYTimes Letter Boxed
#
# This is a notebook to provide solutions to the [New York Times Letter Boxed Puzzle](https://www.nytimes.com/puzzles/letter-boxed).

# %%
#puzzle = {'UNH','ASC','KTO','LRI'}
#puzzle = {'EMA','HNL','RSB','OIT'}
#puzzle = {'VCH','YOR','MAE','NDB'}
#puzzle = {'YDW','OLA','UKR','ENJ'}
#puzzle = {'AOU','SCM','PER','HBL'}
#puzzle = {'CNO','SPX','ILM','HEU'}
puzzle = {'RGE','OTI','CLJ','AUN'}

def check_puzzle(puzzle):
    import string
    try:
        assert len(puzzle) == 4, 'Puzzle must be length 4'
    except AssertionError as e:
        print(e)
    try:
        assert all([len(item)==3 for item in puzzle]), 'Puzzle sides must all be length 3'
    except AssertionError as e:
        print(e)
    try:
        assert all([len(set(item))==3 for item in puzzle]), 'Puzzle must have unique characters'
    except AssertionError as e:
        print(e)
    try:
        char_set = set()
        s = set(string.ascii_uppercase)
        for item in puzzle:
            char_set.update(set(item))
        assert (len(char_set)==12) and (len(char_set.intersection(s))==12), 'Puzzle have exactly 12 unique characters and all in alphabet'
    except AssertionError as e:
        print(e)

check_puzzle(puzzle)

# %%
# load dictionary
# Please note that this file is not on github; you can substitute another dictionary
# for example, https://gitlab.com/snippets/1777561/raw has a dictionary.
file18     = 'twl2018.txt'
with open(file18) as f:
    twl18 = f.read().splitlines()
twl18 = [item.upper() for item in twl18]

# pre-process lexicon: only keep possible words:
# rules: 1) can reuse letters 2) consecutive letters must be from different sides 3) >=3 letter length
def preprocess_lexicon(l,puzzle):
    puzzle_string_unsorted = ''.join(puzzle)
    lex = []
    for item in l:
        # check that word is at least three characters and all the characters are in the puzzle
        if (len(item)>=3) and (all([c in puzzle_string_unsorted for c in item])):
            # check that word is valid; i.e. subsequent letters must come from different puzzle sides
            side1 = -1
            wd  = True
            for c in item:
                side2 = puzzle_string_unsorted.index(c) // 3
                wd = wd and (side2 != side1)
                side1 = side2
            if wd:
                lex.append(item)#=''.join(sorted(set(item)))

    return(lex)

lex = preprocess_lexicon(twl18,puzzle)

# %%
puzzle
# Out:
# {'AUN', 'CLJ', 'OTI', 'RGE'}

# %%
print('Dictionary length:',len(twl18))
print('Lexicon length:   ',len(lex))
# Out:
# Dictionary length: 192111
# Lexicon length:    1225

# %%
def processed_letters(chain,puzzle):
    s = ''.join(sorted(''.join(puzzle)))
    finished_letters = set()
    for item in chain:
        finished_letters.update(item)
    unfinished_letters = set(s) - finished_letters
    return finished_letters,unfinished_letters

def reduce_lexicon(chain,lexicon,unfinished_letters):
    sort_by = [len(unfinished_letters.intersection(set(item))) for item in lexicon]
    sorted_lex = [item for _,item in sorted(zip(sort_by,lexicon),reverse=True)]
    sorted_lex = [item for item in sorted_lex if (len(unfinished_letters.intersection(set(item))) > 0)]
    return(sorted_lex)

def tree(chain,puzzle,lexicon,best_depth):
    tree_depth = len(chain)
    # 1) reduce lexicon: only words that start with the last character of the final 
    # word in chain and only words that will eliminate new letters
    # 2) sort lexicon: descending order by the number of letters that the word will eliminate
    finished_letters,unfinished_letters = processed_letters(chain,puzzle)
    reduced_lexicon = reduce_lexicon(chain,lexicon,unfinished_letters)
    #print('Start tree call',tree_depth,chain,len(reduced_lexicon),unfinished_letters)
    for word in reduced_lexicon:
        if len(chain)>0:
            last_letter = chain[-1][-1]
            valid_next_word = last_letter == word[0]
        else:
            valid_next_word = True
        if (valid_next_word):
            c = chain.copy()
            c.append(word)
            f,u = processed_letters(c,puzzle)
            #print('XXX',chain,word,u,best_depth)
            # base case:
            if len(u)==0:
                if (tree_depth+1<best_depth):
                    best_depth = tree_depth+1
                print('Puzzle Solved! Depth = ',best_depth,' ',c)#,'leftovers',u)
            elif (tree_depth+1 >= best_depth):
                pass
                #print('Puzzle unsolved',tree_depth+1,c,' leftovers',u)
            else:
                #print('XXXX',tree_depth,c,reduced_lexicon)
                best_depth = tree(c,puzzle,reduced_lexicon,best_depth)
    
    return(best_depth)
    
chain = []
best_depth = tree(chain,puzzle,lex,10)
best_depth
# Out:
# Puzzle Solved! Depth =  3   ['OUTLEARNING', 'GOJI', 'IRONICAL']
# Puzzle Solved! Depth =  3   ['OUTLEARNING', 'GOJI', 'IRONIC']
# Puzzle Solved! Depth =  3   ['OUTLEARNING', 'GOJI', 'INTRONIC']
# Puzzle Solved! Depth =  3   ['OUTLEARNING', 'GOJI', 'INTROJECT']
# Puzzle Solved! Depth =  3   ['OUTLEARNING', 'GOJI', 'INTRICATE']
# Puzzle Solved! Depth =  3   ['OUTLEARNING', 'GOJI', 'INTRAOCULAR']
# Puzzle Solved! Depth =  3   ['OUTLEARNING', 'GOJI', 'INTACT']
# Puzzle Solved! Depth =  3   ['OUTLEARNING', 'GOJI', 'INOCULATE']
# Puzzle Solved! Depth =  3   ['OUTLEARNING', 'GOJI', 'INOCULA']
# Puzzle Solved! Depth =  3   ['OUTLEARNING', 'GOJI', 'INLACING']
# Puzzle Solved! Depth =  3   ['OUTLEARNING', 'GOJI', 'INLACE']
# Puzzle Solved! Depth =  3   ['OUTLEARNING', 'GOJI', 'INJECT']
# Puzzle Solved! Depth =  3   ['OUTLEARNING', 'GOJI', 'INCUR']
# Puzzle Solved! Depth =  3   ['OUTLEARNING', 'GOJI', 'INCULT']
# Puzzle Solved! Depth =  3   ['OUTLEARNING', 'GOJI', 'INCOG']
# Puzzle Solved! Depth =  3   ['OUTLEARNING', 'GOJI', 'INCENT']
# Puzzle Solved! Depth =  3   ['OUTLEARNING', 'GOJI', 'INCAGING']
# Puzzle Solved! Depth =  3   ['OUTLEARNING', 'GOJI', 'ILIAC']
# Puzzle Solved! Depth =  3   ['OUTLEARNING', 'GOJI', 'ILEAC']
# Puzzle Solved! Depth =  3   ['OUTLEARNING', 'GOJI', 'ICONOLOGICAL']
# Puzzle Solved! Depth =  3   ['OUTLEARNING', 'GOJI', 'ICONICAL']
# Puzzle Solved! Depth =  3   ['OUTLEARNING', 'GOJI', 'ICONIC']
# Puzzle Solved! Depth =  3   ['OUTLEARNING', 'GOJI', 'ICON']
# Puzzle Solved! Depth =  3   ['OUTLEARNING', 'GOJI', 'ICING']
# Puzzle Solved! Depth =  3   ['OUTLEARNING', 'GOJI', 'ICE']
# Puzzle Solved! Depth =  3   ['OUTLEARNING', 'GOJI', 'IATRICAL']
# Puzzle Solved! Depth =  3   ['OUTLEARNING', 'GOJI', 'IATRIC']
# Puzzle Solved! Depth =  3   ['OUTLEARNING', 'GLUCINIC', 'CONJUROR']
# Puzzle Solved! Depth =  3   ['OUTLEARNING', 'GLUCINIC', 'CONJURING']
# Puzzle Solved! Depth =  3   ['OUTLEARNING', 'GLUCINIC', 'CONJUGATE']
# Puzzle Solved! Depth =  3   ['OUTLEARNING', 'GLUCINIC', 'CONJUGAL']
# Puzzle Solved! Depth =  3   ['OUTLEARNING', 'GLUCINIC', 'CONJECTURING']
# Puzzle Solved! Depth =  3   ['OUTLEARNING', 'GLUCINIC', 'CONJECTURAL']
# Puzzle Solved! Depth =  3   ['OUTLEARNING', 'GLUCINIC', 'CARCAJOU']
# Puzzle Solved! Depth =  3   ['OUTLEARNING', 'GLUCINIC', 'CAJON']
# Puzzle Solved! Depth =  3   ['OUTLEARNING', 'GLUCINIC', 'CAJOLING']
# Puzzle Solved! Depth =  3   ['OUTLEARNING', 'GLUCINIC', 'CAJOLE']
# Puzzle Solved! Depth =  3   ['OUTLEARNING', 'GLUCAGON', 'NONJUROR']
# Puzzle Solved! Depth =  3   ['OUTLEARNING', 'GLUCAGON', 'NONJURING']
# Puzzle Solved! Depth =  3   ['OUTLEARNING', 'GLUCAGON', 'NINJA']
# Puzzle Solved! Depth =  3   ['OUTLEARNING', 'GLACIATE', 'ELECTROJET']
# Puzzle Solved! Depth =  3   ['OUTLEARNING', 'GLACIATE', 'EJECTA']
# Puzzle Solved! Depth =  3   ['OUTLEARNING', 'GLACIATE', 'EJECT']
# Puzzle Solved! Depth =  3   ['OUTLEARNING', 'GLACIATE', 'EJACULATE']
# Puzzle Solved! Depth =  3   ['OUTLEARNING', 'GLACEING', 'GOJI']
# Puzzle Solved! Depth =  3   ['OUTLEARNING', 'GLACEING', 'GAIJIN']
# Puzzle Solved! Depth =  3   ['OUTLEARNING', 'GLACE', 'ELECTROJET']
# Puzzle Solved! Depth =  3   ['OUTLEARNING', 'GLACE', 'EJECTA']
# Puzzle Solved! Depth =  3   ['OUTLEARNING', 'GLACE', 'EJECT']
# Puzzle Solved! Depth =  3   ['OUTLEARNING', 'GLACE', 'EJACULATE']
# Puzzle Solved! Depth =  3   ['OUTLEARNING', 'GARLIC', 'CONJUROR']
# Puzzle Solved! Depth =  3   ['OUTLEARNING', 'GARLIC', 'CONJURING']
# Puzzle Solved! Depth =  3   ['OUTLEARNING', 'GARLIC', 'CONJUGATE']
# Puzzle Solved! Depth =  3   ['OUTLEARNING', 'GARLIC', 'CONJUGAL']
# Puzzle Solved! Depth =  3   ['OUTLEARNING', 'GARLIC', 'CONJECTURING']
# Puzzle Solved! Depth =  3   ['OUTLEARNING', 'GARLIC', 'CONJECTURAL']
# Puzzle Solved! Depth =  3   ['OUTLEARNING', 'GARLIC', 'CARCAJOU']
# Puzzle Solved! Depth =  3   ['OUTLEARNING', 'GARLIC', 'CAJON']
# Puzzle Solved! Depth =  3   ['OUTLEARNING', 'GARLIC', 'CAJOLING']
# Puzzle Solved! Depth =  3   ['OUTLEARNING', 'GARLIC', 'CAJOLE']
# Puzzle Solved! Depth =  3   ['OUTLEARNING', 'GARCON', 'NONJUROR']
# Puzzle Solved! Depth =  3   ['OUTLEARNING', 'GARCON', 'NONJURING']
# Puzzle Solved! Depth =  3   ['OUTLEARNING', 'GARCON', 'NINJA']
# Puzzle Solved! Depth =  3   ['OUTLEARNING', 'GALENIC', 'CONJUROR']
# Puzzle Solved! Depth =  3   ['OUTLEARNING', 'GALENIC', 'CONJURING']
# Puzzle Solved! Depth =  3   ['OUTLEARNING', 'GALENIC', 'CONJUGATE']
# Puzzle Solved! Depth =  3   ['OUTLEARNING', 'GALENIC', 'CONJUGAL']
# Puzzle Solved! Depth =  3   ['OUTLEARNING', 'GALENIC', 'CONJECTURING']
# Puzzle Solved! Depth =  3   ['OUTLEARNING', 'GALENIC', 'CONJECTURAL']
# Puzzle Solved! Depth =  3   ['OUTLEARNING', 'GALENIC', 'CARCAJOU']
# Puzzle Solved! Depth =  3   ['OUTLEARNING', 'GALENIC', 'CAJON']
# Puzzle Solved! Depth =  3   ['OUTLEARNING', 'GALENIC', 'CAJOLING']
# Puzzle Solved! Depth =  3   ['OUTLEARNING', 'GALENIC', 'CAJOLE']
# Puzzle Solved! Depth =  3   ['OUTLEARNING', 'GAIJIN', 'NONTRAGIC']
# Puzzle Solved! Depth =  3   ['OUTLEARNING', 'GAIJIN', 'NONRACIAL']
# Puzzle Solved! Depth =  3   ['OUTLEARNING', 'GAIJIN', 'NONLOGICAL']
# Puzzle Solved! Depth =  3   ['OUTLEARNING', 'GAIJIN', 'NONLOCAL']
# Puzzle Solved! Depth =  3   ['OUTLEARNING', 'GAIJIN', 'NONELECTRONIC']
# Puzzle Solved! Depth =  3   ['OUTLEARNING', 'GAIJIN', 'NONELECTRICAL']
# Puzzle Solved! Depth =  3   ['OUTLEARNING', 'GAIJIN', 'NONELECTRIC']
# Puzzle Solved! Depth =  3   ['OUTLEARNING', 'GAIJIN', 'NONELECT']
# Puzzle Solved! Depth =  3   ['OUTLEARNING', 'GAIJIN', 'NONCULTURAL']
# Puzzle Solved! Depth =  3   ['OUTLEARNING', 'GAIJIN', 'NONCONTRACT']
# Puzzle Solved! Depth =  3   ['OUTLEARNING', 'GAIJIN', 'NONCONTACT']
# Puzzle Solved! Depth =  3   ['OUTLEARNING', 'GAIJIN', 'NONCONCUR']
# Puzzle Solved! Depth =  3   ['OUTLEARNING', 'GAIJIN', 'NONCOLOR']
# Puzzle Solved! Depth =  3   ['OUTLEARNING', 'GAIJIN', 'NONCOLA']
# Puzzle Solved! Depth =  3   ['OUTLEARNING', 'GAIJIN', 'NONCIRCULAR']
# Puzzle Solved! Depth =  3   ['OUTLEARNING', 'GAIJIN', 'NONCENTRAL']
# Puzzle Solved! Depth =  3   ['OUTLEARNING', 'GAIJIN', 'NONCE']
# Puzzle Solved! Depth =  3   ['OUTLEARNING', 'GAIJIN', 'NONCALORIC']
# Puzzle Solved! Depth =  3   ['OUTLEARNING', 'GAIJIN', 'NOCTURNE']
# Puzzle Solved! Depth =  3   ['OUTLEARNING', 'GAIJIN', 'NOCTURN']
# Puzzle Solved! Depth =  3   ['OUTLEARNING', 'GAIJIN', 'NOCTULE']
# Puzzle Solved! Depth =  3   ['OUTLEARNING', 'GAIJIN', 'NOCENT']
# Puzzle Solved! Depth =  3   ['OUTLEARNING', 'GAIJIN', 'NIECE']
# Puzzle Solved! Depth =  3   ['OUTLEARNING', 'GAIJIN', 'NICTATE']
# Puzzle Solved! Depth =  3   ['OUTLEARNING', 'GAIJIN', 'NICOL']
# Puzzle Solved! Depth =  3   ['OUTLEARNING', 'GAIJIN', 'NICE']
# Puzzle Solved! Depth =  3   ['OUTLEARNING', 'GAIJIN', 'NIACIN']
# Puzzle Solved! Depth =  3   ['OUTLEARNING', 'GAIJIN', 'NEUTRONIC']
# Puzzle Solved! Depth =  3   ['OUTLEARNING', 'GAIJIN', 'NEURONIC']
# Puzzle Solved! Depth =  3   ['OUTLEARNING', 'GAIJIN', 'NEUROLOGICAL']
# Puzzle Solved! Depth =  3   ['OUTLEARNING', 'GAIJIN', 'NEUROLOGIC']
# Puzzle Solved! Depth =  3   ['OUTLEARNING', 'GAIJIN', 'NEUROCOEL']
# Puzzle Solved! Depth =  3   ['OUTLEARNING', 'GAIJIN', 'NEURALGIC']
# Puzzle Solved! Depth =  3   ['OUTLEARNING', 'GAIJIN', 'NEOLOGIC']
# Puzzle Solved! Depth =  3   ['OUTLEARNING', 'GAIJIN', 'NEOCON']
# Puzzle Solved! Depth =  3   ['OUTLEARNING', 'GAIJIN', 'NEOCOLONIAL']
# Puzzle Solved! Depth =  3   ['OUTLEARNING', 'GAIJIN', 'NECTARINE']
# Puzzle Solved! Depth =  3   ['OUTLEARNING', 'GAIJIN', 'NECTARIAL']
# Puzzle Solved! Depth =  3   ['OUTLEARNING', 'GAIJIN', 'NECTAR']
# Puzzle Solved! Depth =  3   ['OUTLEARNING', 'GAIJIN', 'NECROLOGICAL']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LUTEOLIN', 'NONJUROR']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LUTEOLIN', 'NONJURING']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LUTEOLIN', 'NINJA']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LUTEIN', 'NONJUROR']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LUTEIN', 'NONJURING']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LUTEIN', 'NINJA']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LUTEA', 'AJUGA']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LUTEA', 'AJI']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LUTEA', 'AJAR']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LUTEA', 'ACAJOU']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LUTE', 'ELECTROJET']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LUTE', 'EJECTA']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LUTE', 'EJECT']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LUTE', 'EJACULATE']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LUCULENT', 'TRIJUGATE']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LUCULENT', 'TRIJET']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LUCULENT', 'TRAJECT']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LUCULENT', 'TAJINE']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LUCULENT', 'TAJ']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LUCENT', 'TRIJUGATE']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LUCENT', 'TRIJET']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LUCENT', 'TRAJECT']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LUCENT', 'TAJINE']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LUCENT', 'TAJ']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LOUT', 'TRIJUGATE']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LOUT', 'TRIJET']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LOUT', 'TRAJECT']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LOUT', 'TAJINE']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LOUT', 'TAJ']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LORICATE', 'ELECTROJET']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LORICATE', 'EJECTA']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LORICATE', 'EJECT']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LORICATE', 'EJACULATE']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LOGOUT', 'TRIJUGATE']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LOGOUT', 'TRIJET']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LOGOUT', 'TRAJECT']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LOGOUT', 'TAJINE']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LOGOUT', 'TAJ']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LOGOCENTRIC', 'CONJUROR']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LOGOCENTRIC', 'CONJURING']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LOGOCENTRIC', 'CONJUGATE']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LOGOCENTRIC', 'CONJUGAL']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LOGOCENTRIC', 'CONJECTURING']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LOGOCENTRIC', 'CONJECTURAL']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LOGOCENTRIC', 'CARCAJOU']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LOGOCENTRIC', 'CAJON']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LOGOCENTRIC', 'CAJOLING']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LOGOCENTRIC', 'CAJOLE']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LOCULATE', 'ELECTROJET']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LOCULATE', 'EJECTA']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LOCULATE', 'EJECT']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LOCULATE', 'EJACULATE']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LOCATE', 'ELECTROJET']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LOCATE', 'EJECTA']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LOCATE', 'EJECT']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LOCATE', 'EJACULATE']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LINT', 'TRIJUGATE']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LINT', 'TRIJET']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LINT', 'TRAJECT']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LINT', 'TAJINE']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LINT', 'TAJ']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LINOLEATE', 'ELECTROJET']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LINOLEATE', 'EJECTA']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LINOLEATE', 'EJECT']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LINOLEATE', 'EJACULATE']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LINOCUT', 'TRIJUGATE']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LINOCUT', 'TRIJET']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LINOCUT', 'TRAJECT']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LINOCUT', 'TAJINE']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LINOCUT', 'TAJ']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LINGULATE', 'ELECTROJET']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LINGULATE', 'EJECTA']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LINGULATE', 'EJECT']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LINGULATE', 'EJACULATE']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LINEOLATE', 'ELECTROJET']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LINEOLATE', 'EJECTA']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LINEOLATE', 'EJECT']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LINEOLATE', 'EJACULATE']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LINECUT', 'TRIJUGATE']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LINECUT', 'TRIJET']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LINECUT', 'TRAJECT']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LINECUT', 'TAJINE']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LINECUT', 'TAJ']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LINEATE', 'ELECTROJET']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LINEATE', 'EJECTA']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LINEATE', 'EJECT']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LINEATE', 'EJACULATE']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LILT', 'TRIJUGATE']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LILT', 'TRIJET']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LILT', 'TRAJECT']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LILT', 'TAJINE']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LILT', 'TAJ']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LIGULATE', 'ELECTROJET']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LIGULATE', 'EJECTA']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LIGULATE', 'EJECT']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LIGULATE', 'EJACULATE']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LIGATURING', 'GOJI']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LIGATURING', 'GAIJIN']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LIGATE', 'ELECTROJET']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LIGATE', 'EJECTA']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LIGATE', 'EJECT']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LIGATE', 'EJACULATE']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LICENTE', 'ELECTROJET']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LICENTE', 'EJECTA']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LICENTE', 'EJECT']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LICENTE', 'EJACULATE']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LET', 'TRIJUGATE']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LET', 'TRIJET']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LET', 'TRAJECT']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LET', 'TAJINE']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LET', 'TAJ']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LENTEN', 'NONJUROR']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LENTEN', 'NONJURING']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LENTEN', 'NINJA']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LENT', 'TRIJUGATE']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LENT', 'TRIJET']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LENT', 'TRAJECT']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LENT', 'TAJINE']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LENT', 'TAJ']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LENIENT', 'TRIJUGATE']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LENIENT', 'TRIJET']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LENIENT', 'TRAJECT']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LENIENT', 'TAJINE']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LENIENT', 'TAJ']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LECTURING', 'GOJI']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LECTURING', 'GAIJIN']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LEARNT', 'TRIJUGATE']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LEARNT', 'TRIJET']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LEARNT', 'TRAJECT']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LEARNT', 'TAJINE']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LEARNT', 'TAJ']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LATRINE', 'ELECTROJET']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LATRINE', 'EJECTA']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LATRINE', 'EJECT']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LATRINE', 'EJACULATE']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LATRIA', 'AJUGA']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LATRIA', 'AJI']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LATRIA', 'AJAR']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LATRIA', 'ACAJOU']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LATENT', 'TRIJUGATE']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LATENT', 'TRIJET']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LATENT', 'TRAJECT']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LATENT', 'TAJINE']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LATENT', 'TAJ']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LATENING', 'GOJI']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LATENING', 'GAIJIN']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LATEN', 'NONJUROR']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LATEN', 'NONJURING']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LATEN', 'NINJA']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LATE', 'ELECTROJET']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LATE', 'EJECTA']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LATE', 'EJECT']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LATE', 'EJACULATE']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LAT', 'TRIJUGATE']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LAT', 'TRIJET']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LAT', 'TRAJECT']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LAT', 'TAJINE']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LAT', 'TAJ']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LARNT', 'TRIJUGATE']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LARNT', 'TRIJET']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LARNT', 'TRAJECT']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LARNT', 'TAJINE']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LARNT', 'TAJ']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LARIAT', 'TRIJUGATE']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LARIAT', 'TRIJET']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LARIAT', 'TRAJECT']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LARIAT', 'TAJINE']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LARIAT', 'TAJ']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LAETRILE', 'ELECTROJET']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LAETRILE', 'EJECTA']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LAETRILE', 'EJECT']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LAETRILE', 'EJACULATE']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LACTATE', 'ELECTROJET']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LACTATE', 'EJECTA']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LACTATE', 'EJECT']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LACTATE', 'EJACULATE']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LACINIATE', 'ELECTROJET']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LACINIATE', 'EJECTA']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LACINIATE', 'EJECT']
# Puzzle Solved! Depth =  3   ['NEUROLOGICAL', 'LACINIATE', 'EJACULATE']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'EULOGIAE', 'ELECTROJET']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'EULOGIAE', 'EJECTA']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'EULOGIAE', 'EJECT']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'EULOGIAE', 'EJACULATE']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'EULOGIA', 'AJUGA']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'EULOGIA', 'AJI']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'EULOGIA', 'AJAR']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'EULOGIA', 'ACAJOU']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'ENTRAINING', 'GOJI']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'ENTRAINING', 'GAIJIN']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'ENTAILING', 'GOJI']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'ENTAILING', 'GAIJIN']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'ENRAGING', 'GOJI']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'ENRAGING', 'GAIJIN']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'ENLACING', 'GOJI']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'ENLACING', 'GAIJIN']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'ENGLUT', 'TRIJUGATE']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'ENGLUT', 'TRIJET']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'ENGLUT', 'TRAJECT']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'ENGLUT', 'TAJINE']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'ENGLUT', 'TAJ']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'ENGIRT', 'TRIJUGATE']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'ENGIRT', 'TRIJET']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'ENGIRT', 'TRAJECT']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'ENGIRT', 'TAJINE']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'ENGIRT', 'TAJ']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'ENGINING', 'GOJI']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'ENGINING', 'GAIJIN']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'ENGINE', 'ELECTROJET']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'ENGINE', 'EJECTA']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'ENGINE', 'EJECT']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'ENGINE', 'EJACULATE']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'ENGAGING', 'GOJI']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'ENGAGING', 'GAIJIN']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'ENG', 'GOJI']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'ENG', 'GAIJIN']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'ENCOURAGING', 'GOJI']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'ENCOURAGING', 'GAIJIN']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'ENCORING', 'GOJI']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'ENCORING', 'GAIJIN']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'ENCAGING', 'GOJI']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'ENCAGING', 'GAIJIN']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'ELONGATE', 'ELECTROJET']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'ELONGATE', 'EJECTA']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'ELONGATE', 'EJECT']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'ELONGATE', 'EJACULATE']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'ELECTROJET', 'TURTLING']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'ELECTROJET', 'TURNING']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'ELECTROJET', 'TUG']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'ELECTROJET', 'TRUING']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'ELECTROJET', 'TRUG']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'ELECTROJET', 'TRUEING']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'ELECTROJET', 'TRUCING']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'ELECTROJET', 'TROGON']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'ELECTROJET', 'TROG']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'ELECTROJET', 'TRINING']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'ELECTROJET', 'TRIJUGATE']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'ELECTROJET', 'TRIGON']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'ELECTROJET', 'TRIGO']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'ELECTROJET', 'TRIG']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'ELECTROJET', 'TRICING']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'ELECTROJET', 'TRIALOGUE']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'ELECTROJET', 'TRIALING']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'ELECTROJET', 'TRIAGING']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'ELECTROJET', 'TRAINING']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'ELECTROJET', 'TRAILING']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'ELECTROJET', 'TRAGICAL']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'ELECTROJET', 'TRAGIC']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'ELECTROJET', 'TRAGI']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'ELECTROJET', 'TRACING']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'ELECTROJET', 'TETRAGON']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'ELECTROJET', 'TENONING']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'ELECTROJET', 'TELEOLOGICAL']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'ELECTROJET', 'TELEOLOGIC']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'ELECTROJET', 'TEARING']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'ELECTROJET', 'TARING']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'ELECTROJET', 'TAILORING']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'ELECTROJET', 'TAILING']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'ELECTROJET', 'TAILGATE']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'ELECTROJET', 'TAIGA']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'ELECTROJET', 'TAGLINE']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'ELECTROJET', 'TAGINE']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'ELECTROJET', 'TAGALONG']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'ELECTROJET', 'TAG']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'EJECTA', 'ARUGULA']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'EJECTA', 'ARUGOLA']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'EJECTA', 'ARCING']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'EJECTA', 'ALONG']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'EJECTA', 'ALOGICAL']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'EJECTA', 'ALINING']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'EJECTA', 'ALIGNING']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'EJECTA', 'ALIGN']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'EJECTA', 'ALIENING']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'EJECTA', 'ALGOR']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'EJECTA', 'ALGOLOGICAL']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'EJECTA', 'ALGOLAGNIAC']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'EJECTA', 'ALGOLAGNIA']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'EJECTA', 'ALGIN']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'EJECTA', 'ALGAL']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'EJECTA', 'ALGAE']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'EJECTA', 'ALGA']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'EJECTA', 'AJUGA']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'EJECTA', 'AIRING']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'EJECTA', 'AILING']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'EJECTA', 'AIGLET']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'EJECTA', 'AGUE']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'EJECTA', 'AGORAE']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'EJECTA', 'AGORA']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'EJECTA', 'AGONIC']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'EJECTA', 'AGONE']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'EJECTA', 'AGON']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'EJECTA', 'AGOG']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'EJECTA', 'AGO']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'EJECTA', 'AGLU']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'EJECTA', 'AGLET']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'EJECTA', 'AGING']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'EJECTA', 'AGIN']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'EJECTA', 'AGILE']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'EJECTA', 'AGATE']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'EJECTA', 'AGARIC']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'EJECTA', 'AGAR']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'EJECTA', 'AGAIN']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'EJECTA', 'AGA']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'EJECTA', 'ACING']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'EJECT', 'TURTLING']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'EJECT', 'TURNING']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'EJECT', 'TUG']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'EJECT', 'TRUING']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'EJECT', 'TRUG']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'EJECT', 'TRUEING']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'EJECT', 'TRUCING']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'EJECT', 'TROGON']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'EJECT', 'TROG']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'EJECT', 'TRINING']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'EJECT', 'TRIJUGATE']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'EJECT', 'TRIGON']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'EJECT', 'TRIGO']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'EJECT', 'TRIG']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'EJECT', 'TRICING']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'EJECT', 'TRIALOGUE']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'EJECT', 'TRIALING']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'EJECT', 'TRIAGING']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'EJECT', 'TRAINING']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'EJECT', 'TRAILING']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'EJECT', 'TRAGICAL']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'EJECT', 'TRAGIC']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'EJECT', 'TRAGI']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'EJECT', 'TRACING']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'EJECT', 'TETRAGON']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'EJECT', 'TENONING']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'EJECT', 'TELEOLOGICAL']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'EJECT', 'TELEOLOGIC']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'EJECT', 'TEARING']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'EJECT', 'TARING']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'EJECT', 'TAILORING']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'EJECT', 'TAILING']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'EJECT', 'TAILGATE']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'EJECT', 'TAIGA']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'EJECT', 'TAGLINE']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'EJECT', 'TAGINE']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'EJECT', 'TAGALONG']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'EJECT', 'TAG']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'EJACULATE', 'EULOGIAE']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'EJACULATE', 'EULOGIA']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'EJACULATE', 'ENTRAINING']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'EJACULATE', 'ENTAILING']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'EJACULATE', 'ENRAGING']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'EJACULATE', 'ENOLOGICAL']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'EJACULATE', 'ENLACING']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'EJACULATE', 'ENGLUT']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'EJACULATE', 'ENGLACIAL']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'EJACULATE', 'ENGIRT']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'EJACULATE', 'ENGINING']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'EJACULATE', 'ENGINE']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'EJACULATE', 'ENGAGING']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'EJACULATE', 'ENG']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'EJACULATE', 'ENCOURAGING']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'EJACULATE', 'ENCORING']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'EJACULATE', 'ENCAGING']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'EJACULATE', 'ELONGATE']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'EJACULATE', 'ECOLOGICAL']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'EJACULATE', 'ECOLOGIC']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'EJACULATE', 'EARNING']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'EJACULATE', 'EARING']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'EJACULATE', 'EAGLING']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'EJACULATE', 'EAGLET']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'EJACULATE', 'EAGLE']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'ECOLOGIC', 'CONJUROR']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'ECOLOGIC', 'CONJURING']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'ECOLOGIC', 'CONJUGATE']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'ECOLOGIC', 'CONJUGAL']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'ECOLOGIC', 'CONJECTURING']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'ECOLOGIC', 'CONJECTURAL']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'ECOLOGIC', 'CARCAJOU']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'ECOLOGIC', 'CAJON']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'ECOLOGIC', 'CAJOLING']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'ECOLOGIC', 'CAJOLE']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'EARNING', 'GOJI']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'EARNING', 'GAIJIN']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'EARING', 'GOJI']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'EARING', 'GAIJIN']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'EAGLING', 'GOJI']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'EAGLING', 'GAIJIN']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'EAGLET', 'TRIJUGATE']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'EAGLET', 'TRIJET']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'EAGLET', 'TRAJECT']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'EAGLET', 'TAJINE']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'EAGLET', 'TAJ']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'EAGLE', 'ELECTROJET']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'EAGLE', 'EJECTA']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'EAGLE', 'EJECT']
# Puzzle Solved! Depth =  3   ['CORNICULATE', 'EAGLE', 'EJACULATE']
# Puzzle Solved! Depth =  2   ['CONJECTURING', 'GULAR']
# Puzzle Solved! Depth =  2   ['CONJECTURING', 'GULAG']
# Puzzle Solved! Depth =  2   ['CONJECTURING', 'GORAL']
# Puzzle Solved! Depth =  2   ['CONJECTURING', 'GOALING']
# Puzzle Solved! Depth =  2   ['CONJECTURING', 'GOALIE']
# Puzzle Solved! Depth =  2   ['CONJECTURING', 'GOAL']
# Puzzle Solved! Depth =  2   ['CONJECTURING', 'GLUTEAL']
# Puzzle Solved! Depth =  2   ['CONJECTURING', 'GLUCAGON']
# Puzzle Solved! Depth =  2   ['CONJECTURING', 'GLORIA']
# Puzzle Solved! Depth =  2   ['CONJECTURING', 'GLOAT']
# Puzzle Solved! Depth =  2   ['CONJECTURING', 'GLIAL']
# Puzzle Solved! Depth =  2   ['CONJECTURING', 'GLIA']
# Puzzle Solved! Depth =  2   ['CONJECTURING', 'GLARING']
# Puzzle Solved! Depth =  2   ['CONJECTURING', 'GLAIRING']
# Puzzle Solved! Depth =  2   ['CONJECTURING', 'GLAIR']
# Puzzle Solved! Depth =  2   ['CONJECTURING', 'GLACIATE']
# Puzzle Solved! Depth =  2   ['CONJECTURING', 'GLACIAL']
# Puzzle Solved! Depth =  2   ['CONJECTURING', 'GLACEING']
# Puzzle Solved! Depth =  2   ['CONJECTURING', 'GLACE']
# Puzzle Solved! Depth =  2   ['CONJECTURING', 'GINGAL']
# Puzzle Solved! Depth =  2   ['CONJECTURING', 'GARLIC']
# Puzzle Solved! Depth =  2   ['CONJECTURING', 'GAOLING']
# Puzzle Solved! Depth =  2   ['CONJECTURING', 'GAOL']
# Puzzle Solved! Depth =  2   ['CONJECTURING', 'GALINGALE']
# Puzzle Solved! Depth =  2   ['CONJECTURING', 'GALING']
# Puzzle Solved! Depth =  2   ['CONJECTURING', 'GALENICAL']
# Puzzle Solved! Depth =  2   ['CONJECTURING', 'GALENIC']
# Puzzle Solved! Depth =  2   ['CONJECTURING', 'GALEATE']
# Puzzle Solved! Depth =  2   ['CONJECTURING', 'GALEAE']
# Puzzle Solved! Depth =  2   ['CONJECTURING', 'GALEA']
# Puzzle Solved! Depth =  2   ['CONJECTURING', 'GALE']
# Puzzle Solved! Depth =  2   ['CONJECTURING', 'GALATEA']
# Puzzle Solved! Depth =  2   ['CONJECTURING', 'GALAGO']
# Puzzle Solved! Depth =  2   ['CONJECTURING', 'GALA']
# Puzzle Solved! Depth =  2   ['CONJECTURING', 'GAL']
# Puzzle Solved! Depth =  2   ['CONJECTURAL', 'LURING']
# Puzzle Solved! Depth =  2   ['CONJECTURAL', 'LUGING']
# Puzzle Solved! Depth =  2   ['CONJECTURAL', 'LOURING']
# Puzzle Solved! Depth =  2   ['CONJECTURAL', 'LONGLINING']
# Puzzle Solved! Depth =  2   ['CONJECTURAL', 'LONGLINE']
# Puzzle Solved! Depth =  2   ['CONJECTURAL', 'LONGING']
# Puzzle Solved! Depth =  2   ['CONJECTURAL', 'LONGICORN']
# Puzzle Solved! Depth =  2   ['CONJECTURAL', 'LOGOCENTRIC']
# Puzzle Solved! Depth =  2   ['CONJECTURAL', 'LOGIN']
# Puzzle Solved! Depth =  2   ['CONJECTURAL', 'LOGICAL']
# Puzzle Solved! Depth =  2   ['CONJECTURAL', 'LOGIC']
# Puzzle Solved! Depth =  2   ['CONJECTURAL', 'LOGIA']
# Puzzle Solved! Depth =  2   ['CONJECTURAL', 'LINING']
# Puzzle Solved! Depth =  2   ['CONJECTURAL', 'LINGULATE']
# Puzzle Solved! Depth =  2   ['CONJECTURAL', 'LINGULAR']
# Puzzle Solved! Depth =  2   ['CONJECTURAL', 'LINGULAE']
# Puzzle Solved! Depth =  2   ['CONJECTURAL', 'LINGULA']
# Puzzle Solved! Depth =  2   ['CONJECTURAL', 'LINGUINI']
# Puzzle Solved! Depth =  2   ['CONJECTURAL', 'LINGUINE']
# Puzzle Solved! Depth =  2   ['CONJECTURAL', 'LINGUICA']
# Puzzle Solved! Depth =  2   ['CONJECTURAL', 'LINGO']
# Puzzle Solved! Depth =  2   ['CONJECTURAL', 'LINGA']
# Puzzle Solved! Depth =  2   ['CONJECTURAL', 'LING']
# Puzzle Solved! Depth =  2   ['CONJECTURAL', 'LIGULE']
# Puzzle Solved! Depth =  2   ['CONJECTURAL', 'LIGULATE']
# Puzzle Solved! Depth =  2   ['CONJECTURAL', 'LIGULAR']
# Puzzle Solved! Depth =  2   ['CONJECTURAL', 'LIGULAE']
# Puzzle Solved! Depth =  2   ['CONJECTURAL', 'LIGULA']
# Puzzle Solved! Depth =  2   ['CONJECTURAL', 'LIGNIN']
# Puzzle Solved! Depth =  2   ['CONJECTURAL', 'LIGATURING']
# Puzzle Solved! Depth =  2   ['CONJECTURAL', 'LIGATE']
# Puzzle Solved! Depth =  2   ['CONJECTURAL', 'LICENCING']
# Puzzle Solved! Depth =  2   ['CONJECTURAL', 'LECTURING']
# Puzzle Solved! Depth =  2   ['CONJECTURAL', 'LEARNING']
# Puzzle Solved! Depth =  2   ['CONJECTURAL', 'LEAGUING']
# Puzzle Solved! Depth =  2   ['CONJECTURAL', 'LATENING']
# Puzzle Solved! Depth =  2   ['CONJECTURAL', 'LARNING']
# Puzzle Solved! Depth =  2   ['CONJECTURAL', 'LAOGAI']
# Puzzle Solved! Depth =  2   ['CONJECTURAL', 'LAIRING']
# Puzzle Solved! Depth =  2   ['CONJECTURAL', 'LACING']
# Puzzle Solved! Depth =  2   ['NEUROLOGIC', 'CONJUGATE']
# Puzzle Solved! Depth =  2   ['NEUROLOGIC', 'CONJECTURAL']
# Puzzle Solved! Depth =  2   ['NEURALGIC', 'CONJUGATE']
# Puzzle Solved! Depth =  2   ['NEURALGIC', 'CONJECTURING']
# Puzzle Solved! Depth =  2   ['NEURALGIC', 'CONJECTURAL']
# Puzzle Solved! Depth =  2   ['LOGOCENTRIC', 'CONJUGATE']
# Puzzle Solved! Depth =  2   ['LOGOCENTRIC', 'CONJUGAL']
# Puzzle Solved! Depth =  2   ['LOGOCENTRIC', 'CONJECTURAL']
# Puzzle Solved! Depth =  2   ['LOGOCENTRIC', 'CARCAJOU']
# Puzzle Solved! Depth =  2   ['ELECTRONICA', 'AJUGA']
# Puzzle Solved! Depth =  2   ['CONJUGATE', 'ELUTRIATE']
# Puzzle Solved! Depth =  2   ['CONJUGATE', 'ELECTRONICA']
# Puzzle Solved! Depth =  2   ['CONJUGATE', 'ELECTRONIC']
# Puzzle Solved! Depth =  2   ['CONJUGATE', 'ELECTRICAL']
# Puzzle Solved! Depth =  2   ['CONJUGATE', 'ELECTRIC']
# Puzzle Solved! Depth =  2   ['CINGULATE', 'ELECTROJET']
# Puzzle Solved! Depth =  2   ['ALEURONIC', 'CONJUGATE']
# Puzzle Solved! Depth =  2   ['ALEURONIC', 'CONJECTURING']
# Puzzle Solved! Depth =  2   ['TRIJUGATE', 'ENOLOGICAL']
# Puzzle Solved! Depth =  2   ['TRIJUGATE', 'ENOLIC']
# Puzzle Solved! Depth =  2   ['TRIJUGATE', 'ELECTRONICA']
# Puzzle Solved! Depth =  2   ['TRIJUGATE', 'ELECTRONIC']
# Puzzle Solved! Depth =  2   ['TRIJUGATE', 'ELECTRON']
# Puzzle Solved! Depth =  2   ['TELOCENTRIC', 'CONJUGATE']
# Puzzle Solved! Depth =  2   ['TELOCENTRIC', 'CONJUGAL']
# Puzzle Solved! Depth =  2   ['NONTRAGIC', 'CONJECTURAL']
# Puzzle Solved! Depth =  2   ['NONELECTRONIC', 'CONJUGATE']
# Puzzle Solved! Depth =  2   ['NONELECTRONIC', 'CONJUGAL']
# Puzzle Solved! Depth =  2   ['NONELECTRIC', 'CONJUGATE']
# Puzzle Solved! Depth =  2   ['NONELECTRIC', 'CONJUGAL']
# Puzzle Solved! Depth =  2   ['NEUTRONIC', 'CONJUGAL']
# Puzzle Solved! Depth =  2   ['NEUTRONIC', 'CAJOLING']
# Puzzle Solved! Depth =  2   ['LINGULATE', 'ELECTROJET']
# Puzzle Solved! Depth =  2   ['JONGLEUR', 'RICTAL']
# Puzzle Solved! Depth =  2   ['JONGLEUR', 'RAINCOAT']
# Puzzle Solved! Depth =  2   ['INTROJECT', 'TRIALOGUE']
# Puzzle Solved! Depth =  2   ['ELECTRONIC', 'CONJUGATE']
# Puzzle Solved! Depth =  2   ['ELECTRONIC', 'CONJUGAL']
# Puzzle Solved! Depth =  2   ['CONJURING', 'GLUTEAL']
# Puzzle Solved! Depth =  2   ['CONJURING', 'GLACIATE']
# Puzzle Solved! Depth =  2   ['CONJURING', 'GALEATE']
# Puzzle Solved! Depth =  2   ['CONJURING', 'GALATEA']
# Puzzle Solved! Depth =  2   ['CONJUGAL', 'LORICATE']
# Puzzle Solved! Depth =  2   ['CONJUGAL', 'LOGOCENTRIC']
# Puzzle Solved! Depth =  2   ['CONJUGAL', 'LECTURING']
# Puzzle Solved! Depth =  2   ['CONJUGAL', 'LATRINE']
# Puzzle Solved! Depth =  2   ['CONJUGAL', 'LAETRILE']
# Puzzle Solved! Depth =  2   ['CAJOLING', 'GURNET']
# Puzzle Solved! Depth =  2   ['ACROCENTRIC', 'CONJUGAL']
# Puzzle Solved! Depth =  2   ['UROLOGIC', 'CONJUGATE']
# Puzzle Solved! Depth =  2   ['UROLOGIC', 'CONJECTURAL']
# Puzzle Solved! Depth =  2   ['TELEOLOGIC', 'CONJECTURAL']
# Puzzle Solved! Depth =  2   ['OLIGURIC', 'CONJUGATE']
# Puzzle Solved! Depth =  2   ['OLIGURIC', 'CONJECTURAL']
# Puzzle Solved! Depth =  2   ['NONJURING', 'GLACIATE']
# Puzzle Solved! Depth =  2   ['NONGUILT', 'TRAJECT']
# Puzzle Solved! Depth =  2   ['NONCALORIC', 'CONJUGATE']
# Puzzle Solved! Depth =  2   ['NONCALORIC', 'CONJECTURING']
# Puzzle Solved! Depth =  2   ['NEOLOGIC', 'CONJECTURAL']
# Puzzle Solved! Depth =  2   ['LINOCUT', 'TRIJUGATE']
# Puzzle Solved! Depth =  2   ['LINGULAE', 'ELECTROJET']
# Puzzle Solved! Depth =  2   ['JUGULATE', 'ENCOURAGING']
# Puzzle Solved! Depth =  2   ['JUGULATE', 'ENCORING']
# Puzzle Solved! Depth =  2   ['JUGULATE', 'ELECTRONICA']
# Puzzle Solved! Depth =  2   ['JUGULATE', 'ELECTRONIC']
# Puzzle Solved! Depth =  2   ['JOCULAR', 'ROUTEING']
# Puzzle Solved! Depth =  2   ['JOCULAR', 'RINGLET']
# Puzzle Solved! Depth =  2   ['JACULATE', 'ENCOURAGING']
# Puzzle Solved! Depth =  2   ['JACULATE', 'ENCORING']
# Puzzle Solved! Depth =  2   ['JACONET', 'TURTLING']
# Puzzle Solved! Depth =  2   ['JACONET', 'TRIALOGUE']
# Puzzle Solved! Depth =  2   ['GALENIC', 'CONJECTURING']
# Puzzle Solved! Depth =  2   ['GALENIC', 'CONJECTURAL']
# Puzzle Solved! Depth =  2   ['EJACULATE', 'ENCOURAGING']
# Puzzle Solved! Depth =  2   ['EJACULATE', 'ENCORING']
# Puzzle Solved! Depth =  2   ['CONCENTRIC', 'CONJUGAL']
# Puzzle Solved! Depth =  2   ['CATALOGIC', 'CONJECTURING']
# Puzzle Solved! Depth =  2   ['CATALOGIC', 'CONJECTURAL']
# Puzzle Solved! Depth =  2   ['ALGOLAGNIAC', 'CONJECTURING']
# Puzzle Solved! Depth =  2   ['ALGOLAGNIAC', 'CONJECTURAL']
# Puzzle Solved! Depth =  2   ['ACENTRIC', 'CONJUGAL']
# Puzzle Solved! Depth =  2   ['TRAGIC', 'CONJECTURAL']
# Puzzle Solved! Depth =  2   ['ONCOLOGIC', 'CONJECTURAL']
# Puzzle Solved! Depth =  2   ['NONELECT', 'TRIJUGATE']
# Puzzle Solved! Depth =  2   ['LACONIC', 'CONJECTURING']
# Puzzle Solved! Depth =  2   ['JUGATE', 'ELECTRONICA']
# Puzzle Solved! Depth =  2   ['JUGATE', 'ELECTRONIC']
# Puzzle Solved! Depth =  2   ['INJECT', 'TRIALOGUE']
# Puzzle Solved! Depth =  2   ['GLUCINIC', 'CONJECTURAL']
# Puzzle Solved! Depth =  2   ['GARLIC', 'CONJUGATE']
# Puzzle Solved! Depth =  2   ['GARLIC', 'CONJECTURING']
# Puzzle Solved! Depth =  2   ['GARLIC', 'CONJECTURAL']
# Puzzle Solved! Depth =  2   ['ELECTRIC', 'CONJUGATE']
# Puzzle Solved! Depth =  2   ['ELECTRIC', 'CONJUGAL']
# Puzzle Solved! Depth =  2   ['ECOLOGIC', 'CONJECTURAL']
# Puzzle Solved! Depth =  2   ['COELIAC', 'CONJECTURING']
# Puzzle Solved! Depth =  2   ['CENTRIC', 'CONJUGAL']
# Puzzle Solved! Depth =  2   ['CALORIC', 'CONJUGATE']
# Puzzle Solved! Depth =  2   ['CALORIC', 'CONJECTURING']
# Puzzle Solved! Depth =  2   ['ATELIC', 'CONJURING']
# Puzzle Solved! Depth =  2   ['ATELIC', 'CONJECTURING']
# Puzzle Solved! Depth =  2   ['AGONIC', 'CONJECTURAL']
# Puzzle Solved! Depth =  2   ['LOGIC', 'CONJECTURAL']
# Puzzle Solved! Depth =  2   ['JURAL', 'LOGOCENTRIC']
# Puzzle Solved! Depth =  2   ['JUGULA', 'ACROCENTRIC']
# Puzzle Solved! Depth =  2   ['JUGAL', 'LOGOCENTRIC']
# Puzzle Solved! Depth =  2   ['ILEAC', 'CONJECTURING']
# Puzzle Solved! Depth =  2   ['CELIAC', 'CONJECTURING']
# Puzzle Solved! Depth =  2   ['AGARIC', 'CONJECTURAL']
# Puzzle Solved! Depth =  2   ['LILAC', 'CONJECTURING']
# Puzzle Solved! Depth =  2   ['LAIC', 'CONJECTURING']
# Puzzle Solved! Depth =  2   ['JUCO', 'OUTLEARNING']
# Puzzle Solved! Depth =  2   ['ILIAC', 'CONJECTURING']
# Puzzle Solved! Depth =  2   ['ALEC', 'CONJECTURING']
# Puzzle Solved! Depth =  2   ['LAC', 'CONJECTURING']
# 2
