# %% [markdown]
# ## This notebook is my *from scratch* version of the 90% of NLP Problems workshop
#
# [Article](https://blog.insightdatascience.com/how-to-solve-90-of-nlp-problems-a-step-by-step-guide-fda605278e4e)
#
# [Github](https://github.com/hundredblocks/concrete_NLP_tutorial/blob/master/NLP_notebook.ipynb)

# %%
# Import libraries
import pandas as pd
import io
import re
## import nltk  ## maybe import whole package later
import nltk
from nltk.tokenize import sent_tokenize, word_tokenize
nltk.download('punkt')
from nltk.stem.porter import *
from nltk.stem import WordNetLemmatizer
nltk.download('wordnet')
import collections
# Out:
# /home/topquirk67/anaconda3/envs/insight/lib/python3.7/site-packages/sklearn/utils/__init__.py:4: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated, and in 3.8 it will stop working
#   from collections import Sequence
# [nltk_data] Downloading package punkt to /home/topquirk67/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /home/topquirk67/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
# Get the data... I just stole their code because I'm not quite sure what they need to do here
# or if the data file I fetched is correct!
input_file = io.open("socialmedia_relevant_cols.csv", "r",encoding='utf-8', errors='replace')
output_file = open("socialmedia_relevant_cols_clean.csv", "w")

def sanitize_characters(raw, clean):    
    for line in input_file:
        out = line
        output_file.write(line)
sanitize_characters(input_file, output_file)

# %%
questions = pd.read_csv("socialmedia_relevant_cols_clean.csv")
questions.columns=['text', 'choose_one', 'class_label']
questions.head(5)
# Out:
#                                                 text choose_one  class_label
# 0                 Just happened a terrible car crash   Relevant            1
# 1  Our Deeds are the Reason of this #earthquake M...   Relevant            1
# 2  Heard about #earthquake is different cities, s...   Relevant            1
# 3  there is a forest fire at spot pond, geese are...   Relevant            1
# 4             Forest fire near La Ronge Sask. Canada   Relevant            1

# %%
# A little EDA
import seaborn as sns
print(questions.class_label.value_counts())
print(questions.choose_one.value_counts())
questions[questions.isna().any(axis=1)]
# Out:
# 0    6163
# 1    4635
# 2      16
# Name: class_label, dtype: int64
# Not Relevant    6163
# Relevant        4635
# Can't Decide      16
# Name: choose_one, dtype: int64
# Empty DataFrame
# Columns: [text, choose_one, class_label]
# Index: []

# %% [markdown]
# So it seems that the classes are pretty close to balanced, and class_label is just encoded with relevant = 1; not = 0.

# %%
# Verify that data is encoded exactly correctly
pd.crosstab(questions.choose_one,questions.class_label)
# Out:
# class_label      0     1   2
# choose_one
# Can't Decide     0     0  16
# Not Relevant  6163     0   0
# Relevant         0  4635   0

# %% [markdown]
# ### Process words:
# - Remove non-alphabetical characters
# - lowercase

# %%
# Here we just use the definitions given by Ameisen
def standardize_text(df, text_field):
    df[text_field] = df[text_field].str.replace(r"http\S+", "")   
    df[text_field] = df[text_field].str.replace(r"http", "")
    df[text_field] = df[text_field].str.replace(r"@\S+", "")
    df[text_field] = df[text_field].str.replace(r"[^A-Za-z0-9(),!?@\'\`\"\_\n]", " ")
    df[text_field] = df[text_field].str.replace(r"@", "at")
    df[text_field] = df[text_field].str.lower()
    return df

questions = standardize_text(questions, "text")
# questions.to_csv("clean_data.csv")  # maybe use this later??? 
# questions.head()

# %%
questions.head()
# Out:
#                                                 text choose_one  class_label
# 0                 just happened a terrible car crash   Relevant            1
# 1  our deeds are the reason of this  earthquake m...   Relevant            1
# 2  heard about  earthquake is different cities, s...   Relevant            1
# 3  there is a forest fire at spot pond, geese are...   Relevant            1
# 4             forest fire near la ronge sask  canada   Relevant            1

# %% [markdown]
# Tokenize!

# %%
# example tokenize
sentence = questions.text[174]
tokens = nltk.word_tokenize(sentence)

# %%
tokens
# Out:
# ['aftershock',
#  'protect',
#  'yourself',
#  'and',
#  'profit',
#  'in',
#  'the',
#  'next',
#  'global',
#  'financial',
#  'meltdown',
#  'by',
#  'david',
#  'wiedemer']

# %%
# tokenize and examine the whole data frame
# NB this differs from the example, so if you re-do this, check back there 
# for alternate ways to do it
questions['tokens']=questions['text'].apply(nltk.word_tokenize)
questions.tokens.head()
# Out:
# 0            [just, happened, a, terrible, car, crash]
# 1    [our, deeds, are, the, reason, of, this, earth...
# 2    [heard, about, earthquake, is, different, citi...
# 3    [there, is, a, forest, fire, at, spot, pond, ,...
# 4        [forest, fire, near, la, ronge, sask, canada]
# Name: tokens, dtype: object

# %%
# Stemming... others to try: SnowBall, Lancaster
stemmer = PorterStemmer()

# %%
## Just an example of doing stemming:
# plurals = ['caresses', 'flies', 'dies', 'mules', 'denied',
# ...            'died', 'agreed', 'owned', 'humbled', 'sized',
# ...            'meeting', 'stating', 'siezing', 'itemization',
# ...            'sensational', 'traditional', 'reference', 'colonizer',
# ...            'plotted']

# singles = [stemmer.stem(plural) for plural in plurals]

# print(' '.join(singles))

# %%
# Produce stemmed column
questions['stems'] = [[stemmer.stem(item) for item in row] for row in questions['tokens']]

# %%
# can't find a pythonic way to do this!
# but look for a non-stemmed word and see if it's present.
s = 'fire'
for index, row in questions.iterrows():
    if (s in row.stems):
        print(index, row['stems'])
# Out:
# 3 ['there', 'is', 'a', 'forest', 'fire', 'at', 'spot', 'pond', ',', 'gees', 'are', 'flee', 'across', 'the', 'street', ',', 'i', 'can', 'not', 'save', 'them', 'all']
# 4 ['forest', 'fire', 'near', 'la', 'rong', 'sask', 'canada']
# 8 ['rockyfir', 'updat', 'california', 'hwi', '20', 'close', 'in', 'both', 'direct', 'due', 'to', 'lake', 'counti', 'fire', 'cafir', 'wildfir']
# 13 ['i', "'m", 'on', 'top', 'of', 'the', 'hill', 'and', 'i', 'can', 'see', 'a', 'fire', 'in', 'the', 'wood']
# 46 ['birmingham', 'wholesal', 'market', 'is', 'ablaz', 'bbc', 'news', 'fire', 'break', 'out', 'at', 'birmingham', "'s", 'wholesal', 'market']
# 91 ['steve', 'these', 'fire', 'out', 'here', 'are', 'someth', 'els', '!', 'california', 'is', 'a', 'tinderbox', 'and', 'thi', 'clown', 'wa', 'set', 'my', "'hood", 'ablaz']
# 93 ['huge', 'fire', 'at', 'wholesal', 'market', 'ablaz']
# 547 ['cheesehead', 'report', 'arson', 'charg', 'file', 'in', 'jackson', 'counti', 'hous', 'fire']
# 548 ['arson', 'suspect', 'link', 'to', '30', 'fire', 'caught', 'in', 'northern', 'california']
# 558 ['lo', 'angel', 'time', 'arson', 'suspect', 'link', 'to', '30', 'fire', 'caught', 'in', 'northern', 'newsintweet']
# 565 ['arson', 'suspect', 'link', 'to', '30', 'fire', 'caught', 'in', 'northern', 'california']
# 572 ['fire', 'that', 'destroy', 'charlton', 'wineri', 'rule', 'to', 'be', 'arson']
# 575 ['relaxinpr', 'miprv', 'rt', 'latim', 'arson', 'suspect', 'link', 'to', '30', 'fire', 'caught', 'in', 'northern', 'california']
# 588 ['arson', 'suspect', 'link', 'to', '30', 'fire', 'caught', 'in', 'northern', 'california', '(', 'via']
# 590 ['arson', 'suspect', 'link', 'to', '30', 'fire', 'caught', 'in', 'northern', 'california']
# 592 ['arson', 'suspect', 'link', 'to', '30', 'fire', 'caught', 'in', 'northern', 'california', 'lo', 'angel', 'time']
# 594 ['arson', 'suspect', 'link', 'to', '30', 'fire', 'caught', 'in', 'northern', 'california']
# 605 ['arsonist', 'set', 'nyc', 'vegetarian', 'restaur', 'on', 'fire', 'polic', 'newyork']
# 606 ['arson', 'suspect', 'link', 'to', '30', 'fire', 'caught', 'in', 'northern', 'california']
# 614 ['arsonist', 'arrest', 'for', 'set', 'mani', 'fire', 'watch', 'tonight', 's', 'other', 'headlin', 'nightbeat', '2minutemix']
# 635 ['arsonist', 'set', 'nyc', 'vegetarian', 'restaur', 'on', 'fire', 'polic', 'newyork']
# 643 ['trust', 'iran', 'to', 'stop', 'terror', 'is', 'like', 'invit', 'an', 'arsonist', 'to', 'join', 'the', 'fire', 'brigad', 'telegraph']
# 645 ['arson', 'suspect', 'link', 'to', '30', 'fire', 'caught', 'in', 'northern', 'california']
# 741 ['but', 'then', 'the', 'fire', 'nation', 'attack']
# 938 ['pendleton', 'media', 'offic', 'said', 'onli', 'fire', 'on', 'base', 'right', 'now', 'is', 'the', 'horno', 'blaze']
# 950 ['port', 'coquitlam', 'fire', 'crew', 'say', 'an', 'electr', 'towel', 'warmer', 'start', 'the', 'four', 'alarm', 'blaze', 'last', 'week', 'that', 'destroy', 'sever', 'busi']
# 964 ['properti', 'loss', 'from', 'california', 'wildfir', 'nearli', 'doubl', 'as', 'week', 'old', 'blaze', 'rage', 'the', 'fire', '_']
# 1016 ['satelit', 'shot', 'seri', 'of', 'wildfir', 'in', 'northern', 'california', 'continu', 'blaze', 'there', 'are', 'at', 'least', 'five', 'fire', 'compl']
# 1028 ['california', 'is', 'hot', 'but', 'not', 'blaze', 'even', 'though', 'there', 'are', 'wildfir', 'go', 'on', 'now', 'even', 'the', 'big', 'massiv', 'rocki', 'fire']
# 1094 ['max', 'blew', 'tf', 'up', '!', '?', '?', '?', '?', '?', '?', 'shot', 'fire', '?', '?', '?', '?', 'catfishmtv']
# 1197 ['gunnar', 'optik', 'hero', 'of', 'the', 'storm', 'sieg', 'game', 'glass', 'onyx', 'fire', 'wow', 'blizzard', 'full', 're', '_']
# 1675 ['sioux', 'citi', 'fire', 'offici', 'believ', 'bridg', 'collaps', 'lead', 'to', 'cement', 'truck', 'roll', 'over', 'siouxland', 'matter', 'siouxlan']
# 1735 ['the', 'rocki', 'fire', 'burn', 'in', 'northern', 'california', 'is', 'still', 'threaten', 'more', 'than', '7000', 'build', 'it', "'s", 'the', 'largest', 'in', 'the', 'state', '9newsmorn']
# 1748 ['port', 'coquitlam', 'fire', 'burn', 'sever', 'busi']
# 1756 ['my', 'jealou', 'tear', 'are', 'burn', 'with', 'the', 'fire', 'of', 'a', 'thousand', 'ransack', 'build', 'so', 'awesomeeeeeee']
# 1758 ['the', 'fire', 'brigad', 'should', 'play', 'thi', 'guy', 'music', 'at', 'burn', 'build', 'to', 'put', 'the', 'flame', 'out']
# 1764 ['two', 'build', 'burn', 'in', '3', 'alarm', 'antioch', 'fire', 'two', 'build', 'are', 'burn', 'in', 'a', '3', 'alarm', 'fire', 'at', 'the', 'delta', 'pine', '_']
# 1771 ['fire', 'hazard', 'associ', 'with', 'instal', 'of', 'non', 'compliant', 'extern', 'clad', 'on', 'by']
# 1773 ['fire', 'hazard', 'associ', 'with', 'instal', 'of', 'non', 'compliant', 'extern', 'clad', 'on', 'by']
# 1774 ['video', 'fire', 'burn', 'two', 'apart', 'build', 'and', 'blow', 'up', 'car', 'in', 'manchest']
# 1775 ['fire', 'destroy', 'two', 'build', 'on', '2nd', 'street', 'in', 'manchest']
# 1776 ['multipl', 'build', 'on', 'fire', 'in', 'downtown', 'hinton']
# 1777 ['jane', 'kelsey', 'on', 'the', 'fire', 'economi', '5th', 'aug', '5', '30', '7', '30pm', 'old', 'govt', 'build', 'wgton', 'the', 'context', 'amp', 'the', 'driver', 'for', 'tpp', 'and', 'tradeinservicesagr']
# 1778 ["'failur", 'doesn', 't', 'exist', 'it', 's', 'onli', 'a', 'chang', 'of', 'direct', "'", 'alejandro', 'jodorowski', '(', 'via', 'build', 'on', 'fire', ')']
# 1779 ['build', 'are', 'on', 'fire', 'and', 'they', 'have', 'time', 'for', 'a', 'busi', 'meet', 'thestrain']
# 1780 ['ton', 'of', 'smoke', 'come', 'out', 'of', 'one', 'of', 'the', 'new', 'apart', 'build', 'at', '160', 'ross', 'in', 'auburn', 'sever', 'fire', 'truck', 'on', 'scene']
# 1781 ['i', "'m", 'secur', 'so', 'they', 'want', 'me', 'to', 'help', 'out', 'in', 'case', 'of', 'emerg', 'like', 'the', 'build', 'on', 'fire', 'or', 'a', 'shooter', "'s", 'in', 'the', 'build', 'i', "'m", 'leav', 'tho']
# 1782 ['that', 'what', 'i', 'would', 'do', 'if', 'there', 'were', 'build', 'on', 'fire']
# 1783 ['fuck', 'apart', 'across', 'the', 'street', 'are', 'on', 'fire', 'right', 'now', '5', 'fuckin', 'firetruck', 'wtf', 'thi', 'is', 'the', 'second', 'time', 'those', 'build', 'caught', 'on', 'fire']
# 1784 ['squar', 'just', 'let', 'booti', 'org', 'write', 'xv', 'im', 'sure', 'we', "'d", 'do', 'just', 'fine', '(', 'build', 'around', 'me', 'set', 'on', 'fire', ')']
# 1785 ['it', "'s", 'a', 'testimoni', 'to', 'the', 'human', 'spirit', 'that', 'more', 'of', 'us', 'do', "n't", 'set', 'fire', 'to', 'our', 'offic', 'build', 'on', 'sunday', 'night']
# 1786 ['smoke', 'detector', 'not', 'requir', 'in', 'all', 'build', 'an', 'offic', 'build', 'on', 'shevlin', 'hixon', 'drive', 'wa', 'on', 'fire', 'there', 'we']
# 1787 ['someon', 'mention', 'gansey', 'on', 'fire', 'me', 'bust', 'through', 'the', 'brick', 'wall', 'of', 'seven', 'differ', 'build']
# 1788 ['there', 'are', 'multipl', 'build', 'on', 'fire', 'in', 'downtown', 'hinton', 'ok', 'the', 'fire', 'is', 'threaten', 'to', 'level', 'the', 'entir', 'block', '!', '8nn']
# 1789 ['such', 'beauti', 'architectur', 'in', 'nyc', 'i', 'love', 'those', 'fire', 'escap', 'rout', 'on', 'the', 'build', 'newyork', '_']
# 1790 ['tweetlikeitsseptember11th2001', 'those', 'two', 'build', 'are', 'on', 'fire']
# 1791 ['just', 'in', 'kenya', 'sever', 'build', 'are', 'report', 'to', 'be', 'on', 'fire', 'close', 'to', 'dam', 'estat', 'langata', 'at', '2', '22pm']
# 1792 ['they', 'are', 'evacu', 'build', 'in', 'that', 'area', 'of', 'state', 'road', '20', 'we', 'still', 'do', "n't", 'have', 'confirm', 'of', 'what', 'is', 'on', 'fire']
# 1793 ['dnr', 're', 'build', 'shell', 'amp', 'on', 'fire', 'in', 'gorlovka', 'tonight', 'civilian', 'casualti', 'jan', 'juli', '2015', '164', 'kill', '(', 'incl', '16', 'children', ')', '501', 'wound']
# 1794 ['lighten', 'struck', 'amp', '2', 'unit', 'in', '1', 'of', 'our', 'build', 'in', 'our', 'develop', 'on', 'fire', 'groton', 'ct', 'check', 'out', 'my', 'fb', 'wall', 'most', 'recent', 'post']
# 1795 ['taiz', 'houthi', 'saleh', 'indiscrimin', 'shell', 'from', 'castl', 'set', 'tahreer', 'st', 'build', 'on', 'fire', 'yemen']
# 1796 ['shoot', 'explos', 'hand', 'grenad', 'thrown', 'at', 'car', 'and', 'hous', 'amp', 'vehicl', 'and', 'build', 'set', 'on', 'fire', 'it', 'all', 'just', 'baffl', 'me', 'is', 'thi', 'sweden', '?']
# 1797 ['build', 'on', 'fire', 'behind', 'tisa', "'s", 'in', 'nicevil']
# 1798 ['a', 'chang', 'in', 'the', 'state', 'fire', 'code', 'prohibit', 'grill', 'on', 'deck', 'at', 'condo', 'and', 'apart', 'build', 'check', 'with', 'your']
# 1799 ['fire', 'hazard', 'associ', 'with', 'instal', 'of', 'non', 'compliant', 'extern', 'clad', 'on', 'high', 'rise', 'build', 'insur', 'aust']
# 1800 ['two', 'build', 'involv', 'in', 'fire', 'on', '2nd', 'street', 'in', 'manchest', 'wmur']
# 1801 ['agricultur', 'build', 'on', 'fire', 'aldwark', 'nyork', 'fire', 'amp', 'rescu', 'servic', 'still', 'grim', 'news', 'but', 'fewer', 'piglet', 'caught', 'up']
# 1802 ['fire', 'displac', 'famili', 'and', 'damag', 'two', 'build', 'in', 'troy', 'fire', 'broke', 'out', 'on', 'fourth', 'street', 'in', '_', 'albani', 'ny', 'news']
# 1803 ['what', 'news', 'report', 'am', 'i', 'miss', '?', 'are', 'there', 'build', 'on', 'fire', 'peopl', 'shot', 'etc', 'due', 'to', 'video', '?', 'ppsellsbabypart']
# 1804 ['so', 'my', 'band', 'build', 'on', 'fire', 'are', 'play', 'thi', 'wednesday', 'with', 'rdg']
# 1805 ['multipl', 'firefight', 'hospit', 'after', 'fight', 'a', 'fire', 'manchest', 'nh', '7new']
# 1806 ['there', 'are', 'multipl', 'build', 'on', 'fire', 'in', 'downtown', 'hinton', 'ok', 'the', 'fire', 'is', 'threaten', 'to', 'level', 'the', 'entir', 'block', '!', '8nn']
# 1807 ['tweetlikeitsseptember11th2001', 'those', 'two', 'build', 'are', 'on', 'fire']
# 1808 ['now', 'on', 'photo', 'flame', 'rage', 'through', 'manchest', 'build', 'in', '3', 'alarm', 'fire', 'nh1new']
# 1809 ['nah', 'philli', 'pundit', 'are', 'half', 'the', 'caus', 'they', 'set', 'build', 'on', 'fire', 'to', 'report', 'on', 'build', 'be', 'on', 'fire']
# 1810 ['mafireem', 'rt', 'wmur9', 'two', 'build', 'involv', 'in', 'fire', 'on', '2nd', 'street', 'in', 'manchest', 'wmur9', 'via', 'kcarosawmur']
# 1811 ['now', 'on', 'wsl', 'fire', 'burn', 'multipl', 'build', 'in', 'montgomeri', 'co', 'tip', 'to', 'make', 'childcar', 'less', 'expens', 'amp', 'rain', 'join']
# 1812 ['i', 'just', 'want', 'to', 'watch', 'paper', 'town', 'but', 'the', 'build', 'on', 'fire', '?', '?', '?', '?', '?']
# 1813 ['i', 'hope', 'the', 'onli', 'time', 'i', 'end', 'up', 'on', 'tv', 'is', 'when', 'i', "'m", 'be', 'arrest', 'for', 'light', 'build', 'on', 'fire']
# 1814 ['char', 'remain', 'of', 'home', 'on', '2nd', 'st', 'in', 'manchest', 'nh', 'after', 'fire', 'rip', 'through', '2', 'build', 'damag', 'neighbor', 'home']
# 1815 ['three', 'alarm', 'fire', 'destroy', 'two', 'residenti', 'build', 'a', 'car', 'in', 'manchest', 'n', 'h', 'on', 'sunday', 'afternoon']
# 1816 ['1943', 'poland', 'work', 'parti', 'prison', 'in', 'the', 'nazi', 'death', 'camp', 'treblinka', 'rebel', 'seiz', 'small', 'arm', 'and', 'set', 'build', 'on', 'fire', 'histori']
# 1817 ['17', 'peopl', 'displac', 'after', '3', 'alarm', 'fire', 'tore', 'through', '2', 'apart', 'build', 'on', 'second', 'street', 'in', 'manchest', 'mht']
# 1818 ['hinton', 'citi', 'offici', 'confirm', 'multipl', 'build', 'on', 'fire', 'current', 'evacu', 'peopl', 'on', 'main', 'street', 'we', "'re", 'on', 'our', 'way']
# 1819 ['my', 'happi', 'pension', 'stori', 'safe', 'build', 'watch', 'a', 'report', 'on', 'unsaf', 'clad', 'catch', 'fire', 'in', 'melbourn', 'same']
# 1820 ['multipl', 'hous', 'build', 'on', 'fire', 'in', 'kalispel']
# 1822 ['fire', 'burn', 'on', 'pendleton', 'ha', 'burn', '300', 'acr', 'smoke', 'report', 'drift', 'over', 'temecula']
# 1825 ['famili', 'heartbroken', 'mobil', 'home', 'at', 'nelli', 'amp', 'cheyenn', 'burn', 'in', 'fire', 'kid', 'were', 'all', 'readi', 'to', 'go', 'back', '2', 'school']
# 1826 ['uh', 'huh', 'you', 'onli', 'have', 'to', 'be', 'burn', 'onc', 'to', 'know', 'fire', 'hurt', 'robbi', 'ross', 'should', 'throw', 'home', 'run', 'derbi', 'in', 'the', 'all', 'star', 'game', 'redsox']
# 1838 ['sure', 'take', 'them', 'away', 'from', 'fire', 'fight', 'for', 'king', 'stevi', 'amp', 'crusti', 'to', 'have', 'a', 'photo', 'op', '!']
# 1861 ['mad', 'river', 'complex', 'fire', 'have', 'burn', '14028', 'acr', '8', 'contain', 'the', 'mad', 'river', 'complex', 'fire', 'in', 'triniti', 'counti']
# 1867 ['so', 'keep', 'call', 'me', 'crazi', 'caus', 'i', 'never', 'learn', 'you', 'should', 'stop', 'love', 'fire', 'becaus', 'you', 'got', 'burn', '_']
# 1870 ['metal', 'cut', 'spark', 'brush', 'fire', 'in', 'brighton', 'a', 'brush', 'fire', 'that', 'wa', 'spark', 'by', 'a', 'landown', 'cut', 'metal', 'burn', '10', '_']
# 1871 ['hermancranston', 'wire', 'all', 'these', 'fire', 'are', 'burn', 'through', 'firefight', "'", 'budget', '_', '_']
# 1872 ['psa', 'i', 'chop', '3', 'jalapeno', 'amp', 'my', 'finger', 'were', 'burn', 'lava', 'on', 'fire', 'pain', 'for', '5', 'hr', 'thi', 'is', 'a', 'first', '!', 'wear', 'glove', '!', 'pepper', 'from', 'hell']
# 1878 ['hermancranston', 'atk', 'letsfootbal', 'rt', 'skanndtyagi', 'letsfootbal', 'atk', 'wire', 'all', 'these', 'fire', 'are', 'burn', 'through', '_']
# 1890 ['flame', 'visibl', 'from', 'fire', 'in', 'tucson', 'mountain', 'a', 'lightn', 'caus', 'fire', 'burn', 'in', 'steep', 'rocki', 'terrain', 'in', 'mountain', '_']
# 1903 ['fear', 'the', 'fever', 'can', 'you', 'feel', 'it', 'now', '?', 'i', 'feel', 'the', 'fire', 'burn', 'belo', 'ooow', 'it', "'s", 'gon', 'na', 'trick', 'ya', 'swallow', 'you', 'who', 'ooo', 'ole', 'mtvhottest', 'justin', 'bieber']
# 1911 ['whi', 'put', 'out', 'a', 'fire', 'that', "'s", 'still', 'burn', '?']
# 1930 ['three', 'alarm', 'fire', 'burn', 'in', 'antioch', 'apart', 'complex']
# 1944 ['the', 'rocki', 'fire', 'burn', 'in', 'ca', 'still', 'threaten', 'more', 'than', '7k', 'build', 'largest', 'in', 'state', 'amp', 'one', 'of', 'nearli', '2', 'dozen', 'burn', 'now', '9newsmorn']
# 1952 ['larg', 'fire', 'burn', 'sever', 'build', 'caus', 'evacu', 'in', 'downtown', 'hinton']
# 1954 ['heavi', 'smoke', 'pour', 'out', 'of', 'build', 'on', 'fire', 'in', 'port', 'coquitlam']
# 1965 ["'", 'i', 'never', 'understood', 'guy', 'who', 'want', 'to', 'run', 'into', 'burn', 'build', "'", "'you", 'chase', 'murder', "'", "'not", 'if', 'they', "'re", 'on', 'fire', "'"]
# 1970 ['what', 'if', 'we', 'use', 'drone', 'to', 'help', 'firefight', 'lead', 'peopl', 'out', 'of', 'burn', 'build', 'help', 'put', 'the', 'fire', 'out', '?']
# 1971 ['insan', 'bush', 'fire', 'in', 'california', 'be', 'safe']
# 1972 ['would', 'you', 'pleas', 'explain', 'what', 'you', 'are', 'go', 'to', 'do', 'about', 'the', 'volcano', 'amp', 'bush', 'fire', 'spout', 'all', 'that', 'co2', 'into', 'the', 'air', '?']
# 1973 ['middl', 'of', 'winter', 'in', 'sydney', 'we', 'have', 'had', 'snow', 'bush', 'fire', 'and', '78', 'degre', 'day', 'in', 'the', 'last', 'week', 'keep', 'you', 'on', 'your', 'toe', 'for', 'sure']
# 1975 ['ted', 'cruz', 'fire', 'back', 'at', 'jeb', 'amp', 'bush', 'we', 'lose', 'becaus', 'of', 'republican', 'like', 'jeb', 'amp', 'mitt', 'video']
# 1976 ['omfg', 'there', 'are', 'bush', 'fire', 'all', 'over', 'thi', 'tini', 'island', 'our', 'freak', 'hous', 'is', 'gon', 'na', 'burn', 'down']
# 1977 ['soar', 'temperatur', "'s", 'in', 'some', 'southern', 'us', 'state', 'caus', 'bush', 'fire', 'piti', 'onli', 'allow', 'rain', 'in', 'scotland', 'tweetlikekez']
# 1978 ['you', 'know', 'it', "'s", 'hot', 'when', 'there', 'are', 'bush', 'fire', 'right', 'near', 'your', 'villa', '?', '?', '?', '?']
# 1979 ['slash', 'and', 'burn', 'blame', 'for', 'bush', 'fire', 'in', 'western', 'st', 'thoma']
# 1980 ['drought', 'fuel', 'bush', 'fire', 'in', 'jamaica', 're']
# 1981 ['ted', 'cruz', 'fire', 'back', 'at', 'jeb', 'amp', 'bush', 'we', 'lose', 'becaus', 'of', 'republican', 'like', 'jeb', 'amp', 'mitt', 'video']
# 1982 ['bushfir', 'caus', 'first', 'victim', 'in', 'albania', 'the', 'multipl', 'fire', 'in', 'albania', 'have', 'caus', 'the', 'first', 'vict', 'bush']
# 1983 ['seem', 'gov', 'moonbeam', 'between', 'toke', 'blame', 'bush', 'for', 'all', 'the', 'fire']
# 1984 ['drove', 'past', 'the', 'field', 'on', 'fire', 'yesterday', 'remind', 'me', 'of', 'the', 'bush', 'fire', 'we', 'use', 'to', 'get', 'in', 'south', 'africa']
# 1985 ['the', 'public', 'health', 'team', 'wa', 'traumatis', 'after', 'the', 'bush', 'fire', 'could', 'appreciativeinquiri', 'turn', 'thi', 'around', '?']
# 1987 ['on', 'holiday', 'to', 'relax', 'sunbath', 'and', 'drink', 'put', 'out', 'bush', 'fire', '?', 'not', 'so', 'much', '?', '?', 'spain']
# 1988 ['bush', 'food', 'fire']
# 1989 ['californian', 'bush', 'fire', '2015']
# 1990 ['28', 'oct', '1895', "'bush", 'fire', "'"]
# 1991 ['ohh', 'there', 'are', 'bush', 'fire', 'in', 'spain', 'like', 'everi', 'year', 'one', 'time', 'when', 'we', 'went', 'swim', 'there', 'were', 'plane', 'get', 'water', 'to', 'fight']
# 1992 ['bush', 'fire', 'are', 'scari', 'even', 'scarier', 'when', 'you', 'go', 'down', 'and', 'fight', 'them']
# 1994 ['one', 'thing', 'you', 'can', 'be', 'sure', 'of', 'there', 'will', 'never', 'be', 'bush', 'fire', 'in', 'scotland', 'as', 'the', 'ground', 'is', 'alway', 'soak', 'wet', '?', '?', '?', '?']
# 1995 ['drought', 'fuel', 'bush', 'fire', 'in', 'jamaica', 're']
# 1996 ['plea', 'for', 'global', 'warm', 'do', "n't", 'realli', 'work', 'when', 'california', 'australia', 'keep', 'have', 'catastroph', "'bush", "'", 'fire']
# 1997 ['i', 'wa', 'about', '2', 'say', 'bush', 'fire', 'in', 'au', 'but', 'the', 'reason', 'is', 'hot']
# 1998 ['bushfir', 'caus', 'first', 'victim', 'in', 'albania', 'the', 'multipl', 'fire', 'in', 'albania', 'have', 'caus', 'the', 'first', 'vict', 'bush']
# 1999 ['ted', 'cruz', 'fire', 'back', 'at', 'jeb', 'amp', 'bush', 'we', 'lose', 'becaus', 'of', 'republican', 'like', 'jeb', 'amp', 'mitt', 'video']
# 2000 ['smh', 'photograph', 'wolter', 'peeter', 'wa', 'on', 'the', 'front', 'line', 'with', 'nsw', 'rural', 'fire', 'servic', 'crew', 'la', '_']
# 2001 ['so', 'appar', 'there', 'were', 'bush', 'fire', 'near', 'where', 'i', 'live', 'over', 'the', 'weekend', 'that', 'i', 'wa', 'total', 'oblivi', 'to']
# 2002 ['if', 'you', 'like', 'goat', 'and', 'dislik', 'bush', 'fire', 'then', 'thi', 'is', 'probabl', 'the', 'video', 'for', 'you']
# 2003 ['california', 'bush', 'fire', 'pleas', 'evacu', 'affect', 'area', 'asap', 'when', 'california', 'govt', 'advis', 'you', 'to', 'do', 'so']
# 2004 ['it', 'is', 'an', 'honour', 'and', 'privleg', 'to', 'pray', 'i', 'have', 'wit', 'these', 'bush', 'fire', 'when', 'live', 'in', 'australia']
# 2005 ['how', 'much', 'co2', 'doe', 'an', 'erupt', 'volcano', 'and', 'bush', 'fire', 'rage', 'put', 'into', 'the', 'atmospher', '?', 'none', 'of', 'the', 'believ', 'mention', 'thi']
# 2006 ['ted', 'cruz', 'fire', 'back', 'at', 'jeb', 'amp', 'bush', 'we', 'lose', 'becaus', 'of', 'republican', 'like', 'jeb', 'amp', 'mitt', 'video']
# 2007 ['the', 'bush', 'fire', 'in', 'ca', 'are', 'so', 'crazi']
# 2008 ['all', 'these', 'eugen', 'fire', 'got', 'ta', 'make', 'you', 'think', 'hashtag', 'conspiraci', 'hashtag', 'popul', 'control', 'hashtag', 'bush', 'did', 'it']
# 2037 ['so', 'do', 'you', 'think', 'a', 'bunch', 'of', 'untrain', 'peopl', 'fire', 'back', 'is', "n't", 'go', 'to', 'caus', 'more', 'casualti']
# 2248 ['emerg', '4', 'harbor', 'citi', 'mod', 'v4', '5', '2', '6', 'chemic', 'fire', 'in', 'residenti', 'area', '!', 'via']
# 2380 ['video', 'link', 'to', 'the', 'billow', 'fire', 'after', 'the', 'southtown', 'lane', 'roof', 'collaps']
# 2470 ['two', 'car', 'collid', 'follow', 'shotgun', 'fire', 'in', 'denton']
# 2483 ['ssp', 'east', 'say', 'a', 'car', 'aeg', '061', 'driven', 'by', 'a', 'young', 'man', 'collid', 'with', 'akram', "'s", 'carhot', 'word', 'were', 'exchang', 'n', 'he', 'did', 'fire', 'in', 'air1bullet', 'hit', 'tyre']
# 2860 ['and', 'here', 'i', 'wa', 'complain', 'about', 'phoenix', 'mode', 'in', 'fire', 'emblem', 'turn', 'out', 'ray', 'gigant', 'will', 'have', 'a', "'difficulti", "'", 'option', 'where', 'you', 'take', '0', 'damag']
# 2911 ['red', 'flag', 'warn', 'for', 'fire', 'danger', 'amp', 'dri', 'thunderstorm', 'in', 'bay', 'area', 'weather', 'cawx', 'by']
# 2943 ['thunderstorm', 'with', 'littl', 'rain', 'expect', 'in', 'central', 'california', 'high', 'fire', 'danger', 'weather', 'cawx']
# 3359 ['demolit', '1', 'amp', '2', 'still', 'the', 'most', 'fire', 'freestyl', 'ever']
# 3577 ['and', 'the', '10', 'horn', 'which', 'u', 'saw', 'on', 'the', 'beast', 'these', 'will', 'hate', 'the', 'harlet', 'make', 'her', 'desol', 'and', 'nake', 'eat', 'her', 'flesh', 'and', 'burn', 'her', 'with', 'fire']
# 3630 ["'", 'i', 'see', 'fire', "'", 'ed', 'sheeran', 'the', 'hobbit', 'the', 'desol', 'of', 'smaug', '(', 'cover', 'by', 'ja', 'via']
# 3633 ['the', 'hobbit', 'the', 'desol', 'of', 'smaug', 'ed', 'sheeran', "'", 'i', 'see', 'fire', "'", 'hd']
# 4050 ['crew', 'were', 'out', 'all', 'day', 'board', 'up', 'window', 'at', 'the', 'park', 'at', 'the', 'galleria', 'apt', 'where', 'fire', 'displac', '55', 'thi', 'am']
# 4057 ['kca', 'votejkt48id', '12new', 'updat', 'a', 'famili', 'of', '3', 'ha', 'been', 'displac', 'after', 'fire', 'damag', 'hous', 'near', '90th', 'and', 'osborn', 'fire', 'extinguish', 'no', 'i', '_']
# 4064 ['kca', 'votejkt48id', '12new', 'updat', 'a', 'famili', 'of', '3', 'ha', 'been', 'displac', 'after', 'fire', 'damag', 'hous', 'near', '90th', 'and', 'osborn', 'fire', 'extinguish', 'no', 'i', '_']
# 4075 ['local', 'famili', 'displac', 'by', 'fire', 'via', 'let', 'help', 'that', 'famili', 'out', 'pleas']
# 4087 ['40', 'displac', 'by', 'ocean', 'township', 'apart', 'fire', 'newyork']
# 4088 ['pennliv', 'two', 'famili', 'displac', 'by', 'mechanicsburg', 'blaze', 'no', 'one', 'wa', 'injur', 'in', 'the', 'fire']
# 4089 ['a', 'crime', 'that', 'kill', 'displac', 'million', 'in', 'which', 'systemat', 'tortur', 'wa', 'carri', 'out', 'but', 'look', 'grahamwp', 'fire', 'a', 'gun', '!', 'arrest', 'him', '!']
# 4096 ['elem', 'pomo', 'help', 'the', 'displac', 'from', 'the', 'rocki', 'fire', 'pleas', 'consid', '!', 'elem', 'evacu', 'center', 'via']
# 4138 ['california', 'meet', 'drought', 'fuel', 'fire', 'season', 'with', 'extra', 'crew', 'relat', 'articl']
# 4266 ['it', 'like', 'there', 'fire', 'in', 'my', 'skin', 'and', 'im', 'drown', 'from', 'within', '?', '?', '?', '?']
# 4476 ['i', 'wa', 'blow', 'dri', 'my', 'hair', 'amp', 'the', 'cabl', 'caught', 'on', 'fire', 'i', 'let', 'go', 'of', 'it', 'as', 'soon', 'as', 'i', 'realiz', 'just', 'befor', 'i', 'could', 'get', 'electrocut', '?', '?']
# 4499 ['surviv', 'kit', 'whistl', 'fire', 'starter', 'wire', 'saw', 'cree', 'torch', 'emerg', 'blanket', 's', 'knife', 'full', 're', '_']
# 4507 ['surviv', 'kit', 'whistl', 'fire', 'starter', 'wire', 'saw', 'cree', 'torch', 'emerg', 'blanket', 's', 'knife', 'full', 're', '_']
# 4512 ['surviv', 'kit', 'whistl', 'fire', 'starter', 'wire', 'saw', 'cree', 'torch', 'emerg', 'blanket', 's', 'knife', 'full', 're', '_']
# 4539 ['came', 'across', 'thi', 'fire', 'video', 'not', 'mine', 'enjoy', 'fire', 'firemen', 'firetruck', 'emerg', 'rescu', '911', 'summertim', 'siren', '_']
# 4579 ['practic', 'your', 'famili', 'fire', 'escap', 'plan', 'so', 'everyon', 'know', 'what', 'to', 'do', 'in', 'case', 'of', 'an', 'emerg']
# 4666 ['stand', 'there', 'engulf', 'in', 'the', 'fire', 'smile']
# 4682 ['fulli', 'engulf', 'garag', 'fire', 'propan', 'tank', 'insid', 'sunnymead', 'dr']
# 4715 ["'so", 'again', 'make', 'sure', 'to', 'evacu', 'past', 'the', 'fire', 'door', 'ani', 'question', '?', 'ye', '?', "'", "'whi", 'would', 'we', 'open', 'the', 'door', 'to', 'the', 'fire', '!', '!', '?', '!', '?', '?', '!', '?', "'", 'i', 'i', 'i', 'cant']
# 4716 ['when', 'there', "'s", 'a', 'fire', 'alarm', 'go', 'off', 'in', 'zehr', 'and', 'we', 'keep', 'work', 'for', '20', 'minut', 'then', 'decid', 'to', 'evacu', 'everyon']
# 4717 ['california', 'amp', '039', 'monster', 'amp', '039', 'fire', 'is', '20', 'contain', 'as', '13000', 'are', 'told', 'to', 'evacu']
# 4720 ['firefigth', 'evacu', 'from', 'northampton', 'township', 'hous', 'fire']
# 4721 ['i', "'d", 'rather', 'have', 'an', 'ass', 'in', 'fire', 'at', 'least', 'i', "'d", 'know', 'whatev', 'i', 'eat', 'will', 'evacu', 'heartburn', 'stick', 'around']
# 4723 ['fire', 'crew', 'evacu', 'passeng', 'from', 'a', 'gold', 'coast', 'tram', 'trap', 'when', 'powerlin', 'fell', 'across', 'a', 'carriag', 'tennew', '5pm']
# 4733 ['what', 'if', 'the', 'fire', 'up', 'in', 'the', 'catalina', 'get', 'wors', 'and', 'we', 'have', 'to', 'evacu', 'the', 'area', 'aka', 'no', 'school', 'tomorrow']
# 4736 ['so', 'all', 'the', 'store', "'s", 'fire', 'alarm', 'went', 'off', 'today', 'at', 'work', 'and', 'we', 'had', 'to', 'evacu', 'i', 'wa', 'like', "'omg", '!', '!', 'i', 's', 'i', 's', 'it', 'happen', '!', '!', '!', '!', "'"]
# 4755 ['tonight', 'is', 'be', 'quit', 'interest', 'a', 'few', 'minut', 'ago', 'the', 'fire', 'system', 'went', 'off', 'and', 'we', 'had', 'to', 'evacu', 'the', 'build']
# 4756 ['town', 'of', 'roosevelt', 'washington', 'order', 'to', 'evacu', 'again', 'as', 'fire', 'worsen']
# 4769 ['new', 'evacu', 'order', 'for', '25', 'home', 'in', 'danger', 'of', 'hwi', '8', 'fire', 'near', 'roosevelt', 'wash', 'koin6new']
# 4772 ['chesterfield', 'apart', 'complex', 'evacu', 'becaus', 'of', 'fire', 'stl']
# 4773 ['trafford', 'centr', 'film', 'fan', 'angri', 'after', 'odeon', 'cinema', 'evacu', 'follow', 'fals', 'fire', 'alarm', 'twitter', 'user', 'tell']
# 4775 ['trafford', 'centr', 'film', 'fan', 'angri', 'after', 'odeon', 'cinema', 'evacu', 'follow', 'fals', 'fire', 'alarm']
# 4777 ['rocki', 'fire', 'in', 'northern', 'california', 'swell', 'to', '60000', 'acr', '12000', 'evacu', 'portland', 'phoenix', 'miami', 'atlanta', 'casper']
# 4778 ['trafford', 'centr', 'film', 'fan', 'angri', 'after', 'odeon', 'cinema', 'evacu', 'follow', 'fals', 'fire', 'alarm', 'twitter', 'user', 'tell', 'of', '_']
# 4780 ['so', 'mani', 'fire', 'in', 'norcal', 'they', 'ca', "n't", 'fight', 'some', 'of', 'them', 'pray', 'for', 'our', 'firefight', 'air', 'tanker', 'pilot', 'support', 'crew', 'amp', 'evacu', 'peopl']
# 4781 ['fortitudevalley', 'unit', 'damag', 'and', 'resid', 'evacu', 'after', 'fire', 'broke', 'out', 'after', '7am', 'thi', 'morn', '7new']
# 4782 ['i', 'did', "n't", 'get', 'to', 'buy', 'one', 'after', 'the', 'last', 'london', 'show', 'becaus', 'the', 'fire', 'alarm', 'went', 'off', 'and', 'everyon', 'had', 'to', 'be', 'evacu', 'hahahaha']
# 4784 ['worldnew', 'fallen', 'powerlin', 'on', 'g', 'link', 'tram', 'updat', 'fire', 'crew', 'have', 'evacu', 'up', 'to', '30', 'passeng', 'who', 'were', 'tr']
# 4787 ['trafford', 'centr', 'film', 'fan', 'angri', 'after', 'odeon', 'cinema', 'evacu', 'follow', 'fals', 'fire', 'alarm']
# 4788 ['evacu', 'order', 'lift', 'for', 'roosevelt', 'in', 'highway', '8', 'fire', 'koin6new']
# 4790 ['trafford', 'centr', 'film', 'fan', 'angri', 'after', 'odeon', 'cinema', 'evacu', 'follow', 'fals', 'fire', 'alarm', 'twi', 'manchesterlit']
# 4793 ['hotel', 'evacu', 'after', 'fire', 'on', 'shore', 'drive', 'in', 'norfolk']
# 4796 ['grass', 'fire', 'burn', 'past', 'roosevelt', 'wash', 'prompt', 'evacu', 'fire', 'firefight']
# 4797 ['rocki', 'fire']
# 4800 ['katunew', 'sr14', 'remain', 'close', 'as', 'brush', 'fire', 'burn', '1700', 'acr', 'liveonk2']
# 4802 ['good', 'thing', 'there', 'wa', 'actual', 'just', 'a', 'legit', 'fire', 'in', 'the', 'mall', 'and', 'nobodi', 'evacu', '!', '!']
# 4805 ['valley', 'build', 'evacu', 'after', 'fire', 'queensland']
# 4807 ['rocki', 'fire', 'in', 'northern', 'california', 'swell', 'to', '60000', 'acr', '12000', 'evacu', 'portland', 'phoenix', 'miami', 'atlanta', 'casper']
# 4813 ['break', 'author', 'have', 'issu', 'new', 'mandatori', 'evacu', 'notic', 'for', '25', 'home', 'to', 'the', 'north', 'of', 'the', 'fire', 'in', 'roosevelt', 'wa']
# 4826 ['our', 'mission', 'to', 'see', 'the', 'end', 'of', 'thi', 'movi', 'last', 'night', 'after', 'get', 'fire', 'alarm', 'evacu']
# 4832 ['elem', 'pomo', 'help', 'the', 'displac', 'from', 'the', 'rocki', 'fire', 'pleas', 'consid', '!', 'elem', 'evacu', 'center', 'via']
# 4837 ['evacu', 'drill', 'at', 'work', 'the', 'fire', 'door', 'would', "n't", 'open', 'so', 'i', 'got', 'to', 'smash', 'the', 'emerg', 'releas', 'glass', 'feelingmanli']
# 4848 ['a', 'voluntari', 'evacu', 'is', 'be', 'recommend', 'at', 'thi', 'time', 'for', 'pickerel', 'lake', 'cabin', 'across', 'highway', 'from', 'reidlak', 'fire', 'say', 'maca', 'nwt', 'yzf']
# 4853 ['new', 'evacu', 'order', 'for', '25', 'home', 'in', 'danger', 'of', 'hwi', '8', 'fire', 'near', 'roosevelt', 'wash', 'koin6new']
# 4854 ['reid', 'lake', 'fire', 'prompt', 'campground', 'evacu', 'order']
# 4858 ['evacu', 'drill', 'at', 'work', 'the', 'fire', 'door', 'would', "n't", 'open', 'so', 'i', 'got', 'to', 'smash', 'the', 'emerg', 'releas', 'glass', 'feelingmanli']
# 4951 ['yumiko', 'jump', 'in', 'surpris', 'as', 'the', 'fire', 'shot', 'upward', 'into', 'the', 'air', 'and', 'explod', 'caught', 'off', 'guard', "'woah", "'", 'she', 'had', '(', ')']
# 5119 ['investig', 'shift', 'focu', 'to', 'caus', 'of', 'fatal', 'waimat', 'fire']
# 5142 ['investig', 'shift', 'focu', 'to', 'caus', 'of', 'fatal', 'waimat', 'fire']
# 5151 ['investig', 'shift', 'focu', 'to', 'caus', 'of', 'fatal', 'waimat', 'fire']
# 5154 ['investig', 'shift', 'focu', 'to', 'caus', 'of', 'fatal', 'waimat', 'fire']
# 5160 ['investig', 'shift', 'focu', 'to', 'caus', 'of', 'fatal', 'waimat', 'fire']
# 5171 ['understand', 'that', 'there', 'are', 'no', 'fatal', 'as', 'no', 'one', 'wa', 'trap', 'insid', 'the', 'wholesal', 'market', '8', 'fire', 'engin', 'and', '40', 'fire', 'fighter', 'on', 'scene']
# 5311 ['holi', 'fuck', 'someon', 'set', 'me', 'on', 'fire']
# 5312 ['whi', 'is', 'it', 'that', 'my', 'pinki', 'feel', 'like', 'it', "'s", 'lit', 'on', 'fire', '?', 'freaki']
# 5313 ['morganit', 'gemston', 'white', 'fire', 'opal', '925', 'sterl', 'silver', 'ring', 'size', '6', 'r1354']
# 5314 ['fire']
# 5315 ['marquei', 'como', 'visto', 'game', 'of', 'throne', '3x5', 'kiss', 'by', 'fire', 'bancodeseri']
# 5316 ['save', 'the', 'date', '!', 'saturday', 'august', '15', '2015', 'is', 'the', 'salisburi', 'fire', 'depart', 'open', 'hous', 'at', '325', 'cypress', 'st', '10am', 'to']
# 5317 ['whi', 'put', 'out', 'a', 'fire', 'when', 'it', "'s", 'still', 'burn']
# 5318 ['almost', 'set', 'the', 'hous', 'on', 'fire', 'tryna', 'make', 'fuck', 'hotdog']
# 5319 ['caus', 'were', 'on', 'fire', 'we', 'are', 'on', 'fire', 'were', 'on', 'fire', 'now', 'yeah', 'were', 'on', 'fire', 'we', 'are', 'on', 'fire', 'were', 'on', 'fire', 'nowwwwww']
# 5320 ['my', 'avi', 'and', 'header', 'combo', 'is', 'fire']
# 5321 ['auction', 'shoe', 'retro', '5', 'fire', 'red']
# 5322 ['my', 'asshol', 'is', 'on', 'fire']
# 5323 ['i', "'m", 'cri', 'that', 'song', 'just', 'end', 'set', 'myself', 'on', 'fire']
# 5324 ['set', 'thing', 'on', 'fire', 'is', 'alway', 'an', 'option']
# 5325 ['sit', 'around', 'a', 'fire', 'sound', 'great', 'right', 'about', 'now']
# 5326 ['i', 'see', 'fire']
# 5327 ['amazon', 'kindl', 'fire', '7', "'", 'fast', 'repair', 'servic', 'for', 'power', 'jack', 'usb', 'charg', 'port', 'full', 'read', 'by', '_']
# 5328 ['but', 'put', "'flood", 'of', 'fire', "'", 'at', 'the', 'top', 'of', 'the', 'list']
# 5329 ['i', 'just', 'got', 'electrocut', 'by', 'my', 'hp', 'chromebook', 'charger', 'it', 'spark', 'and', 'caught', 'fire', 'hp']
# 5330 ['i', "'m", 'on', 'fire']
# 5331 ['politifiact', 'harri', 'reid', "'s", "'30", 'percent', 'of', 'women', 'serv', "'", 'plan', 'parenthood', 'claim', 'is', 'a', "'pant", 'on', 'fire', "'", 'lie', 'tcot']
# 5332 ['dear', 'i', 'brought', 'it', ')', 'canonbringit', 'fire', 'canontattoo', 'mn', 'theresmorewherethatcamefrom']
# 5334 ['i', 'just', 'watch', 'halt', 'and', 'catch', 'fire', '2x10', "'heaven", 'is', 'a', 'place', "'", 'trakt']
# 5335 ['yeah', 'just', 'who', 'we', 'need', 'anoth', 'middl', 'class', 'hate', 'republican', 'out', 'to', 'get', 'hard', 'work', 'cop', 'fire', 'fighter', 'teacher']
# 5336 ['thi', 'fire', 'is', 'way', 'too', 'close', 'wtf', 'is', 'go', 'on', '?', '?', '?', '?']
# 5337 ['fire', 'meet', 'gasolin', 'alway', 'got', 'ta', 'get', 'play', 'twice', 'lol']
# 5338 ['wcw', 'tha', 'bitch', 'is', 'fire']
# 5339 ['well', 'it', 'feel', 'like', 'im', 'on', 'fire']
# 5340 ['u', 'know', 'what', 'i', "'d", 'say', 'she', "'s", 'the', 'equival', 'of', 'strawberri', 'in', 'thi', 'case', 'i', 'would', 'say', 'she', "'s", 'fire', '?', '?', '?', '?']
# 5341 ['her', 'eye', 'and', 'word', 'are', 'so', 'ici', 'but', 'she', 'burn', 'like', 'rum', 'on', 'the', 'fire']
# 5342 ['news', 'politifiact', 'harri', 'reid', "'s", "'30", 'percent', 'of', 'women', 'serv', "'", 'plan', 'parenthood', 'claim', 'is', 'a', "'pant", 'on', 'fire', "'", 'lie']
# 5343 ['noth', 'like', 'a', 'good', 'fire']
# 5344 ['tenshi', 'activ', 'yuki', "'s", 'fire', 'card', '!']
# 5345 ['california', 'been', 'shake', 'catch', 'on', 'fire', 'and', 'overcharg', 'ppl', 'on', 'rent', 'for', 'the', 'past', '150', 'year', 'it', 'ai', "n't", 'go', 'nowher']
# 5346 ['there', "'s", 'a', 'fire', 'in', 'the', 'catalina', 'look', 'kinda', 'cool', 'thi', 'pictur', 'doe', "n't", 'do', 'it', 'justic']
# 5347 ['do', "n't", 'overwork', 'yourself', 'your', 'album', 'is', 'gon', 'na', 'be', 'fire', 'just', 'do', "n't", 'overwork', 'or', 'stress', '!', 'i', 'love', 'you', 'take', 'care']
# 5348 ['y', 'din', 'u', 'fav', 'my', 'fire', 'memez', '!']
# 5349 ['i', 'promis', 'not', 'to', 'tax', 'pancak', 'or', 'rainbow', 'or', 'not', 'die', 'in', 'a', 'fire']
# 5350 ['thi', 'nigga', 'cyhi', 'diss', 'wa', 'what', 'meek', 'wa', 'suppos', 'to', 'do', 'thi', 'shit', 'actual', 'fire']
# 5351 ['i', 'wan', 'na', 'set', 'some', 'shit', 'on', 'fire']
# 5353 ['i', 'just', 'check', 'in', '!', 'at', 'on', 'fire', 'on', 'lovefood']
# 5354 ['when', 'your', 'heart', 'is', 'bigger', 'than', 'the', 'obstacl', 'in', 'front', 'of', 'you', 'euro', 'dontexpectnoth', 'juli', 'fire']
# 5355 ['fire', 'wave', 'and', 'dark']
# 5356 ['it', 'may', 'seem', 'like', 'our', 'fire', 'ha', 'been', 'a', 'littl', 'burnt', 'out']
# 5357 ['smell', 'a', 'bon', 'fire', 'while', 'drive', 'make', 'me', 'wan', 'na', 'be', 'sit', 'near', 'one', 'make', "s'more", '?', '?', '?', '?']
# 5358 ['politifiact', 'harri', 'reid', "'s", "'30", 'percent', 'of', 'women', 'serv', "'", 'plan', 'parenthood', 'claim', 'is', 'a', "'pant", 'on', 'fire', "'", 'lie', 'call']
# 5359 ['will', 'be', 'drop', 'fire', 'selfi', 'tomorrow', 'say', "'you", "'re", 'welcom', "'", 'ahead', 'of', 'time']
# 5360 ['when', 'your', 'like', 'your', 'fire', 'ig', 'selfi', '?', '?', '?', '?']
# 5362 ['fire', 'call', 'brant', 'av', 'drummond', 'rd', 'for', 'fire', 'structur', 'singl', 'unit', 'car', '6', 'on', 'call', 'truck']
# 5363 ['news', 'on', '6', 'crew', 'neighbor', 'put', 'out', 'hallett', 'truck', 'fire']
# 5364 ['what', 'a', 'night', '!', 'kamper', 'go', 'on', 'vacat', 'to', 'end', 'our', 'dream', 'job', 'parti', 'where', 'fire', 'truck', 'spray', 'the', 'pool', 'with', 'a', 'hose', '!']
# 5365 ['your', 'psa', 'for', 'the', 'day', 'if', 'a', 'fire', 'truck', 'is', 'behind', 'you', 'with', 'light', 'go', 'move', 'over', '!', '!', '!', 'so', 'they', 'can', 'get', 'to', 'their', 'call']
# 5366 ['rfp', 'fire', 'truck', 'servic', 'bodi', 'for', 'f', '450', '(', 'fire', 'fight', 'rescu', 'amp', 'safeti', 'equip', 'transporta']
# 5367 ['reno', 'truck', 'trailer', 'catch', 'fire', 'in', 'reno']
# 5368 ['wild', 'night', 'in', 'the', 'villag', 'of', 'pugwash', 'everi', 'fire', 'truck', 'is', 'out', 'that', 'the', 'town', 'ha', 'which', 'is', 'like', 'a', 'fire', 'truck', 'for', 'everi', 'hous', 'popul', '6']
# 5369 ['irvin', 'sigalert', 'updat', '133', 's', 'now', 'close', 'at', 'irvin', 'blvd', '133', 'n', 'close', 'past', 'the', '5', 'b', 'c', 'of', 'trash', 'truck', 'fire']
# 5370 ['ltd', 'toy', 'stamp', 'amp', 'vintag', 'tonka', 'tfd', 'no', '5', 'press', 'steel', 'pumper', 'fire', 'truck', 'full', 'read', 'by', 'ebay']
# 5371 ["'an", '18', 'wheeler', 'came', 'along', 'and', 'struck', 'the', 'fire', 'truck', 'spin', 'it', 'around', '180', 'degre', 'and', 'caus', 'it', 'to', 'roll', 'over', "'"]
# 5372 ['sigalert', 'updat', '3', 'n', '133', 'close', 'at', '5', 'fwi', 'ufn', 'trash', 'truck', 'fire']
# 5373 ['did', "n't", 'look', 'like', 'a', 'murder', 'scene', 'just', '1', 'cop', 'a', 'fire', 'truck', 'and', '2', 'fire', 'assist', 'car', 'along', 'with', 'a', 'helicopt']
# 5374 ['news', 'on', '6', 'crew', 'neighbor', 'put', 'out', 'hallett', 'truck', 'fire']
# 5375 ['former', 'township', 'fire', 'truck', 'be', 'use', 'in', 'philippin', 'langley', 'time', 'philippin']
# 5376 ['photo', 'njturnpik', '_', 'nj', 'turnpik', 'reopen', 'hour', 'after', 'truck', 'fire', 'in', 'linden', 'driver', 'dead', 'nj', 'turnpik']
# 5377 ['former', 'township', 'fire', 'truck', 'be', 'use', 'in', 'philippin', 'township', 'of', 'langley', 'assist', 'fire', 'chief', 'pat', 'walker', 'spen']
# 5378 ['our', 'garbag', 'truck', 'realli', 'caught', 'on', 'fire', 'lmfao']
# 5379 ['on', 'northgat', 'by', 'the', 'taco', 'truck', 'that', "'s", 'fire']
# 5380 ['it', "'s", 'never', 'a', 'good', 'sign', 'when', 'you', 'pull', 'up', 'to', 'work', 'amp', 'there', "'s", 'five', 'ambul', 'amp', 'a', 'fire', 'truck', 'in', 'the', 'bay', 'wompppp', 'at', 'least', 'it', "'s", 'friday']
# 5381 ['fire', 'truck', 'and', 'ambul', 'in', 'k3', 'phase', '3', 'hope', 'everyon', "'s", 'okay', 'prayforsaipan']
# 5382 ['sigalert', 'north', 'amp', 'southbound', '133', 'close', 'btwn', '5', 'fwi', 'and', 'irvin', 'blvd', 'due', 'to', 'truck', 'fire', 'chp', 'is', 'detour', 'traffic']
# 5383 ['true', 'becaus', 'of', 'the', 'truck', 'that', 'caught', 'fire', '?']
# 5384 ['ohgod', 'xd', 'i', 'did', "n't", 'mean', 'it', 'so', 'p', 'but', 'you', 'have', 'that', 'fire', 'truck', 'in', 'the', 'back', 'of', 'you', 'to', 'make', 'up', 'for', 'it', 'so', 'you', 'good', 'xd']
# 5385 ['came', 'across', 'thi', 'fire', 'video', 'not', 'mine', 'enjoy', 'babe', 'way', 'of', 'say', 'hi', 'to', 'me', 'while', 'he', "'s", 'in', 'the', 'fire', 'truck', '?', '?', 'fireman', '_']
# 5386 ['133', 'n', 'past', 'the', '5', 'l', 'lane', 'is', 'reopen', 'all', 'other', 'lane', 'are', 'close', 'all', 'lane', 'are', 'open', 'on', 'the', '133', 's', 'trash', 'truck', 'fire', 'cleanup']
# 5387 ['sigalert', 'north', 'amp', 'southbound', '133', 'close', 'btwn', '5', 'fwi', 'and', 'irvin', 'blvd', 'due', 'to', 'truck', 'fire', 'chp', 'is', 'detour', 'traffic']
# 5388 ['but', 'the', 'fire', 'ring', 'of', 'nyc', 'permit', 'i', "'d", 'have', 'to', 'jump', 'through', 'for', 'a', 'food', 'truck', 'do', "n't", 'make', 'it', 'appeal']
# 5389 ['found', 'thi', 'cool', 'photo', 'not', 'mine', '1952', 'dodg', 'wayn', 'bodi', '4', 'window', 'bu', 'ex', 'libbi', 'mt', 'fire', 'depart', 'truck', 'all', 'ori', '_']
# 5390 ['last', 'night', 'wa', 'a', 'ball', '!', 'atop', 'a', '40', 'ft', 'fire', 'truck', 'latter', '!', 'nno2015']
# 5391 ['trident', '90225', 'chevi', 'fire', 'truck', 'w', 'pumper', 'im', 'fire', 'dept', 'red', 'ho', '1', '87', 'plastic']
# 5392 ['toddler', 'bed', 'firetruck', 'bundl', 'fire', 'truck', 'firefight', 'sticker', 'decal', 'sign', 'wall']
# 5393 ['fire', 'shut', 'down', 'part', 'of', 'nj', 'turnpik', '_', '96']
# 5394 ['mark', 'your', 'calendar', 'fire', 'truck', 'parad', 'return', 'to', 'raleigh', '!']
# 5395 ['thi', 'dude', 'just', 'pull', 'in', 'front', 'of', 'our', 'product', 'with', 'hi', 'truck', 'on', 'fire', 'cop', 'pull', 'up', 'after', 'we', 'put', 'it', 'out']
# 5396 ['when', 'a', 'monster', 'truck', 'racer', 'catch', 'on', 'fire', 'at', 'the', 'fair']
# 5397 ['truck', 'fire', 'clog', 'canyon', 'road']
# 5398 ['truck', 'catch', 'fire', 'in', 'warwick', 'a', 'tree', 'servic', 'truck', 'caught', 'fire', 'around', '7', '15', 'p', 'm', 'on', 'wednesday', 'in', 'warwick', 'on', 'in']
# 5399 ['pickup', 'truck', 'fire', 'on', 'driscol', 'bridg', 'snag', 'garden', 'state', 'parkway', 'newyork']
# 5400 ['rgj', 'truck', 'trailer', 'catch', 'fire', 'in', 'reno']
# 5401 ['langhorn', 'middletown', 'fire', 'co', 'welcom', 'new', 'truck']
# 5402 ['truck', 'driver', 'die', 'in', 'turnpik', 'fire', 'most', 'lane', 'still', 'close', 'polic', 'say', 'via']
# 5403 ['philippin', 'former', 'township', 'fire', 'truck', 'be', 'use', 'in', 'philippin', '_', 'of', 'emerg', 'equip', 'in', 'cebu', 'philippi']
# 5404 ['there', 'a', 'fire', 'truck', 'in', 'thi', 'park', 'lot']
# 5405 ['photo', 'xshanemichaelsx', 'instaxbooti', '?', '?', '?', '?', '(', 'via', 'tumbleon', ')', 'is', 'that', 'a', 'fire', 'truck', '?', 'i', 'need', 'to']
# 5407 ["'choos", 'to', 'be', 'happi', 'fire', 'truck', 'the', 'rest', "'", '?', '?', '?', '?', '?', 'review', 'of', 'kick', 'push', 'by']
# 5408 ['former', 'township', 'fire', 'truck', 'be', 'use', 'in', 'philippin', 'langley', 'time', 'filipino']
# 5409 ['jacksonvil', 'fire', 'amp', 'rescu', 'engin', '58', 'awesom', 'truck', '!', 'offici', 'jade', 'fl', 'via']
# 5410 ['njturnpik', '_', 'njturnpik', 'reopen', 'hour', 'after', 'truck', 'fire', 'in', '?']
# 5427 ["'an", 'alarm', 'trend', 'among', 'first', 'respond', 'is', 'rais', 'concern', 'for', 'local', 'fire', 'depart', 'in', 'colorado', 'and', 'around']
# 5431 ['volunt', 'serv', 'first', 'respond', 'today', 'dure', 'a', 'tanker', 'fire', 'in', 'eufaula', 'provid', 'cold', 'drink', 'and', 'food', 'okwx', 'tankerfir']
# 5464 ['more', 'new', 'flame', 'for', 'that', 'next', 'fire', 'under', 'the', 'pot', 'line', 'up', 'flame', 'right', 'here', 'right', 'now', 'let', 'em', 'knw', 'u', 'wit', 'em', 'flame', '!', '!', '!']
# 5469 ['just', 'ad', 'some', 'more', 'fire', 'to', 'the', 'flame', 'for', 'saturday', '!', 'rick', 'wonder', 'will', 'be', 'spin', 'a', 'guest', 'set', 'along', 'with', 'chachi']
# 5470 ['the', 'fire', 'of', 'hell', 'for', 'juli', 'extant', 'writer', 'she', 'better', 'go', 'down', 'in', 'flame', 'when', 'thi', 'is', 'all', 'over', 'extant']
# 5479 ['i', 'wish', 'i', 'wa', 'good', 'enough', 'to', 'add', 'flame', 'to', 'my', 'nail', 'im', 'on', 'fire']
# 5484 ['maryland', 'mansion', 'fire', 'that', 'kill', '6', 'caus', 'by', 'damag', 'plug', 'under', 'christma', 'tree', 'report', 'say', 'into', 'the', 'flame']
# 5491 ['maryland', 'mansion', 'fire', 'that', 'kill', '6', 'caus', 'by', 'damag', 'plug', 'under', 'christma', 'tree', 'report', 'say', 'into', 'the', 'flame', 'firefight', "'s", 'braveri']
# 5494 ['maryland', 'mansion', 'fire', 'that', 'kill', '6', 'caus', 'by', 'damag', 'plug', 'under', 'christma', 'tree', 'report', 'say', 'into', 'the', 'flame']
# 5503 ['soloquiero', 'maryland', 'mansion', 'fire', 'that', 'kill', '6', 'caus', 'by', 'damag', 'plug', 'under', 'christma', 'tree', 'report', 'say', 'into', 'the', 'flame', 'firefight']
# 5505 ['maryland', 'mansion', 'fire', 'that', 'kill', '6', 'caus', 'by', 'damag', 'plug', 'under', 'christma', 'tree', 'report', 'say', 'into', 'the', 'flame']
# 5711 ['e1', '1', '2', 'particul', 'break', 'up', 'of', 'solid', 'combust', 'fossil', 'fuel', 'voltaic', 'activ', 'forest', 'fire', 'biolog', 'voc', 'petroleum', 'ch4', 'bacteria', 'decomposit']
# 5712 ['be', 'care', 'anyon', 'who', 'live', 'west', 'of', 'beaverton', 'forest', 'grove', 'ha', 'a', 'rapidli', 'spread', 'fire', 'head', 'east']
# 5714 ['how', 'is', 'it', 'one', 'careless', 'match', 'can', 'start', 'a', 'forest', 'fire', 'but', 'it', 'take', 'a', 'whole', 'box', 'to', 'start', 'a', 'campfir', '?']
# 5715 ['our', 'littl', 'forest', 'fire', 'warden']
# 5716 ['fire', 'in', 'pisgah', 'nation', 'forest', 'grow', 'to', '375', 'acr']
# 5717 ['ashenforest', 'floorburnt', 'manzanita', 'amp', 'timber', 'on', 'johnson', 'fire', 'along', 'ridg', 'on', 'forest', 'road', '1', 'routecomplex']
# 5718 ['grass', 'fire', 'near', 'forest', 'grove', 'contain', 'spark', 'by', 'a', 'rock', 'be', 'struck', 'by', 'a', 'tractor', 'liveonk2']
# 5719 ['run', 'at', 'her', 'for', 'set', 'my', 'forest', 'on', 'fire', 'and', 'bite', 'the', 'shit', 'out', 'of', 'her', 'neck']
# 5720 ['set', 'the', 'forest', 'on', 'fire']
# 5721 ['i', 'like', 'a', 'video', 'j', 'cole', 'fire', 'squad', '(', '2014', 'forest', 'hill', 'drive', ')']
# 5722 ['view', 'of', 'smoke', 'column', 'rise', 'abov', 'the', 'south', 'end', 'of', 'the', 'blake', 'fire', 'along', 'forest', 'road', '1', 'routecomplex']
# 5723 ['damn', 'dri', 'desert', 'forest', 'fire', 'damn', '(']
# 5724 ['it', 'start', 'a', 'forest', 'fire', 'that', 'can', 'not', 'be', 'put', 'out']
# 5725 ['winston', 'salem', 'fire', 'in', 'pisgah', 'nation', 'forest', 'grow', 'to', '375', 'acr']
# 5726 ['fire', 'in', 'pisgah', 'nation', 'forest', 'grow', 'to', '375', 'acr']
# 5727 ['i', 'had', 'to', 'grill', 'for', 'a', 'school', 'function', 'one', 'of', 'the', 'grill', 'we', 'had', 'go', 'wa', 'pretti', 'much', 'either', 'off', 'or', 'forest', 'fire', 'no', 'inbetween', '!', 'made', 'it', 'work']
# 5728 ['crew', 'respond', 'to', 'small', 'brush', 'fire', 'burn', 'in', 'taho', 'forest', 'my', 'news', '4', 'krnv', 'reno', 'nv']
# 5729 ['5', '15p', 'for', 'those', 'who', 'watch', 'over', 'me', 'forest', 'fire', 'smoke', 'ha', 'lift', "'nuff", 'f', 'me', 't', 'make', 'a', 'run', 't', 'the', 'pet', 'store', 'on', 'the', 'hwi', '(', 'n', ')', 'i', "'ll", 'b', 'home', 'by', '7p']
# 5730 ['we', 'are', 'have', 'forest', 'fire', 'out', 'here', 'in', 'socal', 'but', 'the', 'onli', 'fire', 'you', 'should', 'watch', 'for', 'is', 'realhiphop']
# 5731 ['omg', 'there', "'s", 'a', 'news', 'chopper', 'over', 'a', '3', 'acr', 'mostli', 'contain', 'fire', 'outsid', 'forest', 'grove', '?', 'slownewsday', '?']
# 5732 ['u', 's', 'forest', 'servic', 'firefight', 'david', 'ruhl', '38', 'die', 'in', 'the', "'frog", 'fire', "'", 'in', 'the', 'modoc', 'nation', 'forest', 'he', 'had', 'been', 'temporarili', 'reassign']
# 5733 ['usf', 'an', 'acronym', 'for', 'unit', 'state', 'fire', 'servic']
# 5734 ['how', 'is', 'it', 'one', 'careless', 'match', 'can', 'start', 'a', 'forest', 'fire', 'but', 'it', 'take', 'a', 'whole', 'box', 'to', 'start', 'a', 'campfir']
# 5735 ['globalwarm', 'u', 's', 'forest', 'servic', 'say', 'spend', 'more', 'than', 'half', 'of', 'budget', 'on', 'fire', '_', 'unit', 'state', 'the', 'agen']
# 5736 ['onli', 'you', 'can', 'prevent', 'forest', 'fire', '?', '?', '?', '?']
# 5737 ['reuter', 'us', 'forest', 'servic', 'say', 'spend', 'more', 'than', 'half', 'of', 'budget', 'on', 'fire']
# 5738 ['cossack', 'hussar', 'oo', 'hd', 'riggd', 'up', 'rough', 'shelter', 'n', 'th', 'glade', 'were', 'kindlng', 'glowng', 'fire', 'n', 'a', 'hollow', 'v', 'th', 'forest', 'where', 'th', 'frnch', 'could', 'not', 'c', 'th']
# 5739 ['naturaldisast', 'as', 'california', 'fire', 'rage', 'the', 'forest', 'servic', 'sound', 'the', 'alarm', 'about', 'rise', 'wildfir', 'cost', '_']
# 5740 ['q', 'whi', 'do', 'duck', 'have', 'big', 'flat', 'feet', '?', 'a', 'to', 'stamp', 'out', 'forest', 'fire', 'q', 'whi', 'do', 'eleph', 'have', 'big', 'flat', 'feet', '?', 'a', 'to', 'stamp', 'out', 'flame', 'duck']
# 5741 ['wow', 'where', 'is', 'thi', '?', 'for', 'the', 'rest', 'of', 'the', 'summer', 'i', 'usual', 'have', 'to', 'worri', 'about', 'forest', 'fire', 'calgari', 'is', 'about', '8', 'hour', 'away']
# 5742 ['whi', 'ca', "n't", 'they', 'use', 'ocean', 'water', 'to', 'fight', 'forest', 'fire', '?']
# 5743 ['as', 'california', 'fire', 'rage', 'forest', 'servic', 'sound', 'the', 'alarm', 'about', 'sharpli', 'rise', 'wildfir', 'cost']
# 5744 ['a', 'littl', 'concern', 'about', 'the', 'number', 'of', 'forest', 'fire', 'where', 'i', "'ll", 'be', 'live']
# 5745 ['trump', 'is', 'a', 'climat', 'denier', 'alga', 'bloom', 'in', 'the', 'pacif', 'from', 'calif', 'to', 'alska', 'seewe', 'in', 'caribean', 'forest', 'fire', 'snowbal', 'inhof']
# 5746 ['the', 'forest', 'servic', 'now', 'spend', 'gt', '50', 'of', 'it', 'budget', 'fight', 'fire']
# 5747 ['peopl', 'come', 'and', 'go', 'some', 'are', 'cigarett', 'break', 'other', 'are', 'forest', 'fire']
# 5748 ['cartoon', 'bear', 'without', 'them', 'we', 'would', 'qave', 'no', 'knowlddg', 'of', 'forest', 'fire', 'or', 'toilet', 'paper']
# 5749 ['ya', 'it', 'wa', 'damn', 'forest', 'fire']
# 5750 ['are', 'ani', 'of', 'your', 'vineyard', 'affect', 'by', 'the', 'forest', 'fire', 'in', 'california', '?']
# 5751 ['thi', 'is', 'the', 'first', 'year', 'the', 'forest', 'servic', 'spent', 'more', 'than', 'half', 'it', 'annual', 'budget', 'on', 'fight', 'fire', 'climatechang']
# 5752 ['as', 'california', 'fire', 'rage', 'the', 'forest', 'servic', 'sound', 'the', 'alarm', 'about', 'rise', 'wildfir', 'cost']
# 5753 ['reddit', 'lightn', 'spark', 'new', 'fire', 'in', 'bois', 'nation', 'forest', 'r', 'stormcom']
# ...
# 5765 ['pray', '!', 'for', 'east', 'coast', 'forest', 'fire', '!', 'pray', '!', 'that', 'they', 'be', 'put', 'out', 'pray', '!', 'for', 'rain', '!']
# 5766 ['instead', 'of', 'dump', 'water', 'on', 'yourselv', 'pleas', 'send', 'it', 'to', 'british', 'columbia', 'to', 'help', 'with', 'the', 'forest', 'fire']
# 5768 ["'peopl", 'come', 'and', 'go', 'some', 'are', 'cigarett', 'break', 'other', 'are', 'forest', 'fire', "'"]
# 5769 ['heartdiseas', 'u', 's', 'forest', 'servic', 'say', 'spend', 'more', 'than', 'half', 'of', 'budget', 'on', 'fire']
# 5770 ['two', 'new', 'bitterroot', 'nation', 'forest', 'fire', 'are', 'largest', 'for', 'forest', 'so', 'far', 'thi', 'year']
# 5771 ["'", 'no', 'pharrel', 'onli', 'you', 'can', 'prevent', 'forest', 'fire', "'", '?', '?']
# 5772 ['climat', 'consequ', 'u', 's', 'forest', 'servic', 'say', 'spend', 'more', 'than', 'half', 'of', 'budget', 'on', 'fire']
# 5773 ['stand', 'in', 'mountaintop', 'field', 'scent', 'with', 'wildflow', 'dust', 'and', 'distant', 'forest', 'fire', 'smell', 'of', 'impend', 'rain', 'in', 'the', 'air', 'fieldworksmel']
# 5774 ['q', 'whi', 'do', 'duck', 'have', 'big', 'flat', 'feet', '?', 'a', 'to', 'stamp', 'out', 'forest', 'fire', 'q', 'whi', 'do', 'eleph', 'have', 'big', 'flat', 'feet', '?', 'a', 'to', 'stamp', 'out', 'flame', 'duck']
# 5775 ['u', 's', 'forest', 'servic', 'say', 'spend', 'more', 'than', 'half', 'of', 'budget', 'on', 'fire']
# 5777 ['inciweb', 'or', 'updat', 'rogu', 'river', 'siskiy', 'nation', 'forest', 'fire', '8', '5', '15', '12', '00', 'pm', '(', 'rogu', 'river', 'siskiy', 'nf', 'area', '_']
# 5778 ['forest', 'fire', 'could', 'delay', 'but', 'offici', 'say', 'it', 'could', 'be', 'a', 'good', 'thing']
# 5780 ['u', 's', 'forest', 'servic', 'say', 'spend', 'more', 'than', 'half', 'of', 'budget', 'on', 'fire', 'by', 'ian', 'simpson', '_']
# 5781 ['campsit', 'recommend', 'toilet', 'shower', 'pub', 'fire', 'no', 'kid', 'pizza', 'shop', 'forest', 'pretti', 'stream', 'no', 'midg', 'no', 'snake', 'thank', '?', '?']
# 5782 ['rivercomplex', 'ca', 'cashf', 'river', 'complex', 'six', 'river', 'nation', 'forest', 'lightn', 'fire', 'morn', 'updat']
# 5783 ['when', 'ur', 'friend', 'and', 'u', 'are', 'talk', 'about', 'forest', 'fire', 'in', 'a', 'forest', 'and', 'he', 'tell', 'u', 'to', 'drop', 'ur', 'mix', 'tape', 'out', 'there', 'straightfir']
# 5893 ['i', "'ve", 'burn', 'myself', 'befor', 'not', 'in', 'the', 'self', 'harm', 'way', 'in', 'the', 'i', "'m", 'a', 'dumbass', 'and', 'i', 'should', "n't", 'be', 'allow', 'to', 'be', 'around', 'fire', 'way']
# 5948 ['nvidia', 'recal', 'some', 'shield', 'tablet', 'becaus', 'of', 'possibl', 'fire', 'hazard', 'nvidia']
# 5950 ['road', 'closur', 'remain', 'in', 'effect', 'due', 'to', 'hazard', 'tree', 'fall', 'tree', 'torch', 'and', 'uphil', 'run', 'of', 'the', 'fire', 'forest', 'servic', 'road', '1', 'remain', 'close']
# 5966 ['becaus', 'if', 'it', 'were', 'on', 'fire', 'that', "'d", 'be', 'a', 'safeti', 'hazard']
# 5979 ['hi', 'is', 'there', 'an', 'email', 'that', 'peopl', 'can', 'use', 'to', 'report', "s'thing", 'they', 'think', 'is', 'a', 'fire', 'hazard', 'danger', '?']
# 6471 ['terrorist', 'open', 'fire', 'at', 'udhampur', 'polic', 'post', '2', 'spo', "'s", 'injur', 'fire', 'underway', 'see', 'more', 'at']
# 6487 ['there', 'are', 'now', '5', 'fire', 'truck', 'and', '2', 'ambul', 'at', 'wellington', 'ridg', 'lp', 'in', 'cari', 'one', 'of', 'the', 'unit', 'is', 'on', 'fire', 'not', 'sure', 'on', 'injuri']
# 6500 ['tonight', 'we', 'have', 'attend', 'a', 'fire', 'in', 'romford', 'with', 'thank', 'no', 'injuri']
# 6773 ['lightn', 'caus', 'six', 'new', 'fire', 'on', 'vancouv', 'island']
# 6993 ['saturday', 'night', 'massacr', '?', '25', 'year', 'later', 'tomlandri', '?', 's', 'fire', 'still', 'a', 'day', 'of', 'infami']
# 7039 ['break', 'author', 'respond', 'to', 'ocean', 'fire']
# 7751 ["'gunman", 'who', 'open', 'fire', 'at', 'tennesse', 'movi', 'theater', 'kill', 'by', 'polic', "'", 'anyon', 'suspect', 'suicid', 'by', 'cop', '?']
# 7752 ['polic', 'kill', 'hatchet', 'wield', 'gunman', 'who', 'open', 'fire', 'insid', 'nashvil', 'movi', 'theater', 'a', 'middl', 'age', 'man', 'arm', 'wi']
# 8063 ['florida', 'firefight', 'rescu', 'scare', 'meow', 'kitten', 'from', 'vent', 'shaft', 'fire', 'firefight']
# 8090 ['revel8ion', 'media', 'recent', 'went', 'out', 'to', 'support', 'the', "'rocki", 'fire', "'", 'rescu', 'effort', 'thi', 'is', 'what', 'we', 'film', 'rockyfir']
# 8798 ['so', 'far', 'miss', 'may', 'i', 'sleep', 'with', 'siren', 'august', 'burn', 'red', 'memphi', 'may', 'fire', 'attila', 'amp', 'all', 'were', 'so', 'good', '?', '?']
# 8818 ['i', 'wa', 'walk', 'past', 'the', 'fire', 'hous', 'today', 'amp', 'as', 'soon', 'as', 'i', 'walk', 'by', 'the', 'door', 'they', 'get', 'call', 'and', 'flip', 'the', 'siren', 'on', 'i', "'ve", 'never', 'ran', 'so', 'fast']
# 8833 ['fire', 'truck', 'siren', 'for', 'the', 'past', 'ten', 'minut', 'straight', 'come', 'and', 'go', 'must', 'be', 'huge', 'mayb', 'it', "'s", 'taco', 'bell', 'and', 'they', "'ll", 'build', 'a', 'sonic', 'instead']
# 8849 ['smoke', '?', '?', 'so', 'much', 'you', 'do', "n't", 'got', 'ta', 'do', 'shit', 'but', 'light', '?', '?', 'one', 'of', 'hi', 'lock', 'on', 'fire', 'that', "'s", 'like', 'a', 'whole', 'tre', 'five', 'right', 'there']
# 8872 ['sky', 'look', 'clear', 'no', 'smoke', 'from', 'the', 'fire', 'enjoy', 'your', 'time', 'in', 'taho', 'one', 'of', 'my', 'favorit', 'place', '!']
# 8900 ['sorri', 'i', 'built', 'a', 'fire', 'by', 'my', 'desk', 'alreadi', 'rt', 'pleas', 'maintain', 'that', 'snowstorm', 'til', 'i', 'arriv']
# 9016 ['the', "'1pack", '2pack', '3pack', "'", 'line', 'is', 'on', 'fleek', 'if', 'stretcher', 'is', 'fire']
# 9231 ['russia', 'and', 'that', 'back', 'fire', 'now', '2015', 'look', 'what', 'happen', '911bomb', 'of', 'marin', 'barrack', 'suicid', 'bomber', 'attack', 'on', 'world', 'site']
# 9548 ['to', 'the', 'largest', 'moblin', "'s", 'he', "'d", 'leav', 'the', 'biggest', 'one', 'for', 'red', 'and', 'fire', 'with', 'one', 'strike', 'alreadi', 'the', 'threat', 'wa', 'reduc', 'gt']
# 9868 ['one', 'good', 'thing', 'came', 'out', 'of', 'watch', 'the', 'film', 'wa', 'too', 'traumatis', 'to', 'watch', 'show', 'so', 'start', 'halt', 'amp', 'catch', 'fire', 'on', 'amazon', 'd']
# 10242 ['what', "'s", 'the', 'hottest', 'thing', 'you', "'ve", 'ever', 'seen', 'fire', '?', 'the', 'sun', '?', 'a', 'volcano', '?', 'or', 'thi', '?']
# 10300 ['fun', 'fact', 'everi', 'rapid', 'fire', 'weapon', 'in', 'the', 'game', 'is', 'a', 'hard', 'counter', 'to', 'the', 'slosher', 'and', 'the', 'splattl']
# 10370 ['navi', 'say', 'lt', 'cmdr', 'who', 'fire', 'sidearm', 'in', 'defens', 'dure', 'nosc', 'chattanooga', 'terrorist', 'attack', 'will', 'not', 'face', 'charg']
# 10435 ['harperanetflixshow', 'blaze', 'saddl', '(', 'a', 'show', 'about', 'wild', 'fire', 'in', 'alberta', ')']
# 10436 ['as', 'wild', 'fire', 'blacken', 'northern', 'california', 'parch', 'harri', 'counti', 'becom', 'tinder', 'box']
# 10437 ['?', '?', 'break', 'massiv', 'wild', 'and', 'field', 'fire', 'report', 'throughout', 'germani', '!', 'the', 'most', 'fire', 'are', 'in', 'eastern', 'german']
# 10438 ['we', 'all', 'complain', 'about', 'pa', 'but', 'atleast', 'we', 'do', "n't", 'have', 'those', 'wild', 'fire', 'take', 'our', 'home', 'like', 'north', 'cali', 'or', 'the', 'flood', 'in', 'florida', 'right', 'now']
# 10439 ['collect', 'of', 'artic', 'and', 'video', 'of', 'west', 'coast', 'wild', 'fire', 'by']
# 10440 ['my', 'wife', 'ha', 'opt', 'to', 'take', 'holiday', 'amp', 'histor', 'sinc', 'we', 'met', 'get', 'special', 'treatment', 'her', 'bonfir', 'ca', "n't", 'start', 'wild', 'fire', 'rain', '!']
# 10441 ['my', 'brother', 'n', 'law', 'riooooo', 'got', 'the', 'call', 'to', 'head', 'up', 'north', 'and', 'fight', 'the', 'wild', 'fire', 'dude', 'a', 'beast', 'at', '_']
# 10442 ['like', 'blaze', 'wild', 'fire', 'sing', 'your', 'name', '!']
# 10443 ['sever', 'wild', 'fire', 'have', 'burn', 'a', 'lot', 'of', 'land', 'in', 'california', 'here', 'is', 'one', 'of', 'the', 'larger', 'fire']
# 10444 ['map', 'show', 'where', 'all', 'of', 'california', "'s", 'wild', 'fire', 'are', 'burn', 'thi', 'map', 'creat', 'by', 'cal', 'fire', '_']
# 10445 ['some', 'great', 'footag', 'of', 'strong', 'work', 'from', 'san', 'bernardino', 'counti', 'fire', 'who', 'is', 'also', 'work', 'the', 'wild', 'fire', 'right', 'now']
# 10446 ['god', 'forbid', 'thi', 'is', 'true', 'california', 'ha', 'enough', 'problem', 'with', 'sever', 'drought', 'amp', 'wild', 'fire', 'nuclear', 'power', 'sanonofr']
# 10447 ['netnewsledg', 'wild', 'fire', 'updat', 'august', '4', '2015', 'thunder', 'bay', 'weather', 'there', 'were', 'no', 'new', 'fire', 'confirm', 'by', 't']
# 10448 ['firefight', 'head', 'to', 'california', 'to', 'fight', 'wild', 'fire']
# 10449 ['foxdebatequest', 'to', 'what', 'degre', 'ha', 'obama', "'s", 'effort', 'to', 'institut', 'sharia', 'law', 'exacerb', 'the', 'california', 'wild', 'fire', '?']
# 10450 ['prayer', 'for', 'my', 'cousin', '!', 'he', "'s", 'in', 'california', 'help', 'with', 'the', 'wild', 'fire']
# 10451 ['catastroph', 'wild', 'fire', 'threaten', 'u', 's', 'mid', 'west', 'amp', 'republican', 'fight', 'new', 'climat', 'chang', 'rule', 'i', 'guess', 'thi', 'is', 'the', 'ultim', 'in', 'darwin']
# 10452 ['becuas', 'it', 'can', 'caus', 'properti', 'damag', 'and', 'caus', 'wild', 'fire']
# 10453 ['hey', '!', 'my', 'mom', 'hous', 'burn', 'down', 'in', 'the', 'ca', 'wild', 'fire', 'amp', 'i', 'bought', 'her', 'an', 'e', 'gift', 'card', 'to', 'buy', 'her', 'cloth', '(', 'cont', ')']
# 10454 ['california', 'wild', 'fire', 'clearli', 'caus', 'by', 'global', 'climat', 'chang', 'and', 'excess', 'co2', '!', '!', '!', '?']
# 10455 ['i', 'wa', 'think', 'about', 'you', 'today', 'when', 'i', 'wa', 'read', 'about', 'the', 'wild', 'fire']
# 10456 ['climat', 'chang', 'cnn', 'weather', "'specialist", "'", 'warn', 'wild', 'fire', 'rain', 'flood', 'note', 'about', 'the', 'sun', '?']
# 10457 ['thank', 'sen', 'feinstein', 'now', 'hurri', 'home', 'becaus', 'california', 'is', 'a', 'huge', 'uncontrol', 'wild', 'fire', 'lighten', 'is', 'start', 'new', 'fire']
# 10458 ['wild', 'fire', 'freak', 'me', 'the', 'fuck', 'out', 'like', 'hell', 'no']
# 10459 ['california', 'wild', 'fire', 'blow', 'my', 'mind', 'everi', 'time']
# 10460 ['are', 'those', 'wild', 'fire', 'get', 'anywher', 'near', 'you', '?']
# 10461 ['man', '!', 'what', 'i', 'would', 'give', 'to', 'be', 'in', 'ca', 'right', 'now', 'to', 'help', 'with', 'the', 'wild', 'fire']
# 10462 ['in', 'europ', 'natur', 'is', 'kind', 'while', 'in', 'us', 'they', 'have', 'tornado', 'hurrican', 'wild', 'fire', 'earthquak', 'flash', 'flood', 'mega', 'snow', 'drought']
# 10463 ['stamped', 'and', 'fire', 'brought', 'him', 'home', 'can', 'her', 'love', 'make', 'him', 'stay', '?', 'tame', 'a', 'wild', 'heart', 'audiobook', 'bynr']
# 10464 ['they', 'should', 'just', 'have', 'load', 'shed', 'perman', 'and', 'we', 'will', 'all', 'just', 'live', 'like', 'we', 'in', 'the', 'wild', 'and', 'have', 'camp', 'fire', 'cook', 'with', 'fire', 'etc']
# 10465 ['go', 'home', 'california', 'you', "'re", 'drunk', 'natur', 'select', 'ha', 'taken', 'affect', 'debt', 'extrem', 'wild', 'fire', 'water', 'suppli', 'problem', 'you', 'fail', 'as', 'a', 'state']
# 10466 ['firefight', 'from', 'connecticut', 'are', 'head', 'to', 'california', 'to', 'fight', 'wild', 'fire']
# 10467 ['these', 'wild', 'fire', 'out', 'west', 'are', 'crazi']
# 10468 ['deep', 'crew', 'to', 'help', 'with', 'california', 'wild', 'fire', 'via']
# 10469 ['even', 'news', 'cover', 'tent', 'collaps', 'wild', 'fire', 'no', 'mention', 'of', 'worst', 'plan', 'parenthood', 'video', 'to', 'date', 'narr']
# 10470 ['the', 'out', 'of', 'control', 'wild', 'fire', 'in', 'california', 'even', 'in', 'the', 'northern', 'part', 'of', 'the', 'state', 'veri', 'troubl']
# 10471 ['full', 'episod', 'wn', '08', '02', '15', 'california', 'wild', 'fire', 'forc', '12000', 'to', 'evacu', 'worldnew']
# 10472 ['man', 'sell', 'wild', 'morel', 'at', 'amblesid', 'farmr', 'mart', 'sun', 'mushroom', 'foragesecret', 'is', 'to', 'know', 'what', 'tree', 'they', 'grow', 'under', 'amp', 'best', 'after', 'forest', 'fire']
# 10473 ['watch', 'news', 'of', 'wild', 'fire', 'and', 'hope', 'all', 'is', 'ok']
# 10474 ['wild', 'fire', '!']
# 10475 ['wild', 'fire', 'in', 'california', 'continu', 'to', 'burn']
# 10476 ['one', 'of', 'them', 'wild', 'fire', 'in', 'cali', 'or', 'someth', 'or', 'in', 'the', 'mid', 'west', 'or', 'where', 'ever', 'they', 'show', 'up', 'shit', 'dont', 'pop', 'up', 'around', 'me']
# 10477 ['it', "'s", 'so', 'sad', 'out', 'there', 'in', 'bc', 'all', 'the', 'wild', 'fire', 'hope', 'u', 'are', 'safe']
# 10478 ["'your", 'love', 'will', 'sure', 'come', 'find', 'us', 'like', 'blaze', 'wild', 'fire', 'sing', 'your', 'name', "'"]
# 10479 ['a5', 'donat', 'some', 'fruit', 'snack', 'amp', 'handi', 'wipe', 'to', 'our', 'fire', 'fighter', 'battl', 'wild', 'fire', '!', 'profittothepeopl']
# 10480 ['when', 'there', "'s", '35', 'wild', 'fire', 'in', 'the', 'us', 'and', '21', 'of', 'them', 'are', 'in', 'california', 'and', 'we', "'re", 'in', 'a', 'drought', 'thi', 'state', 'is', 'so', 'sad']
# 10481 ['wild', 'land', 'fire', 'here', 'i', 'come', '?', '?', '?', '?', '?', '?']
# 10482 ['ye', 'god', 'doessnt', 'chang', 'he', 'say', 'not', 'to', 'rejoic', 'over', 'the', 'fall', 'of', 'peopl', 'or', 'calam', 'like', 'wild', 'fire', 'ect', 'you', 'wan', 'na', 'be', 'punish', '?']
# 10483 ['my', 'heart', 'goe', 'out', 'to', 'all', 'those', 'effect', 'by', 'the', 'wild', 'fire', 'in', 'cali', '?', '?', '?', '?']
# 10484 ['wild', 'fire', 'in', 'california', 'must', 'be', 'global', 'warm', 'ca', "n't", 'just', 'be', 'extrem', 'heat', 'combin', 'with', 'dri', 'foliag', 'ignit', 'by', 'some', 'douchebag', 'hiker']
# 10487 ['fire', 'in', 'pisgah', 'nation', 'forest', 'grow', 'to', '375', 'acr', 'wsoc', 'charlott']
# 10488 ['rout', 'complex', 'am', 'fire', 'updat', '(', 'rout', 'complex', 'wildfir', ')', 'fire', 'updat', 'rout', 'complex', 'thursday', 'morn', 'aug', 'cafir']
# 10490 ['we', 'should', 'all', 'have', 'a', 'fire', 'safeti', 'plan', 'rt', 'mock', 'wildfir', 'near', 'vail', 'as', 'agenc', 'prepar', 'for', 'the', 'worst']
# 10497 ['here', "'s", 'a', 'quick', 'timelaps', 'i', 'made', 'of', 'the', 'finger', 'rock', 'fire', 'last', 'night', 'from', 'about', '9pm', '1am', 'check', 'it', 'out', '!', 'fingerrockfir', 'wildfir', 'catalina']
# 10498 ['drone', 'under', 'fire', 'offici', 'offer', '75000', 'reward', 'lead', 'to', 'pilot', 'who', 'flew', 'over', 'wildfir', 'photographi', 'art']
# 10501 ['wawildfir', 'in', 'chelan', '?', 'wolverin', 'fire', 'result', 'in', 'evacu']
# 10508 ['dr', 'bengston', 'on', 'wildfir', 'manag', 'number', 'and', 'size', 'of', 'fire', 'area', 'affect', 'and', 'cost', 'of', 'fight', 'them', 'all', 'show', 'upward', 'trend', 'smem']
# 10509 ['as', 'california', 'fire', 'rage', 'the', 'forest', 'servic', 'sound', 'the', 'alarm', 'about', 'sharpli', 'rise', 'wildfir', 'cost']
# 10512 ['wolverin', 'fire', 'updat', 'thursday', 'august', '6', '9', '00', 'am', 'incid', 'wolverin', 'fire', 'wildfir', 'releas', '41', 'min', 'ago']
# 10515 ['photo', 'the', 'rocki', 'fire', 'ha', 'grown', 'into', 'california', "'s", 'most', 'destruct', 'wildfir', 'thi', 'year']
# 10518 ['california', 'is', 'battl', 'it', 'scariest', '2015', 'wildfir', 'so', 'far', 'the', 'rocki', 'fire']
# 10519 ['solitud', 'fire', 'updat', 'august', '6', '2015', '(', 'solitud', 'wildfir', ')', 'summari', 'thi', 'lightn', 'caus', 'fire', 'is', 'be', 'utfir']
# 10521 ['reuter', 'top', 'news', 'photo', 'the', 'rocki', 'fire', 'ha', 'grown', 'into', 'california', "'s", 'most', 'newsintweet']
# 10530 ['rocki', 'fire', 'cali', 'scfd', 'wildfir', 'lakecounti']
# 10532 ['forest', 'grove', 'grass', 'fire', 'spark', 'by', 'tractor', 'quickli', 'contain', 'katu']
# 10555 ['realiti', 'train', 'train', 'fall', 'off', 'elev', 'track', 'dure', 'windstorm', 'fire', 'em']
# 10590 ['gunmen', 'open', 'fire', 'on', 'bu', 'near', 'el', 'salvador', "'s", 'capit', 'kill', '4', 'a', 'week', 'after', 'gang', 'attack', 'kill', '8', 'bu', 'driver', 'bit', '_']

# %%
# Try Lemmatizing as a separate column
wordnet_lemmatizer = WordNetLemmatizer()
questions['lemma'] =  [[wordnet_lemmatizer.lemmatize(item) for item in row] for row in questions['tokens']]

# %% [markdown]
# We will just keep parallel paths of lemmatization and stemming and see which leads to better results.

# %%
# Some more exploration... how many words in the vocabulary?
# Create vectors from vocabulary
stem_vocab = collections.Counter()
for item in questions.stems:
    stem_vocab.update(item)
lemm_vocab = collections.Counter()
for item in questions.lemma:
    lemm_vocab.update(item)

print('==========================\nStemmed data:')
print('Total number of stems/words:     ',sum(stem_vocab.values()))
print('Total unique stems/words:        ',len(stem_vocab))
print('Most common words in the lextcon:\n',stem_vocab.most_common(100))
print('==========================\nLemmatized data:')
print('Total number of stems/words:     ',sum(lemm_vocab.values()))
print('Total unique stems/words:        ',len(lemm_vocab))
print('Most common words in the lextcon:\n',lemm_vocab.most_common(100))
# Out:
# ==========================
# Stemmed data:
# Total number of stems/words:      162142
# Total unique stems/words:         14726
# Most common words in the lextcon:
#  [('the', 4552), ('?', 4404), ('a', 3093), ('to', 2830), ('in', 2793), ('of', 2597), ('i', 2500), ('and', 2013), ('!', 1647), ('is', 1413), ('you', 1274), ('for', 1238), ('on', 1234), ('it', 1219), ("'s", 1091), ("'", 1043), ('my', 969), ('that', 851), ('with', 797), ('at', 790), ('by', 772), ('be', 715), ('thi', 706), ("n't", 620), ('are', 619), ('from', 611), ('like', 590), ('wa', 581), ('have', 563), ('_', 532), ('fire', 529), ('do', 516), (')', 512), ('amp', 509), ('(', 503), ('as', 484), ('up', 464), ('your', 461), ('just', 453), ('get', 451), ('me', 450), ('not', 444), ('but', 434), ('so', 428), ('we', 412), ('out', 412), ('no', 399), ('will', 378), ('all', 366), ('ha', 366), ('after', 365), ('when', 359), ("'m", 351), ('he', 351), ('an', 349), ('if', 344), ('bomb', 331), ('new', 329), ('they', 325), ('via', 324), ('more', 322), ('about', 313), ('2', 310), ('now', 306), ('what', 304), ('one', 294), ('or', 293), ('how', 290), ('go', 289), ('news', 286), ('peopl', 280), ('s', 279), ('there', 269), ('who', 266), ('burn', 258), ('can', 256), ('over', 255), ('kill', 252), ('year', 252), ('been', 245), ('attack', 240), ('video', 238), ('into', 237), ('emerg', 233), ('time', 231), ('crash', 230), ('flood', 230), ('disast', 226), ('would', 225), ('build', 221), ('bodi', 206), ('her', 204), ('hi', 204), ('love', 203), ('say', 203), ('day', 197), ('polic', 196), ('3', 196), ('make', 193), ('look', 188)]
# ==========================
# Lemmatized data:
# Total number of stems/words:      162142
# Total unique stems/words:         16932
# Most common words in the lextcon:
#  [('the', 4552), ('?', 4404), ('a', 3577), ('to', 2828), ('in', 2793), ('of', 2596), ('i', 2500), ('and', 2012), ('!', 1647), ('is', 1413), ('you', 1274), ('for', 1238), ('on', 1234), ('it', 1219), ("'s", 1091), ("'", 1043), ('my', 969), ('that', 843), ('with', 797), ('at', 790), ('by', 772), ('this', 702), ("n't", 620), ('are', 619), ('from', 611), ('be', 592), ('wa', 581), ('_', 532), ('have', 528), ('fire', 518), (')', 512), ('amp', 509), ('(', 503), ('like', 495), ('do', 475), ('up', 464), ('just', 453), ('me', 450), ('not', 444), ('but', 433), ('so', 428), ('your', 427), ('we', 412), ('out', 412), ('no', 399), ('get', 377), ('will', 372), ('all', 366), ('ha', 366), ('after', 365), ('u', 363), ('when', 359), ("'m", 351), ('he', 351), ('an', 349), ('if', 343), ('new', 329), ('they', 325), ('via', 324), ('more', 322), ('about', 312), ('2', 310), ('now', 306), ('what', 299), ('one', 294), ('or', 293), ('how', 290), ('news', 286), ('people', 280), ('s', 279), ('there', 269), ('who', 266), ('can', 256), ('over', 255), ('year', 252), ('been', 245), ('video', 238), ('into', 237), ('time', 228), ('emergency', 227), ('disaster', 226), ('would', 225), ('body', 205), ('building', 198), ('day', 197), ('her', 197), ('police', 196), ('3', 196), ('his', 190), ('life', 189), ('than', 186), ('were', 186), ('storm', 185), ('go', 183), ('home', 181), ('say', 181), ('still', 180), ('family', 180), ("'re", 179), ('some', 178)]

# %% [markdown]
# Yak... what's an embedding, what do these actually look like etc.?

# %%
questions.head()
# compile the 'stems' and 'tokens' columns back into strings for input into a corpus
# questions['s_stem'] = ' '.join(questions.stems)
# questions['tokens']=questions['text'].apply(nltk.word_tokenize)
questions['s_stems'] =  [' '.join(row) for row in questions['stems']]
questions['s_lemmas'] =  [' '.join(row) for row in questions['lemma']]

# %%
# Need to split training and test set before we do TFIDF since it's extracted from the samples themselves.
# Gak, I just stole this code directly.   
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

def cv(data):
    count_vectorizer = CountVectorizer()
    emb = count_vectorizer.fit_transform(data)
    return emb, count_vectorizer

#list_corpus = questions['text'].tolist()
#list_corpus = questions['s_stems'].tolist()
list_corpus = questions['s_lemmas'].tolist()
list_labels = questions['class_label'].tolist()

X_train, X_test, y_train, y_test = train_test_split(list_corpus, list_labels, test_size=0.2, 
                                                                                random_state=40)

X_train_counts, count_vectorizer = cv(X_train)
X_test_counts = count_vectorizer.transform(X_test)

# %%
questions.head()
# Out:
#                                                 text choose_one  class_label  \
# 0                 just happened a terrible car crash   Relevant            1
# 1  our deeds are the reason of this  earthquake m...   Relevant            1
# 2  heard about  earthquake is different cities, s...   Relevant            1
# 3  there is a forest fire at spot pond, geese are...   Relevant            1
# 4             forest fire near la ronge sask  canada   Relevant            1
#
#                                               tokens  \
# 0          [just, happened, a, terrible, car, crash]
# 1  [our, deeds, are, the, reason, of, this, earth...
# 2  [heard, about, earthquake, is, different, citi...
# 3  [there, is, a, forest, fire, at, spot, pond, ,...
# 4      [forest, fire, near, la, ronge, sask, canada]
#
#                                                stems  \
# 0             [just, happen, a, terribl, car, crash]
# 1  [our, deed, are, the, reason, of, thi, earthqu...
# 2  [heard, about, earthquak, is, differ, citi, ,,...
# 3  [there, is, a, forest, fire, at, spot, pond, ,...
# 4       [forest, fire, near, la, rong, sask, canada]
#
#                                                lemma  \
# 0          [just, happened, a, terrible, car, crash]
# 1  [our, deed, are, the, reason, of, this, earthq...
# 2  [heard, about, earthquake, is, different, city...
# 3  [there, is, a, forest, fire, at, spot, pond, ,...
# 4      [forest, fire, near, la, ronge, sask, canada]
#
#                                              s_stems  \
# 0                    just happen a terribl car crash
# 1  our deed are the reason of thi earthquak may a...
# 2  heard about earthquak is differ citi , stay sa...
# 3  there is a forest fire at spot pond , gees are...
# 4               forest fire near la rong sask canada
#
#                                             s_lemmas
# 0                 just happened a terrible car crash
# 1  our deed are the reason of this earthquake may...
# 2  heard about earthquake is different city , sta...
# 3  there is a forest fire at spot pond , goose ar...
# 4              forest fire near la ronge sask canada

# %%
# just playing with a sparse matrix

for row in range(200):
    if (X_train_counts[row,:].max())>2:
        print (row,X_train_counts[row,:].max())
# Out:
# 22 3
# 65 4
# 109 3
# 142 4
# 181 3
# 188 3

# %%
from sklearn.decomposition import PCA, TruncatedSVD
import matplotlib 
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches


def plot_LSA(test_data, test_labels, savepath="PCA_demo.csv", plot=True):
        lsa = TruncatedSVD(n_components=2)
        lsa.fit(test_data)
        lsa_scores = lsa.transform(test_data)
        color_mapper = {label:idx for idx,label in enumerate(set(test_labels))}
        color_column = [color_mapper[label] for label in test_labels]
        colors = ['orange','blue','blue']
        if plot:
            plt.scatter(lsa_scores[:,0], lsa_scores[:,1], s=8, alpha=.8, c=test_labels, cmap=matplotlib.colors.ListedColormap(colors))
            red_patch = mpatches.Patch(color='orange', label='Irrelevant')
            green_patch = mpatches.Patch(color='blue', label='Disaster')
            plt.legend(handles=[red_patch, green_patch], prop={'size': 30})


fig = plt.figure(figsize=(16, 16))          
plot_LSA(X_train_counts, y_train)
plt.show()

# %% [markdown]
# Honestly, this is a little depressing... I mean, I did most of my own stuff here, but then these magical vectorizers do all the work for you and now I'm just copying code like crazy.  Sigh.  I guess that's the idea.
#
# Oooooooh.  Maybe I can reconstruct things from my separately cleaned data to see if I do a bit better...

# %%
from sklearn.linear_model import LogisticRegression

clf = LogisticRegression(C=30.0, class_weight='balanced', solver='newton-cg', 
                         multi_class='multinomial', n_jobs=-1, random_state=40)
clf.fit(X_train_counts, y_train)

y_predicted_counts = clf.predict(X_test_counts)

# %%
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, classification_report

def get_metrics(y_test, y_predicted):  
    # true positives / (true positives+false positives)
    precision = precision_score(y_test, y_predicted, pos_label=None,
                                    average='weighted')             
    # true positives / (true positives + false negatives)
    recall = recall_score(y_test, y_predicted, pos_label=None,
                              average='weighted')
    
    # harmonic mean of precision and recall
    f1 = f1_score(y_test, y_predicted, pos_label=None, average='weighted')
    
    # true positives + true negatives/ total
    accuracy = accuracy_score(y_test, y_predicted)
    return accuracy, precision, recall, f1

accuracy, precision, recall, f1 = get_metrics(y_test, y_predicted_counts)
print("accuracy = %.3f, precision = %.3f, recall = %.3f, f1 = %.3f" % (accuracy, precision, recall, f1))
# Out:
# accuracy = 0.761, precision = 0.760, recall = 0.761, f1 = 0.760

# %%
def tfidf(data):
    tfidf_vectorizer = TfidfVectorizer()
    train = tfidf_vectorizer.fit_transform(data)
    return train, tfidf_vectorizer

X_train_tfidf, tfidf_vectorizer = tfidf(X_train)
X_test_tfidf = tfidf_vectorizer.transform(X_test)

# %%
# just playing with a sparse matrix from tfidf... what does it look like?

for row in range(20):
    print (row,X_train_tfidf[row,:])
#     if (X_train_tfidf[row,:].max())>2:
#        print (row,X_train_tfidf[row,:].max())
# Out:
# 0   (0, 6364)	0.2532093326943942
#   (0, 5440)	0.30874422814716146
#   (0, 6203)	0.2829899898107953
#   (0, 3092)	0.2913305457891839
#   (0, 13102)	0.11068090631430708
#   (0, 11474)	0.28191640761791625
#   (0, 3575)	0.29403146393925467
#   (0, 12047)	0.26990248983066817
#   (0, 14050)	0.26110982998661336
#   (0, 1928)	0.2526558907309076
#   (0, 6048)	0.2926605402301968
#   (0, 223)	0.2455531450907346
#   (0, 10077)	0.29003910739136796
#   (0, 1814)	0.2499873383687721
# 1   (0, 13102)	0.13107173171311987
#   (0, 12860)	0.3679696483024547
#   (0, 11439)	0.36122525396996874
#   (0, 3035)	0.3847710321191115
#   (0, 9257)	0.17140481285733752
#   (0, 11140)	0.3633789922718792
#   (0, 5245)	0.17043147276860152
#   (0, 2665)	0.3268090586079953
#   (0, 14255)	0.33913440573514403
#   (0, 6792)	0.39572593175502613
# 2   (0, 5744)	0.30374919239609893
#   (0, 6162)	0.19371009020462793
#   (0, 1249)	0.14047458311664657
#   (0, 3535)	0.2105258640059097
#   (0, 7614)	0.2382101309078313
#   (0, 13670)	0.2521999723484079
#   (0, 12438)	0.27230175512571797
#   (0, 12679)	0.261968017847349
#   (0, 2760)	0.21827426383244583
#   (0, 14355)	0.18783874377676685
#   (0, 6448)	0.22103875719483218
#   (0, 13464)	0.21331180895782798
#   (0, 10519)	0.30374919239609893
#   (0, 2572)	0.336662983697359
#   (0, 3688)	0.336662983697359
#   (0, 856)	0.21633213217572914
# 3   (0, 9953)	0.2975016863209964
#   (0, 9190)	0.3847872939507131
#   (0, 14380)	0.35648083635536154
#   (0, 12586)	0.37476794544112707
#   (0, 3604)	0.3138680593926915
#   (0, 848)	0.2587433662137877
#   (0, 4749)	0.441972370598666
#   (0, 11668)	0.36756090759531035
# 4   (0, 11021)	0.8762136149802796
#   (0, 5096)	0.481922920105685
# 5   (0, 7127)	0.44881151034739775
#   (0, 1764)	0.44881151034739775
#   (0, 12201)	0.39620279605085634
#   (0, 1117)	0.3090896372076693
#   (0, 12890)	0.1736458626852073
#   (0, 1579)	0.33621234284851625
#   (0, 7626)	0.44881151034739775
# 6   (0, 3604)	0.208103955222803
#   (0, 8566)	0.4874078541401808
#   (0, 2047)	0.21828184857375857
#   (0, 12399)	0.27329423332854547
#   (0, 11294)	0.2402655287373909
#   (0, 12099)	0.29304096313191963
#   (0, 5251)	0.27527705247048395
#   (0, 1371)	0.1421393401097453
#   (0, 7550)	0.2505724591773613
#   (0, 108)	0.23280854851592564
#   (0, 9693)	0.17871394214920872
#   (0, 12484)	0.20307655670534494
#   (0, 2046)	0.22324461491064346
#   (0, 12414)	0.28994679234716697
#   (0, 8890)	0.18203188489426117
# 7   (0, 13102)	0.08157933044191892
#   (0, 5245)	0.10607691874495113
#   (0, 66)	0.3077659442985788
#   (0, 12205)	0.3077659442985788
#   (0, 7472)	0.3077659442985788
#   (0, 4478)	0.3189215144692862
#   (0, 7687)	0.20779150207489594
#   (0, 2342)	0.29445149224461714
#   (0, 12894)	0.07047545623215602
#   (0, 9601)	0.20552595009247207
#   (0, 307)	0.19953896976347868
#   (0, 8368)	0.24892907999580707
#   (0, 12548)	0.27767726644920554
#   (0, 8830)	0.1777028242255226
#   (0, 9873)	0.18963927776441128
#   (0, 8714)	0.11650325556413438
#   (0, 1826)	0.20701881985561524
#   (0, 11837)	0.29445149224461714
#   (0, 11118)	0.17197749850164878
# 8   (0, 12890)	0.18908453780875709
#   (0, 675)	0.4314287793059835
#   (0, 5730)	0.3379991727240785
#   (0, 7947)	0.32996113100143654
#   (0, 2865)	0.41028618389413596
#   (0, 5800)	0.4314287793059835
#   (0, 14124)	0.2660755362389515
#   (0, 9034)	0.22060768650216175
#   (0, 14078)	0.2847261325866379
# 9   (0, 9257)	0.13786993594531785
#   (0, 8811)	0.39773702762891766
#   (0, 8003)	0.32943721684195515
#   (0, 9191)	0.26113740605499264
#   (0, 11314)	0.21595421426013187
#   (0, 3623)	0.2548388976203014
#   (0, 5298)	0.25411346015239383
#   (0, 10881)	0.275078152351322
#   (0, 6931)	0.2619947495265927
#   (0, 6917)	0.13300088078778047
#   (0, 5383)	0.16533202369004452
#   (0, 8312)	0.24336857109440155
#   (0, 1886)	0.39773702762891766
#   (0, 10786)	0.251329704440349
# 10   (0, 13102)	0.18769600804060657
#   (0, 5245)	0.12202977203796958
#   (0, 4703)	0.21109957203264726
#   (0, 12283)	0.35405070648880976
#   (0, 13628)	0.15809258664191517
#   (0, 974)	0.16476949467609886
#   (0, 8935)	0.22372435362429838
#   (0, 6077)	0.17288544643884232
#   (0, 1633)	0.3387339008332651
#   (0, 1086)	0.21129005111303256
#   (0, 12918)	0.21153130119830474
#   (0, 6060)	0.26346807646382603
#   (0, 11147)	0.22372435362429838
#   (0, 12999)	0.22750509542771669
#   (0, 4289)	0.23904115927984304
#   (0, 12355)	0.19223440820644508
#   (0, 999)	0.251751697754682
#   (0, 9597)	0.29723284296213104
#   (0, 9405)	0.16340916831981891
# 11   (0, 5245)	0.13538318644597666
#   (0, 4351)	0.3083497896165617
#   (0, 9409)	0.2683046751332815
#   (0, 928)	0.3143470905343756
#   (0, 8014)	0.22120120020802075
#   (0, 12854)	0.3637440648044599
#   (0, 8838)	0.3543922050176558
#   (0, 13869)	0.3543922050176558
#   (0, 5102)	0.2837158782068716
#   (0, 4893)	0.22446853820768015
#   (0, 8240)	0.2837158782068716
#   (0, 10388)	0.2683046751332815
# 12   (0, 5245)	0.15861719066014127
#   (0, 3623)	0.29486254718670885
#   (0, 5383)	0.19129819698645645
#   (0, 8312)	0.2815907518364975
#   (0, 3132)	0.3051884720240896
#   (0, 10702)	0.3863502957942969
#   (0, 6333)	0.2900289428846439
#   (0, 3971)	0.4062594429015612
#   (0, 9177)	0.12503312405216097
#   (0, 3339)	0.2523004107910677
#   (0, 11786)	0.30955597134403445
#   (0, 13809)	0.220448169386591
#   (0, 13829)	0.23817464611728653
# 13   (0, 12894)	0.0920002511125567
#   (0, 1086)	0.11988235490229118
#   (0, 12355)	0.21814101920689535
#   (0, 9209)	0.26128394616025535
#   (0, 11642)	0.2518805666367814
#   (0, 6945)	0.14113741168821406
#   (0, 10995)	0.3052589648285983
#   (0, 11605)	0.4017646095981318
#   (0, 653)	0.4017646095981318
#   (0, 12926)	0.20085869078424443
#   (0, 13016)	0.26735604862585605
#   (0, 7666)	0.2581649864579249
#   (0, 8416)	0.3423386252619147
#   (0, 12493)	0.2574194583370862
# 14   (0, 5629)	0.3043213532697509
#   (0, 8186)	0.20072709968596925
#   (0, 14552)	0.2056474423778454
#   (0, 7900)	0.3709738508697673
#   (0, 8504)	0.31746207051385633
#   (0, 8860)	0.4418877560110317
#   (0, 5152)	0.30306400471313966
#   (0, 2363)	0.17359995949968207
#   (0, 4886)	0.3501424189563735
#   (0, 10390)	0.3828227673988907
# 15   (0, 12170)	0.2404675440100261
#   (0, 5177)	0.185189834323472
#   (0, 3019)	0.2613463760778228
#   (0, 455)	0.2794914668928954
#   (0, 312)	0.2794914668928954
#   (0, 3492)	0.2794914668928954
#   (0, 3364)	0.24774206792385325
#   (0, 7555)	0.2404675440100261
#   (0, 14345)	0.20188488276917096
#   (0, 7659)	0.21787652000378543
#   (0, 1612)	0.23556029127789654
#   (0, 437)	0.27574894491281177
#   (0, 9197)	0.2511275908649315
#   (0, 5212)	0.27574894491281177
#   (0, 7450)	0.24939451030172508
#   (0, 5423)	0.18838163045970524
#   (0, 10538)	0.17172455219975424
# 16   (0, 13628)	0.1960857005370527
#   (0, 6708)	0.43913685190530116
#   (0, 4210)	0.3247024756692151
#   (0, 8856)	0.43913685190530116
#   (0, 3618)	0.24538666051138988
#   (0, 6093)	0.3063887218993549
#   (0, 8388)	0.3514349359002722
#   (0, 5894)	0.43913685190530116
# 17   (0, 6917)	0.16714610515752357
#   (0, 6382)	0.2451926226945151
#   (0, 12960)	0.40156357080524246
#   (0, 11397)	0.49984778034050303
#   (0, 12321)	0.273649786424831
#   (0, 972)	0.3826656294311402
#   (0, 9140)	0.34569877663303133
#   (0, 2449)	0.40002102278981483
# 18   (0, 8714)	0.19620390527123868
#   (0, 5625)	0.32664917684178113
#   (0, 5725)	0.2870356982090551
#   (0, 5626)	0.4676381258065766
#   (0, 2735)	0.4676381258065766
#   (0, 2002)	0.39680015736359786
#   (0, 7671)	0.22857903121137238
#   (0, 14180)	0.3540413520613956
# 19   (0, 12047)	0.19049090129932236
#   (0, 12890)	0.11401997230442
#   (0, 12894)	0.06748353308954726
#   (0, 6077)	0.14390419282295083
#   (0, 7671)	0.25993018347503555
#   (0, 1160)	0.21061586235285243
#   (0, 4458)	0.2193022122978662
#   (0, 12951)	0.16898314237826792
#   (0, 12301)	0.520312216301377
#   (0, 1094)	0.2819510235549177
#   (0, 3891)	0.2511104009643233
#   (0, 14165)	0.13843232291167892
#   (0, 5583)	0.13767721316011985
#   (0, 4752)	0.24409400537000858
#   (0, 3908)	0.2729053163685524
#   (0, 1763)	0.17431466621050057
#   (0, 774)	0.2038170691243663
#   (0, 8121)	0.2819510235549177

# %%
fig = plt.figure(figsize=(16, 16))          
plot_LSA(X_train_tfidf, y_train)
plt.show()

# %%
clf_tfidf = LogisticRegression(C=30.0, class_weight='balanced', solver='newton-cg', 
                         multi_class='multinomial', n_jobs=-1, random_state=40)
clf_tfidf.fit(X_train_tfidf, y_train)

y_predicted_tfidf = clf_tfidf.predict(X_test_tfidf)

# %%
accuracy_tfidf, precision_tfidf, recall_tfidf, f1_tfidf = get_metrics(y_test, y_predicted_tfidf)
print("accuracy = %.3f, precision = %.3f, recall = %.3f, f1 = %.3f" % (accuracy_tfidf, precision_tfidf, 
                                                                       recall_tfidf, f1_tfidf))
# Out:
# accuracy = 0.769, precision = 0.767, recall = 0.769, f1 = 0.768
