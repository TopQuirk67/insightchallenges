# %%
import numpy as np

# %%
n = 50

# %%
[(x, (-21+x*x*x)/7.) for x in range(1,n)]
# Out:
# [(1, -2.857142857142857),
#  (2, -1.8571428571428572),
#  (3, 0.8571428571428571),
#  (4, 6.142857142857143),
#  (5, 14.857142857142858),
#  (6, 27.857142857142858),
#  (7, 46.0),
#  (8, 70.14285714285714),
#  (9, 101.14285714285714),
#  (10, 139.85714285714286),
#  (11, 187.14285714285714),
#  (12, 243.85714285714286),
#  (13, 310.85714285714283),
#  (14, 389.0),
#  (15, 479.14285714285717),
#  (16, 582.1428571428571),
#  (17, 698.8571428571429),
#  (18, 830.1428571428571),
#  (19, 976.8571428571429),
#  (20, 1139.857142857143),
#  (21, 1320.0),
#  (22, 1518.142857142857),
#  (23, 1735.142857142857),
#  (24, 1971.857142857143),
#  (25, 2229.1428571428573),
#  (26, 2507.8571428571427),
#  (27, 2808.8571428571427),
#  (28, 3133.0),
#  (29, 3481.1428571428573),
#  (30, 3854.1428571428573),
#  (31, 4252.857142857143),
#  (32, 4678.142857142857),
#  (33, 5130.857142857143),
#  (34, 5611.857142857143),
#  (35, 6122.0),
#  (36, 6662.142857142857),
#  (37, 7233.142857142857),
# ...

# %%
[x**3 for x in range(1,n)]
# Out:
# [1,
#  8,
#  27,
#  64,
#  125,
#  216,
#  343,
#  512,
#  729,
#  1000,
#  1331,
#  1728,
#  2197,
#  2744,
#  3375,
#  4096,
#  4913,
#  5832,
#  6859,
#  8000,
#  9261,
#  10648,
#  12167,
#  13824,
#  15625,
#  17576,
#  19683,
#  21952,
#  24389,
#  27000,
#  29791,
#  32768,
#  35937,
#  39304,
#  42875,
#  46656,
#  50653,
#  54872,
#  59319,
#  64000,
#  68921,
#  74088,
#  79507,
#  85184,
#  91125,
#  97336,
#  103823,
#  110592,
#  117649]
