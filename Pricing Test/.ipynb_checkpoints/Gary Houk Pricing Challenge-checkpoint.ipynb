# %% [markdown]
# # Data Challenge: Pricing Test
#
# Determine whether XYZ company's test to sell software for $59 rather than $39 produces a net gain in revenue.
#
# ## My Investigation
#
# 1.
# 2.
#
#
# ### Hypotheses
# -
# -
# -
# -
#
# ## Findings
# - The price change has depressed conversion rate, but because we have a higher price, actual revenue per customer is higher
# - The A/B test for increasing revenue per customer could have been significantly shorter.
#
# ## Recommendation for XYZ
# ...

# %% [markdown]
# # Code and Analysis

# %%
import pandas as pd
import math
import numpy as np
import datetime as dt
import matplotlib.pyplot as plt
import seaborn as sns
import altair as alt
from statsmodels.stats.proportion import proportions_ztest
import scipy.stats as st
# Load data; start with only the events CSV because it's where the user engagement info is
df = pd.read_csv('Pricing_Test_data/test_results.csv')
users = pd.read_csv('Pricing_Test_data/user_table.csv')
# Since all user_id's are unique in both frames, we can merge / join them on the user_id key
df = df.merge(users, on='user_id')
df.head(10)
# Out:
#    user_id            timestamp          source  device operative_system  \
# 0   604839  2015-05-08 03:38:34    ads_facebook  mobile              iOS
# 1   624057  2015-05-10 21:08:46      seo-google  mobile          android
# 2   317970  2015-04-04 15:01:23        ads-bing  mobile          android
# 3   685636  2015-05-07 07:26:01  direct_traffic  mobile              iOS
# 4   820854  2015-05-24 11:04:40    ads_facebook     web              mac
# 5   169971  2015-04-13 12:07:08      ads-google  mobile              iOS
# 6   798371  2015-03-15 08:19:29        ads-bing  mobile          android
# 7   447194  2015-03-28 12:28:10    ads_facebook     web          windows
# 8   431639  2015-04-24 12:42:18    ads_facebook     web          windows
# 9   590182  2015-04-17 13:30:04      ads-google     web          windows
#
#    test  price  converted                 city country    lat   long
# 0     0     39          0              Buffalo     USA  42.89 -78.86
# 1     0     39          0            Lakeville     USA  44.68 -93.24
# 2     0     39          0                Parma     USA  41.38 -81.73
# 3     1     59          0         Fayetteville     USA  35.07 -78.90
# 4     0     39          0              Fishers     USA  39.95 -86.02
# 5     0     39          0             New York     USA  40.67 -73.94
# 6     1     59          1          East Orange     USA  40.77 -74.21
# 7     1     59          0               Dayton     USA  39.78 -84.20
# 8     1     59          0             Richmond     USA  37.53 -77.47
# 9     0     39          0  Bloomfield Township     USA  42.58 -83.27

# %% [markdown]
# ## Invalid data check
#
# It turns out that there are some rows where the test / train  price designations don't match.
#
# Since I don't have specs for what to do with this, I will simply drop those rows in the interest in getting an initial analysis in a reasonable time.

# %%
# Drop rows where price = 59 does not correspond to test = 1
# store the dropped data for later analysis for oddities if there is time
dfdropped = df[(df['test']==0)!=(df['price']==39)] 
df=df[(df['test']==0)==(df['price']==39)]
train = df[df['test']==0]
test  = df[df['test']==1]

# %% [markdown]
# ## Find raw rates of conversion overall with uncertainties and statistical significances
#
# Here we calculate the one-sided t-test to see if the conversion rate

# %%
Ntrain = len(train)
Ntest  = len(test)
conv_train = sum(train['converted'])/Ntrain
conv_test  = sum(test['converted'])/Ntest
sig_conv_train = np.sqrt(conv_train*(1.-conv_train)/Ntrain)
sig_conv_test  = np.sqrt(conv_test* (1.-conv_test)/Ntest)
print('Conversion rate, train:',round(100*conv_train,3),' +- ',round(100*sig_conv_train,3),'%')
print('Conversion rate, train:',round(100*conv_test,3),' +- ',round(100*sig_conv_test,3),'%')
revC_train = conv_train * 39
revC_test  = conv_test * 59
sig_revC_train = revC_train * (sig_conv_train / conv_train)
sig_revC_test  = revC_test  * (sig_conv_test  / conv_test)
print('Rev / customer, train: $',round(revC_train,5),' +- ',round(sig_revC_train,5))
print('Rev / customer, test:  $',round(revC_test,5),' +- ',round(sig_revC_test,5))

statdata = pd.DataFrame({
    "Converted": [sum(test['converted']), sum(train['converted'])],
    "Total": [Ntest, Ntrain]
    }, index=['Test', 'Train'])

x=proportions_ztest(
    count=statdata.Converted, nobs=statdata.Total, alternative='two-sided')
print('T-test and significance that conversion rate is different (two-sided): ',x)
#
# both samples are pretty big, so just do a simple z-score
z = (revC_test-revC_train)/(np.sqrt((sig_revC_train/Ntrain)**2+(sig_revC_test/Ntest)**2))
p = st.norm.cdf(-1*z)
print('Is the revenue increased? z-score:',z,' And one-sided p:',p)

# Now we estimate how much smaller the sample could have been (given the actual observed difference in means)
# to be able to make this determination at p = 0.05
      
p = 0.01
z = st.norm.ppf(1.-p)
# Assume f = 0.67 proportion between train and test, propagate from there:
Nneeded = 4.5*(.5*sig_revC_train+0.5*sig_revC_test)**2/((revC_test-revC_train)/z)**2
print('Our test consisted of ',Ntrain+Ntest,' user interactions but we needed only ',Nneeded)
# Out:
# Conversion rate, train: 1.977  +-  0.033 %
# Conversion rate, train: 1.545  +-  0.039 %
# Rev / customer, train: $ 0.77097  +-  0.01293
# Rev / customer, test:  $ 0.91133  +-  0.02312
# T-test and significance that conversion rate is different (two-sided):  (-8.139210289348732, 3.978644140013609e-16)
# Is the revenue increased? z-score: 573724.7341576539  And one-sided p: 0.0
# Our test consisted of  275294  user interactions but we needed only  0.40160723658094216

# %% [markdown]
# # SCRAP ANALYSIS & CODE

# %% [markdown]
# ## Conclusions:
#
# - We find a statistically significant change in conversion rate.
# - We find a statistically significant increase in revenue per customer.
# - We believe that

# %% [markdown]
# ## Data integity and basic information checks

# %%
df.head(10)
# check that the user_ids are unique ... if so we can join with the users frame to get 
# all information in one place
sum(df['user_id'].value_counts()!=1)
users.head(10)
sum(users['user_id'].value_counts()!=1)
# answer is, yes, they are unique, so use this as a key to combine
# also check that price = 59 corresponds to test = 1
# if you test this before the Invalid data check, it shows ~300 rows incorrect
df[(df['test']==0)!=(df['price']==39)].shape
# Out:
# (0, 12)

# %%
df.head(10)
# Out:
#    user_id            timestamp          source  device operative_system  \
# 0   604839  2015-05-08 03:38:34    ads_facebook  mobile              iOS
# 1   624057  2015-05-10 21:08:46      seo-google  mobile          android
# 2   317970  2015-04-04 15:01:23        ads-bing  mobile          android
# 3   685636  2015-05-07 07:26:01  direct_traffic  mobile              iOS
# 4   820854  2015-05-24 11:04:40    ads_facebook     web              mac
# 5   169971  2015-04-13 12:07:08      ads-google  mobile              iOS
# 6   798371  2015-03-15 08:19:29        ads-bing  mobile          android
# 7   447194  2015-03-28 12:28:10    ads_facebook     web          windows
# 8   431639  2015-04-24 12:42:18    ads_facebook     web          windows
# 9   590182  2015-04-17 13:30:04      ads-google     web          windows
#
# 262285   782790  2015-05-24 02:44:40   direct_traffic     web
# 263673   287861  2015-03-08 16:47:33         ads-bing  mobile
# 265163   849338  2015-05-17 16:04:53        ads-yahoo     web
# 265812   820047  2015-05-21 18:10:52     seo_facebook     web
# 267504   160411  2015-03-28 12:25:19         ads-bing     web
# 267687   744493  2015-05-08 18:10:09        ads_other  mobile
# 268618   755080  2015-03-28 18:06:27        ads_other  mobile
# 270091   362747  2015-03-05 10:44:54     ads_facebook     web
# 271051   326423  2015-05-25 19:15:05       ads-google     web
# 271711   193582  2015-05-16 12:08:45   direct_traffic  mobile
# 272089   894867  2015-03-05 10:44:54     ads_facebook     web
# 272114   782507  2015-04-05 18:01:28   direct_traffic     web
# 272967   557784  2015-05-17 16:04:53        ads-yahoo     web
# 272977   237101  2015-05-06 22:40:51        ads_other  mobile
# 273438   666946  2015-05-22 13:32:48   direct_traffic     web
# 273530    24049  2015-04-12 14:39:38       seo-google     web
# 273539   191130  2015-04-10 15:45:42   direct_traffic  mobile
# 273799   237644  2015-05-15 11:41:49   direct_traffic  mobile
# 274515   590389  2015-04-14 04:07:41   direct_traffic  mobile
# 274805   748425  2015-05-25 19:15:05       ads-google     web
#
#        operative_system  test  price  converted            city country  \
# 1268            android     1     39          0       Kennewick     USA
# 1668            android     1     39          0     Los Angeles     USA
# 2037            windows     1     39          0     Saint Louis     USA
# 2734                iOS     1     39          0        Bellevue     USA
# 3707            windows     1     39          0     West Covina     USA
# 7149                iOS     0     59          0       Arlington     USA
# 7261            windows     0     59          0      Bridgeport     USA
# 10038             other     0     59          0     Carson City     USA
# 10242           windows     1     39          0         Vallejo     USA
# 10397               iOS     1     39          0       La Puente     USA
# 12731           android     0     59          0           Plano     USA
# 13060           windows     0     59          0         Ontario     USA
# 13678               iOS     0     59          0            Orem     USA
# 14465             other     1     39          0          Toledo     USA
# 15007           windows     0     59          0   Warner Robins     USA
# 15670             other     1     39          0   The Woodlands     USA
# 16337           android     1     39          0    Indianapolis     USA
# 17578           android     0     59          0     Palm Harbor     USA
# 17924           windows     0     59          0         Fontana     USA
# 19948           windows     0     59          0          Cicero     USA
# 20365             other     0     59          0       Levittown     USA
# 23241           android     1     39          0        New York     USA
# 23464           windows     0     59          0         Raleigh     USA
# 24261               iOS     0     59          0        New York     USA
# 25419               iOS     0     59          0    Philadelphia     USA
# 30712           android     0     59          0     Palm Harbor     USA
# 32989               iOS     1     39          0       Knoxville     USA
# 34481           windows     1     39          0           Brick     USA
# 35991               iOS     0     59          0      Shreveport     USA
# 36272           windows     1     39          0      Rapid City     USA
# ...                 ...   ...    ...        ...             ...     ...
# 253751              iOS     0     59          0  Corpus Christi     USA
# 255378              iOS     0     59          0    Philadelphia     USA
# 255423              iOS     1     39          0   Castro Valley     USA
# 255805          android     0     59          0         Turlock     USA
# 256041              iOS     0     59          0         Chicago     USA
# 257866            other     0     59          0           Miami     USA
# 257924              iOS     1     39          0        New York     USA
# 259395          windows     0     59          0      Santa Cruz     USA
# 261149          windows     0     59          0     Los Angeles     USA
# 261678          android     1     39          0      Hutchinson     USA
# 262285          windows     1     39          0        Columbia     USA
# 263673          android     0     59          0     Palm Harbor     USA
# 265163          windows     1     39          0    Philadelphia     USA
# 265812          windows     0     59          0      Santa Cruz     USA
# 267504          windows     0     59          0          Irvine     USA
# 267687              iOS     1     39          0         Memphis     USA
# 268618          android     0     59          0        New York     USA
# 270091          windows     0     59          0      Georgetown     USA
# 271051          windows     1     39          0        Mesquite     USA
# 271711            other     0     59          0     Carson City     USA
# 272089          windows     0     59          0      Georgetown     USA
# 272114          windows     1     39          0        New York     USA
# 272967          windows     1     39          0    Philadelphia     USA
# 272977              iOS     0     59          0       Arlington     USA
# 273438              mac     0     59          0        San Jose     USA
# 273530              mac     1     39          0          Albany     USA
# 273539          android     1     39          0       Placentia     USA
# 273799          android     1     39          0     Los Angeles     USA
# 274515              iOS     0     59          0       Livermore     USA
# 274805          windows     1     39          0        Mesquite     USA
#
#           lat    long
# 1268    46.20 -119.17
# 1668    34.11 -118.41
# 2037    38.64  -90.24
# 2734    41.16  -95.92
# 3707    34.05 -117.91
# 7149    32.69  -97.13
# 7261    41.19  -73.20
# 10038   39.15 -119.74
# 10242   38.11 -122.26
# 10397   34.03 -117.95
# 12731   33.05  -96.75
# 13060   34.05 -117.61
# 13678   40.30 -111.70
# 14465   41.66  -83.58
# 15007   32.61  -83.63
# 15670   30.16  -95.49
# 16337   39.78  -86.15
# 17578   28.09  -82.76
# 17924   34.10 -117.46
# 19948   41.84  -87.76
# 20365   40.15  -74.85
# 23241   40.67  -73.94
# 23464   35.82  -78.66
# 24261   40.67  -73.94
# 25419   40.01  -75.13
# 30712   28.09  -82.76
# 32989   35.97  -83.95
# 34481   40.06  -74.11
# 35991   32.47  -93.80
# 36272   44.08 -103.23
# ...       ...     ...
# 253751  27.71  -97.29
# 255378  40.01  -75.13
# 255423  37.71 -122.06
# 255805  37.50 -120.85
# 256041  41.84  -87.68
# 257866  25.78  -80.21
# 257924  40.67  -73.94
# 259395  36.97 -122.04
# 261149  34.11 -118.41
# 261678  38.07  -97.91
# 262285  34.04  -80.89
# 263673  28.09  -82.76
# 265163  40.01  -75.13
# 265812  36.97 -122.04
# 267504  33.66 -117.80
# 267687  35.11  -90.01
# 268618  40.67  -73.94
# 270091  30.65  -97.69
# 271051  32.77  -96.60
# 271711  39.15 -119.74
# 272089  30.65  -97.69
# 272114  40.67  -73.94
# 272967  40.01  -75.13
# 272977  32.69  -97.13
# 273438  37.30 -121.85
# 273530  42.67  -73.80
# 273539  33.88 -117.85
# 273799  34.11 -118.41
# 274515  37.69 -121.76
# 274805  32.77  -96.60
#
# [322 rows x 12 columns]

# %%
# Constructing a t-test from scratch that the revenue per customer is increased (one-sided)
n1 = Ntrain 
s1 = sig_revC_train
x1 = revC_train
n2 = Ntest 
s2 = sig_revC_test
x2 = revC_test
deg_free = (s1**2/n1 + s2**2/n2)**2 / ((s1**2/n1)**2/(n1-1) + (s2**2/n2)**2/(n2-1))
t = (x2-x1) / np.sqrt((s1**2/n1) + (s2**2/n2))
print(t,deg_free)
