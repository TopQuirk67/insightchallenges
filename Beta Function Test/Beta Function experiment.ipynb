# %%
import numpy as np
import matplotlib.pyplot as plt
# just playing with the beta distribution
mu = 0.270
# mu = alpha / (alpha + beta)
alpha = range(0, 100,10)
beta = [item*((1-mu)/mu) for item in alpha]

import scipy.stats as ss

def plot_beta(x_range, a, b, mu=0, sigma=1, cdf=False, **kwargs):
    '''
    Plots the f distribution function for a given x range, a and b
    If mu and sigma are not provided, standard beta is plotted
    If cdf=True cumulative distribution is plotted
    Passes any keyword arguments to matplotlib plot function
    '''
    x = x_range
    if cdf:
        y = ss.beta.cdf(x, a, b, mu, sigma)
    else:
        y = ss.beta.pdf(x, a, b, mu, sigma)
    plt.plot(x, y, **kwargs)
    
x = np.linspace(0, 1, 5000)

for a,b in zip(alpha,beta):
    plot_beta(x, a, b, 0, 1, color='red', lw=2, ls='-', alpha=0.5, label='pdf')
    plt.legend();
